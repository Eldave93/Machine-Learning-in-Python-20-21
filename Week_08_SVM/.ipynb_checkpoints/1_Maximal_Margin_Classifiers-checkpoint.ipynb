# %%
# This line will add a button to toggle visibility of code blocks,
# for use with the HTML export version
from IPython.core.display import HTML
HTML('''<button style="margin:0 auto; display: block;" onclick="jQuery('.code_cell .input_area').toggle();
    jQuery('.prompt').toggle();">Toggle code</button>''')
# Out:
# <button style="margin:0 auto; display: block;" onclick="jQuery('.code_cell .input_area').toggle();
#     jQuery('.prompt').toggle();">Toggle code</button>

# %% [markdown]
# <img src="./Images/UoE_Horizontal_Logo_282_v1_160215.png" alt="drawing" width="600"/>
#
# # Week 8 - Support Vector Machines
# __Dr. David Elliott__
#
# 1. [Introduction](#intro)
#
# 2. [What is a Hyperplane?](#hyperplane)
#
# 3. [Maximal Margin Classifier](#MMC)

# %% [markdown]
# __Common Notation__
#
# - $X$ is a matrix containing all the feature values of all the observations
# - $n$ is the number of observations in the dataset
# - $\mathbf{x}_i$ is a vector of all the feature values (except the label) of the $i$th instance in the dataset.
# - $y_i$ is the label (desired model output) of the $i$th instance in the dataset.
# - $p$ is the number of features in the dataset
# - $\mathbf{x}_j$ is a vector of all the observations values of the $j$th feature in the dataset.

# %% [markdown]
# # 1. Introduction <a id='intro'></a>
#
# The term Support Vector Machines (SVM's) is sometimes used loosely to refer to three methods, each an extension of the previous method$^1$:
#
# - Maximal margin classifier,
# - Support vector classifier,
# - Support vector machine.
#
# SVM's are a common supervised discriminative algorithm, well suited to *complex* small- to medium sized datasets$^2$.
#
# They can be used for both __classification__ and regression.

# %%
# %matplotlib inline

import os # locating directories

import numpy as np   # Arrays
import pandas as pd  # DataFrames

# Plotting
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['animation.embed_limit'] = 30000000.0
import seaborn as sns; sns.set()

from sklearn.datasets import load_iris           # for the Iris data
from IPython.display import Image                # displaying .png images
from sklearn.svm import SVC, LinearSVC           # SVM
from mpl_toolkits.mplot3d import Axes3D          # 3d plots
from sklearn.preprocessing import StandardScaler # scaling features
from sklearn.preprocessing import LabelEncoder   # binary encoding

# colours for print()
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
    
image_dir = os.path.join(os.getcwd(),"Images")

# Initial fig number
fig_num = 0

plt.rcParams['figure.dpi'] = 120
# golden ratio for figures ()
gr = 1.618

height_pix = 500
width_pix = height_pix*gr

height_inch = 4
width_inch = height_inch*gr

# %%
# Centered figures in the notebook and presentation
# ...was a real pain to find this:
# https://gist.githubusercontent.com/maxalbert/800b9f06c7b2dd365ea5

import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import urllib
import base64
from io import BytesIO, StringIO

def fig2str(fig, format='svg'):
    """
    Return a string containing the raw data of the matplotlib figure in the given format.

    """
    assert isinstance(fig, matplotlib.figure.Figure)
    imgdata = BytesIO()
    fig.savefig(imgdata, format=format, bbox_inches='tight')
    imgdata.seek(0)  # rewind the data
    output = imgdata.getvalue()
    if format == 'svg':
        return output
    else:
        return urllib.parse.quote(base64.b64encode(output))

class MatplotlibFigure(object):
    """
    Thin wrapper around a matplotlib figure which provides a custom
    HTML representation that allows tweaking the appearance

    """
    def __init__(self, fig, centered=False):
        assert isinstance(fig, matplotlib.figure.Figure)
        self.centered = centered

    def _repr_html_(self):
        img_str_png = fig2str(fig, format='png')
        uri = 'data:image/png;base64,' + img_str_png
        html_repr = "<img src='{}'>".format(uri)
        if self.centered:
            html_repr = "<center>" + html_repr + "</center>"
        return html_repr

# %% [markdown]
# ## Dataset Example: Iris <a id='data'></a>
#
# To demonstrate SVM's I'll be using Fisher's (or Anderson's) Iris flowers dataset$^3$.
#
# The dataset consists of 50 samples each from three species of Iris (Iris setosa, Iris virginica and Iris versicolor).

# %% [markdown]
# __Notes__
#
# - _"...This data comes from a famous experiment on a series of measurements of three species of iris flowers. R A Fisher, a statistically minded thinker in the early twentieth centure used this dataset in his 1936 paper The Use of multiple measurements in taxonomic problems, published in the Annals of Eugenics."_$^9$

# %%
fig_num+=1
print(color.BOLD+color.UNDERLINE+"Figure %d: Iris Flowers" %(fig_num)+color.END)
# Image from: https://www.ritchieng.com/machine-learning-iris-dataset/
display(Image(os.path.join(image_dir,"iris_flowers.png"), height = height_pix, width=width_pix))
# Out:
# Figure 1: Iris Flowers

# %% [markdown]
# Five attributes were collected for the 150 records.

# %%
iris = load_iris(as_frame=True)  # data stored in a `sklearn.utils.Bunch`
iris_df = iris['data']           # get features DataFrame
target = iris['target']          # get target Series
display(iris_df.head())             # display the first few rows
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# get the labels of flowers capitalised for visualisation
target_names = list(map(lambda s: s.capitalize(), iris['target_names']))

# create a dictionary with the original labels decoded (inverse of LabelEncoder)
decode_label = dict(zip(range(3), target_names))

# make a label encoder to use later if needed
le = LabelEncoder().fit(target_names)
# display the labels
decode_label
# Out:
# {0: 'Setosa', 1: 'Versicolor', 2: 'Virginica'}

# %%
# add the target labels to df for visualisation purposes
iris_vis = pd.concat([iris_df, target],axis=1)
# turn the ints to labels
iris_vis["species"] = iris_vis["target"].replace(decode_label)
# drop the binary labels for the visualisation data
iris_vis = iris_vis.drop('target',axis=1)
# Capitalize column names for plotting
iris_vis.columns = [x.capitalize() for x in list(iris_vis.columns)]
# display the first few rows
iris_vis.head()
# Out:
#    Sepal length (cm)  Sepal width (cm)  Petal length (cm)  Petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   Species
# 0  Setosa
# 1  Setosa
# 2  Setosa
# 3  Setosa
# 4  Setosa

# %% [markdown]
# __Notes__
#
# - Species is the typical target for its use in classification

# %%
fig_num+=1
print(color.BOLD+color.UNDERLINE+"Figure %d: Iris Attributes"%(fig_num)+color.END)
# Image from: https://www.ritchieng.com/machine-learning-iris-dataset/
display(Image(os.path.join(image_dir,"iris_attributes.png")))
# Out:
# Figure 2: Iris Attributes

# %%
g = sns.pairplot(iris_vis, hue="Species", height=height_inch/2, aspect = gr)
fig_num+=1
plt.suptitle("Figure %d: Iris Flower Dataset Pairplot"%(fig_num), y=1.02)
plt.close()
fig = g.fig
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2BwNKbICAgKBgEMbaoERuWaGxJ1PyiRhO/RhNbNGKPUaNRY2xYAQsgvTeBpbN0li1sbzO3/f5Yd2HdXlgWeN6vl3mFe8%2Bce%%2BxDXXXHO8mtfqzJo1i//%2B979s3rwZx3Ho3LkzF1xwAdOmTcPj8TTLMWbMmMEDDzxAYmIi8%2BbNa/Dr%2Bvbty4wZM5qlLT/V2Ovl3HPP5eDBg7z66qucc845x6VtrdkLL7zAiy%2B%2BWGW7oij4fD7atGlDjx49mDx5MhdddBG63ryPacFgkPT0dDp27Nis9R5vu3btIikpqV5lDxw4wPjx46vdpygKHo%2BHiIgI%2Bvbty2WXXcaECROapY3lfxNffvklPXv2bJY6q3M8/r4bcn6FEEIIIYSojgSYhBBCCCEEPXv2JCwsrNYyJ1vndHN7%2Bumnef311wFo164d4eHh7Nq1i2eeeYavvvqKd999lzZt2pzgVrYMuV4aJywsrFIQwnVdSkpKSEtLY/HixSxevJj33nuPV155hfj4%2BGY55pIlS3jkkUe47rrrTppgcGZmJn/961/Zv38/n3zySYNf369fv0oBX9d1CQaDHDhwgHnz5jFv3jymTp3Kww8/3JzNPmk09fwKIYQQQghRTgJMQgghhBCChx56iOHDh9e7/JNPPklJSQmxsbHHsVWtx9y5c3n99dfxeDw899xzFTMl0tLSuOOOO0hJSeGxxx7jqaeeOmFtPO%2B88xg4cCA%2Bn%2B%2B4H6uh14so06dPH955550q213XZfny5Tz44IOkpKRw66238t577xEaGtrkY7766qvs3bu3yfW0pEWLFjF79mz69u3bqNdPnz6dDh06VNlumiYvvvgir776Kv/9738ZM2YM5557bpPaOmvWLODkCqg29fwKIYQQQghRTtZgEkIIIYQQDda%2BfXuSkpJOmxk777//PgC33nprpTRc7dq145FHHgHKOppLSkpOSPsAwsPDSUpKIjEx8YS1QTSOoiiMHDmSd955h4iICLZs2cJrr712opt1yjEMg7vvvpvBgwcD8N///rfJdSYlJZGUlNRsKTKFEEIIIYQ4mUiASQghhBBCiDr069ePs88%2Bm8mTJ1fZV57yzDRNsrKyWrpp4hSSmJjInXfeCcC7775LYWHhCW7Rqal8HbCNGzee4JYIIYQQQghxcpMAkxBCCCGEaLBrr72W5ORk3n333Sr7li1bxs0338xZZ53F4MGDueqqq5g7dy4rVqwgOTmZa6%2B9tqLsgQMHSE5OJjk5maKioip1bd%2B%2BvWJ/dcdfu3YtjzzyCEOGDGHIkCFMmzYNx3Eqyq1atYo77riDs846i379%2BjF27Fj%2B%2BMc/Njhl2O9%2B9zv%2B9a9/0a1btyr7Nm3aBEBISAhxcXHVtvP%2B%2B%2B9v0PGq88ILL5CcnMwbb7xRkd5rwIABTJkyhb179zJjxgySk5O59NJLK70uGAzy73//m8suu4xBgwYxYMAAJkyYwEMPPcSuXbua3K6mSklJ4d5772XMmDH069ePESNG8Otf/5qlS5dWKvfMM8%2BQnJzMfffdV6WOBQsWVFwn%%2B6//77SU5OZubMmaxdu5brrruOwYMHM2LECG666SaWLVvWoPcTCAT497//zS9%2B8QsGDx7MwIEDmTJlCs899xx5eXmVyrbE%2BRVCCCGEEKcPWYNJCCGEEEI0mzfffJMnn3wSgLi4OLp27UpKSgq33357pdRyzeXJJ59k/fr19OzZk9zcXGJjY1HVsjFUL7/8MtOnTwcgMjKSnj17VixqP2vWLKZPn87YsWObdPxly5bx0EMPAXD99dfj9Xqb9obq4dtvv2X9%2BvUkJiaSmJhIcXExHTt2ZM2aNVXKuq7LnXfeyYIFC9B1nc6dO%2BP1etmzZw8fffQRX331FW%2B//TYDBw487u2uznvvvcdf//pXbNumbdu29OrVi8OHD/P999/z/fffc9NNN/GHP/wBgLFjx/Laa69V2/m%2BfPnyiv%2B/cuVKOnXqVPHvI0eOsHnzZiIiIipSo7muy5///Gc%2B/PBDAGJjY%2BnRowe7d%2B/mnXfeYebMmbz22mv079%2B/yrFqOv/NJSwsjO7du7N161ZWr15dMdsG4MEHH%2BTjjz8GytJU9uzZk6ysLFJTU0lNTWX27Nl8/vnnREZGEh4ezpAhQ9i%2BfTuFhYV07NiR2NhY2rVr16j6ys9bQ6%2Bn3NxcfvWrX7FhwwZUVaVjx474fD62bdvG5s2bmTlzJm%2B88UbFMfr164dhGOzZswe/30%2BvXr2afa238iDkseeiMeejLrXdn6Dsuv3000%2BBspmQmZmZLF68mCVLlnD//fczbdq0Oo%2BRnZ3NtGnT2LZtG4qi0K1bNzweDzt27OCVV17h888/5/XXXycpKQlomfMrhBBCCCFOHxJgEkIIIYQQzWLDhg089dRTqKrKn//8Z375y1%2BiKAo5OTncd999zJ07t9mPuX79el588UXOO%2B88HMchPz8fKAsCTJ8%2BnbCwMB599NGK1HamafKvf/2L6dOnc8899/Dll1/Svn37Bh/317/%2BNZs2bSIzMxNd1/nVr37Fb3/72yrlnnzySUpKSggPD2/aGz3G%2BvXruf7663nggQdQFIXs7OxKndbHWrBgAQsWLKBLly68/fbbJCQkAFBYWMh9993HnDlzePbZZ3n77bebrX31tWLFCh599FEA7rnnHm666SZ0Xcd1XT7//HP%2B9Kc/8cYbb9C1a1cuv/xyBg8eTNu2bUlPT2fXrl0VHeZApaDTqlWr%2BMUvflHx70WLFuG6LmPGjEHTNADeeustPvzwQ%2BLi4njqqacYOXIkAMXFxTz99NP897//5a677uKrr76qmO1SriHnv7Hat2/P1q1bSU9Pr9g2b948Pv74Y/x%2BP6%2B88gojRoyo2Ldy5UpuvfVW0tPT%2Bfjjj/nVr35Fnz59eP/997n22mtZuXIl06ZN45prrml0fdC46%2Bn%2B%2B%2B9nw4YNDB48mKeeeqoi%2BJeWlsbvf/97Vq9ezYMPPsjLL78MwPPPP8%2BMGTN44IEH6Nq1a8X6Z80lLy%2BPL774AqBSgLkx56MuNd2fyn344Yf07duXF198kfbt2%2BO6Lv/%2B97958sknefLJJxk%2BfDi9e/eu9Ri/%2B93v2LZtGz179uS5556r%2BLtIT0/nD3/4A8uXL%2Bf222/niy%2B%2BwOv1HvfzK4QQQgghTi%2BSIk8IIYQQQnDddddVpHqq7r85c%2BbUWccr ...

# %%
# reduce the data for example
X_AX_LABEL = "Petal length (cm)"
Y_AX_LABEL = "Petal width (cm)"
REMOVE = "Virginica"

iris_reduced = iris_vis[[X_AX_LABEL, Y_AX_LABEL, "Species"]]
iris_reduced = iris_reduced[iris_reduced.Species != REMOVE]

# get the names of the flowers
flowers = list(iris_reduced.Species.unique())

def reduced_plot(X, x_ax_label, y_ax_label, title=None, scale=1):
    sns.set(font_scale = scale)
    # make scatterplot
    g = sns.scatterplot(data=X, x = x_ax_label, y = y_ax_label, 
                        hue="Species", style = "Species", s=60*scale
                       )
    
    # set the title
    if title:
        plt.title(title)
    
    # remove the legend title
    g.axes.get_legend().set_title(False)
    
    return g
    
fig_num+=1
fig = plt.figure(figsize=(width_inch*2, height_inch*2))
g = reduced_plot(iris_reduced, X_AX_LABEL, Y_AX_LABEL, 
             "Figure %d: "%(fig_num)+X_AX_LABEL+" and "+Y_AX_LABEL+" of \n"+flowers[0]+" and "+flowers[1]+" flowers",
                scale=2)
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%%2B8KEBGpMmTIEHh7e%2BfIvoYOHYrff/9dtMzZ2Vl4PH78eEyYMCFHjkW5a9asWdi/fz8AoEePHli8eHG%2B1MPLywtDhw7Ven1dXV0YGhrC1NQU9vb2qFy5MurVq4dWrVrB0NAwF2uqWVRUFNasWQMrKyuMHTs2T4995MgRzJw5UyhfvnwZxYoVKzD7%2B15ocw7MmDEDR48eBQA4OjrCzc0tL6uoVkxMDLp164YPHz6gU6dOWLlyZX5XKdctWbIE27Ztg4WFBY4dO4aiRYvmd5W%2BSrnRZmTm94tEIoGenh6MjY1RuHBhlCxZErVq1UKLFi1Qrly5bNUjJ3h4eGDevHk4f/58nh%2B7ZcuWCAgIAJC//%2B%2BzI7deg/w5VrduXezatSvDddm%2Bf32%2BhfZdKpVi7969OH/%2BPF6%2BfIno6GgYGBjAwsIClSpVwoYNG/K7ikRaY6YpERF9FS5duiQETL82KSkpiIuLw6dPn/DgwQP8999/mDx5Mlq1aoWDBw/mW72OHDmC9u3bY9euXUhJScm3elD%2B%2BRbOgT///BMfPnyAsbExpk%2Bfnt/VyRPjxo2DnZ0dIiMjMXXq1K/2s/veyWQySKVSREZG4s2bN7h69SpWrFiBLl26YOzYsQgODs6XegUGBmLChAkYOXIk3rx5ky91oOxj%2B/51%2Btrb97i4OAwZMgQLFy7EnTt3EBERgZSUFMTHxyMoKAgxMTH5XUWiTGGmKRF9FZycnLK8rZWVVQ7WhPJDcHCwUrZwQWJhYQELC4sMn09JSUFSUhIiIyNFXeQ%2Bf/6MP/74A69evcqXiwH5DCv6Pn3t58CxY8dw5swZAMBPP/0Ee3v7fK5R3jA1NcWUKVMwffp03LlzBxs3bszzTHHSjqbfL8nJyYiNjUVkZKSwTCaT4fLly/D398e///6LMmXK5HY1RQ4dOoQLFy7k6TEp57F9/zp97e37%2BvXr4evrK1pmbGwMS0tLREZGonLlyvlUM6KsYdCUiL4KFy9ezO8qUD6RyWT49ddfERERkd9VydCQIUO0GuJBJpPh6dOn2LJlC06ePCks37ZtG6pXr4527drlZjWJvilhYWFYtGgRAKBo0aL44Ycf8rlGeatbt27YvXs3Hjx4gA0bNqBjx44oWbJkfleLFGj7%2ByUmJgZnzpyBq6srAgMDAaTdMJw6dSoOHDgAfX393KwmUYHC9v3rbd/l2zwjIyP8888/aNCgQT7WiCh72D2fiL5LT58%2BFf44nmnBtnnzZnh6euZ3NXKERCJBhQoVsHz5cowfP1703OLFiyGTyfKpZkRfn2XLlgk3UyZNmpTv4wPnNYlEgmnTpgFIm%2BRl9uzZ%2BVwjyg5TU1P07dsXe/bsEY1h%2BOjRIxw/fjwfa0ZZ5ebmJvzW/BrHZM1PbN%2B/3vZdfliRdu3aMWBKXz0GTYmIqMB68OAB1qxZAwAwNDSEsbFxPtco54wbNw5ly5YVyh8/fvxmgsNEue3p06fCxCVOTk7o0qVLPtcof9SrVw916tQBAHh6esLd3T2fa0TZ5ejoiKlTp4qWpZ/rRN8Dtu9pvtb2PSEhQXj8NU5iRaSIQVMiIiqQ4uLiMHXqVEilUgDAtGnTULhw4XyuVc7R0dFBz549Rcv8/PzyqTZEX5dVq1YJmdn9%2B/eHrq5uPtco/wwcOFB4vHr1amasfwM6dOgAU1NToezn58fPlb4bbN%2B/%2BNrb9%2B/5s6NvB8c0JaLvkrOzs/B4/PjxGrvof/z4EQcPHsTNmzfx6tUrxMfHw8rKCuXKlUPHjh3RtWtX6OvrY%2BvWrVi6dCkAoG7duti1a5doPx8%2BfECrVq2E8qJFi5QCZ6q0bNkSAQEBAIAePXqo7OYlv87mzZvRtGlT%2BPv7Y9WqVfD19YWRkRGcnJzQunVr9OzZU%2BUEWfHx8Th16hSuXbuGx48fIzQ0FKmpqbC2tka5cuXQuHFjdO/eHWZmZhrrnF3z5s0TZu1t2rQphgwZgn///TfT%2B5H/rIG0DIaCQnF8qqCgII3b%2BPv74%2BzZs/D09ERQUBAiIyNhamoKe3t71KlTB%2B3bt0ft2rUz3H7GjBkqs5bWrVuHdevWCWV179PNmzdx8%2BZN3LlzB0FBQYiIiIBUKoWZmRkKFy4MFxcXNGzYEO3bt4eBgYHG15SfpFIpzp8/j6tXr%2BLBgwcIDQ1FYmIirKysUKpUKTRq1Ajdu3eHra2t2v0ofrf9/PxgaGiIyMhInDp1CufPn8e7d%2B8QGhoKExMTODo6omnTpujZsyeKFy%2BudX1jY2Nx7NgxuLm54cmTJ8Lnn/7d7t27N6ysrPDgwQP07t1b2E7%%2BPy5cv4/bt23jx4gUiIiIQExODQoUKwdzcHKVKlULdunXRtWtXFClSRO2%2BVP2vSklJwYULF3D27Fk8fvwYnz9/hq6uLuzt7VGvXj106dIFNWvW1Lq%2BqampuHz5Mk6dOoUHDx7g8%2BfPMDIygqOjI1q3bo1%2B/fpp/E7nJx0dHTg5OeHRo0cA0rrnhoeHq53YMrv/vxXbMHna/mYKCQnB%2BfPncefOHTx%2B/BgRERGIjo6GgYEBzM3NUbx4cdStWxcdO3bMk8mtgoOD0axZMyHQNHbsWEyaNEntNu3atRN%2Be%2Bjr6%2BP27dsoVKhQhusfO3ZMmMhRT08Pt27dgrm5OQDtfrvJCwsLw%2BHDh%2BHu7o7nz58jNjYWVlZWKF%2B%2BPLp3744OHTpobE/ZvrN9zyzF30EhISHC76BixYqhYcOG6NSpE0qVKqVye3Vth%2BJ5p801F1FBw6ApEZEaMpkM//zzD1xdXUWzngNpP8aDg4Ph4eGB7du3Y9myZflUS9V8fX0xbNgwJCYmAkgLtoSGhsLX1xfNmjVTuvg6fPgwVq1ahc%2BfPyvtKyAgAAEBAbh69SrWrl2LiRMnYvDgwblW97Nnz%2BLIkSMAACsrK2EygG%2BNRCIRldVN9BEcHIy5c%2Bfi0qVLSs%2BFh4cjPDwcT548wa5du9CoUSPMnTsXxYoVy9H63rp1C4sXL8aTJ09UPh8WFoawsDC8fPkSR48exYoVK7B48eICO57VlStXsHDhQrx7907puaCgIAQFBeHWrVtYv349fvjhB4wfPz5TF4hubm6YNWuW0ncqPQDi7%2B%2BPLVu2YMyYMRg3bpzG/V2%2BfBmzZ89W2l/653///n1s3boVc%2BbMyfHPXlFMTAz%2B/PNPYWZjeW/evMGbN29w7tw51KhRAytWrICjo2OOHXv37t3CY1VtWUbu3buHWbNmqQwWpL%2BHvr6%2B2LJlC4YPH47//e9/0NPT/FP55s2bmDFjhmgcNwAIDAxEYGAgvL2 ...

# %%
# Altered https://github.com/ageron/handson-ml2/blob/master/05_support_vector_machines.ipynb
from sklearn.svm import SVC
x0 = np.linspace(0, 5.5, 200)
pred_2 = x0 - 1.8
pred_3 = 0.1 * x0 + 0.5

X = iris_reduced[[X_AX_LABEL, Y_AX_LABEL]].values
y = le.transform(iris_reduced[["Species"]].values.ravel())

# SVM Classifier model
svm_clf = SVC(kernel="linear", C=float("inf"))
svm_clf.fit(X, y)
w = svm_clf.coef_[0]
b = svm_clf.intercept_[0]

# At the decision boundary, w0*x0 + w1*x1 + b = 0
# => x1 = -w0/w1 * x0 - b/w1
x0 = np.linspace(0, 5.5, 200)
pred_1 = -w[0]/w[1] * x0 - b/w[1]

def example_lines(X, x_ax_label, y_ax_label, title, pred_lines, axes_limit = [0, 5.5, 0, 2]):
    reduced_plot(X, x_ax_label, y_ax_label, title, scale=2)
    
    line_styles=["g-", "m-", "r-"]
    for i, pred_line in enumerate(pred_lines):
        plt.plot(x0, pred_line, line_styles[i], linewidth=2)
        
    plt.axis(axes_limit)

fig_num+=1
fig = plt.figure(figsize=(width_inch*2, height_inch*2))
example_lines(iris_reduced, X_AX_LABEL, Y_AX_LABEL, 
              "Figure %d: Potential Decision Boundaries"%(fig_num),
              [pred_1, pred_2, pred_3])

plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%%2B/ULv98EHH2DatGnFEFHunj59ih49epi8vUwmg4WFBezs7ODh4YH69evD19cXPXv2hL29fTFGWjCtVos///wT/v7%2BWLVqlVljKQ5RUVFYsmQJOnbsiKFDh%2Ba6jeH9xtfXF1u2bCmx%2BD777DPs2rULAODt7Y0TJ0688DEN72/5yXpd2traws3NDdWrV0eHDh3Qq1cvuLi4vHAcpc3OnTsxa9YsoX38%2BHFUqVKlWM%2B5YsUKrFy5UmjfvXu3WM9XGhm%2Bxgsik8lgZWUFd3d31KxZE23btsWAAQPg7u5ezFHShQsXMGbMGKG9efNmtG3b1owRFYzXFxGVR%2BxpSkREREbS09MRGhpq7jCKhVarRUZGBmJiYnDr1i3s3LkTn332Gbp3745169ZBr9ebJa7Lly9j2LBhmD9/PpKSkswSQ3HRarXYuHEj%2BvXrh3379pntOS7Nsl6XsbGxuHv3Lg4fPoy5c%2BeiU6dO%2BOyzzxAfH2/uEKmC0Wq1SE1NxaNHj3DixAksXLgQvXv3xi%2B//AKNRmPu8IiIiIode5oSEVGh%2Bfj4FHnf8thjqjy6c%2BcOtFqt0K5SpQqkUtN%2Ba3V2di6usExia2sLV1fXPP%2Bu0%2BmgUqmQnJyM9PR0YX1SUhKWLl2KmzdvYtmyZSY/3pdl2bJluHPnTomes6RERERg8eLF5g7D7CwtLVGpUqVc/6bRaJCRkYHExETRtafRaLBr1y6cOnUKP/zwA/z8/EoqXKoAvL29IZPJjNZrtVqoVCokJiaKptNIS0vDd999h7t37%2BK7774ryVCJiIhKHJOmRERUaEePHjV3CFTMbt26JSzb2dnh2LFjkEgkZozIdL1798aiRYtM2vbx48fYsmULfv/9d%2Bh0OgDAoUOH0KxZM4wbN644w6QKqFmzZgVON6DVavH48WOcP38ev/32G8LCwgAAcXFxeO%2B997Bu3TomTuml2bx5c77TIuj1ekRERODIkSNYs2YNEhISAAB79%2B5FnTp18N5775VQpERERCWPSVMiIjI7zntV%2Bty8eVNYbtCgQZlJmBZWtWrVMGfOHDRo0ACff/65sP6nn37CiBEjYGdnZ8boKqaSnMO0NJLJZKhZsyZq1qyJESNG4KuvvsI///wDILOA1tSpU7Fnzx54enqaOdIXM2zYMAwbNqxEz/nRRx9xzuxCkkgkqFy5MsaOHQs/Pz%2BMHDkSaWlpAIA1a9bgtddeg6Ojo5mjpNKA1xcRlUec05SIiIiMGPY0bdiwoRkjKRmvvvoqOnbsKLTT09Nx6NAhM0ZEBCgUCnzzzTcYPHiwsC4hIQHffvutGaOiiqpevXoYOXKk0E5LS8OxY8fMGBEREVHxYtKUiIiIRFQqFe7fvy%2B0GzVqZMZoSs7//vc/UTs4ONhMkRBlk0gkmDdvnmgI9eHDh8vt/LdUunXr1k3Uvn37tpkiISIiKn4cnk9ERGZXr149YXnSpEkFDu969uwZtm/fjvPnz%2BPhw4dIT0%2BHi4sL6tSpg/79%2B2Pw4MGwsLDAhg0bsGTJEgCAr6%2Bv0bDfp0%2BfokePHkJ74cKFJg0X7d69O8LDwwEAQ4cOzXX%2BTMNt1q9fj86dO%2BPGjRtYtmwZrly5AisrK/j4%2BKBnz54YNmxYrgWy0tPTsW/fPpw%2BfRq3b99GbGwsdDodXF1dUadOHXTs2BGvvPIK7O3tC4y5MEJCQqBWq4X2y0yaGj4vAHD8%2BPF859MrSdWrVxe1IyMjC9zn1q1b%2BPfffxEUFITw8HAkJSXB1tYW7u7uaNmyJbp164auXbvmOb3Bzp07MWvWLKP1gYGBouti8%2BbNaNu2ba7HUKvVOHz4MP777z9cv34dsbGxUCqVcHFxQY0aNdChQwe88sorcHd3z/ex5LwegoODYWlpicTEROzbtw%2BHDx/GkydPEBsbC1tbW3h7e6Nz584YNmwYqlatmusxR48ejcDAQKP1s2bNEh63t7c3Tpw4kes%2BuV23OSmVShw9ehSBgYEIDg5GbGwsEhMTIZFIYG9vDw8PD7Rq1Qrdu3cvs3OB2tjYYMKECaIpJP7880/MmzevwH0TEhKwd%2B9enDlzBg8ePEBsbCykUilcXV3RsGFDdO7cGYMGDYKlpWWhYkpOTsbevXtx%2BvRp3LlzB3FxcZBKpXB2dkaDBg3QvXt3DBw4ENbW1rnun/O1n9%2B9QKfT4cyZMzh8%2BDCCg4MREREBpVIJBwcHuLi4oFmzZujQoQN69%2B4NuTzvrzcrVqzAypUrhbYpU8NERUVh165duHDhAu7fv4%2BEhARYWFjA1dUVDRo0QKdOnfJ9nFkuXLiAMWPGAADc3Nxw7tw5AMDz58%2BxZ88eHD9%2BHOHh4YiPj4ejoyOqVauGrl274tVXX823sF1JyxmLXq83ab%2Bc96mYmBjhPlWlShW0b98eAwYMQI0aNQo8VmE/MwCm3VcMt/nqq6/w%2BuuvAwBOnTqF/fv349q1a4iOjoZer4e7uztatWqFfv36oXPnziY9B1n8/f2xe/duXLlyBVFRUZDJZKhcuTI6d%2B6MkSNHFrnYZlhYGI4fP46LFy8Kr9WUlBRYW1vDwcEBNWrUgK%2BvLwYPHgwvL698j1WUzzBFub6K4/508eJFHDhwAFevXsXTp0%2BRlpYGOzs7ODs7o3Hjxmjfvj369etX4DVLRAQwaUpERGWIXq/H2rVrsXr1alE1XyDzi21UVBTOnj2L3377rdRV9b1y5QreeustKJVKAEBqaipiY2Nx5coVdOnSxShp%2Bs8//2DZsmWIjo42OlZ4eDjCw8Px33//YcWKFZg8eTLefPPNlxar4dB8a2tr1KxZ86UduzTLmdi0sLDIc9tnz55h7ty5OHPmjNHfEhISkJCQgHv37mHbtm1o0KAB5s6di5YtW770mE%2BePIlvv/0WT548MfpbZGQkIiMj4e/vj1WrVuHtt9/GpEmTcq2UnZcTJ05g7ty5Rq9DlUqF%2BPh43LhxA7/88gs%2B%2BOADTJw48YUfT2H9/vvvWLNmTa7XCQBkZGQgOjoaN2/exObNm9G8eXMsW7YMlStXLuFIX9ygQYOwYMECYT7Jo0eP4quvvsozIa/X6/HLL79g7dq1SElJMfp7WloawsLCcPjwYfz000/47LPP0L9//wLj0Gq1%2BPXXX7F69WqkpqYa/T0iIgIRERE4ceIEVq5ciQULFqBTp06FfLTZQkNDMXXq1Fx71sbGxiI2Nhb37t3Djh07ULVqVcydO7fQSazcpKenY%2BnSpfjrr79EPyIBma//1NRUPHnyBIcPH8aPP/6IadOm4dVXXy3UObZv345FixYZ/fvExMQgJiYGly5dwtq1azFr1iyjnvDmEhMTI2qbkuA7evQo5s%2Bfj6ioKKO/Zb13X7p0CatXr8aQIUMwe/bsUjGfdFRUFD7//HOcPXvW6G%2BPHz/G48ePsXPnTvj6%2BmL58uUFJrcjIiIwc%2BZMXLhwwehv9%2B7dw71797B161ZMnz4dDRo0MDnO%2BPh4fPvtt9i/fz%2B0Wq3R35OTk5GcnIzw8HCcPXsWK1aswFtvvYWPP/4YUqlp ...

# %% [markdown]
# __Notes__
#
# - We could use any one of the decision boundries above to separate the flower classes, but which one if the "best"?

# %%
# Altered https://github.com/ageron/handson-ml2/blob/master/05_support_vector_machines.ipynb
def svc_decision_boundary(clf, xmin=0, xmax=5.5, highlight=True, axes_limit = [0, 5.5, 0, 2], scale=1):
    w = clf.coef_[0]
    b = clf.intercept_[0]

    # At the decision boundary, w0*x0 + w1*x1 + b = 0
    # => x1 = -w0/w1 * x0 - b/w1
    x0 = np.linspace(xmin, xmax, 200)
    decision_boundary = -w[0]/w[1] * x0 - b/w[1]

    margin = 1/w[1]
    gutter_up = decision_boundary + margin
    gutter_down = decision_boundary - margin

    svs = clf.support_vectors_
    if highlight:
        g = sns.scatterplot(x = svs[:, 0], y = svs[:, 1], s=180*scale, facecolors='#FFAAAA')
    plt.plot(x0, decision_boundary, "g-", linewidth=2)
    plt.plot(x0, gutter_up, "r--", linewidth=2)
    plt.plot(x0, gutter_down, "r--", linewidth=2)
    
    plt.axis(axes_limit)

# SVM Classifier model
svm_clf = SVC(kernel="linear", 
              C=float("inf") # Inf is for demo purposes (dont use in practice!)
             )
svm_clf.fit(X, y)

fig_num+=1
fig = plt.figure(figsize=(width_inch*2, height_inch*2))
svc_decision_boundary(svm_clf, scale=2)
reduced_plot(iris_reduced, X_AX_LABEL, Y_AX_LABEL, 
             "Figure %d: Support Vector Hyperplane and Margin"%(fig_num), scale=2)
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2Bf6IO9nJpmzazpLcv%2Bvyct7N7OzD9rn3LYIoiiKIiIiIiIiIiIiICACgUroAIiIiIiIiIiIiInfC0JSIiIiIiIiIiIjIDkNTIiIiIiIiIiIiIjsMTYmIiIiIiIiIiIjsMDQlIiIiIiIiIiIissPQlIiIiIiIiIiIiMgOQ1MiIiIiIiIiIiIiOwxNiYiIiIiIiIiIiOwwNCUiIiIiIiIiIiKyw9CUiIiIiIiIiIiIyA5DUyIiIiI3lJ%2Bfr3QJNR7vYyIiIiIqiUbpAoiIXGXSpEmIiYmpkmNNnjwZr776quyy1q1bS9vPPvss/vOf/1TJbVHVyMrKwq%2B//opdu3bhwoULSE5OhtVqRWBgINq1a4ehQ4fi3nvvhaenp9KlSlJTU7Fv3z7s27cP58%2BfR0pKCtLT0%2BHl5YWgoCAEBwejW7du6NevH7p37w6dTqd0yVQFjEYjVqxYgaSkJLz55psVPs7MmTOxadMmqf3CCy/giSeeqHR9Tz31FHbt2iW1N2/ejFatWlX6uK6UkZGBTz/9FEFBQXj66aeVLqfK3bhxA0OHDpXaY8eOxYIFCyp0rI0bN2LWrFlS%2B5133sG4ceMqXSNVL/vvPL169cLq1asVrohuN0OGDEFcXByAyr2H2BR9L7F5/vnn8eSTT1b4uJs2bcLMmTNllzVq1Ag7d%2B6s8DFvdy%2B//DJ%2B%2BuknAED9%2BvVln9lEVD7saUpERDXezz//jLvvvhuzZ8/Grl27cO3aNeTk5CAvLw8JCQn4448/8Morr%2BCee%%2BPj4ID8/HwaDQTa0ODk5GQsWLMBvv/2Gzz77DAEBAS6smqrKW2%2B9JfXsqawePXqgefPmuHjxIgDg3Llz%2BPvvv9GuXbsKH/OXX36RBfP3339/pet0teJ6OhERkTL%2B/vtvXL58GU2bNi33dVNSUnDgwIFqqIqIqABDUyKqtWrzsJ3a4ssvv5QFpuHh4Xj22WcxYsQIaRj%2BlStX8MUXX2DDhg0AAJPJhJkzZ2LLli2oU6eOS%2BtNTk52CEyHDRuG8ePHo1u3bvD19ZUut1qtuHjxInbs2IFvvvkGGRkZAIAjR47gqaeewqpVq6DVal1aP7mfiRMn4p133pHamzZtqlRounHjRmlbr9fjnnvuqVR9RERE27ZtwzPPPFPu6/36668cYUNE1YrD84mIqsjZs2el/zifqfKuXr2KDz/8UGq3bdsW33//PcaPHy%2Bbt7RJkyaYN28eZsyYIV2WkZGBVatWubReAPjwww%2BlwFQQBLz77rv49NNPMXDgQFlgCgAqlQotW7bEs88%2Biy1btqBly5bS344cOcL56wgAMHr0aNlct1u3bq3wkPQTJ07g/PnzsmO70xzARER0%2B6hfv760XdEh%2Blu2bJG2PTw8Kl1TTbFgwQLpnITzmRJVDkNTIiKqkRYtWgSTyQSgoEfcihUrEBYWVuL%2BTz75JJo0aSK1t2/fXt0lymRmZsrm5brvvvswZswYp65bp04dLFmyRHbC8PXXX8NqtVZ1mXSbCQwMxF133SW1k5OTERkZWaFj/fjjj7L27Tg0n4iI3IP9SIXz58/j3Llz5br%2BjRs3cPToUQBAaGgoOnToUKX1EREBDE2JiKgGSktLk4WeM2bMQGhoaKnXUalUePzxxzF06FCMGzcOd911lxS6usLx48dlc5T%2B61//Ktf1GzdujOHDh0vtxMREaS5Lqt2KLgi1adOmch/DaDRi27ZtUrtr166y3s1ERETl0b9/f/j7%2B0tt%2B88YZ9j3Mh0%%2BZNTtr9%2B7dUuDp7%2B%2BP8ePHO3W9CRMmOARMxbG/XwDgjz/%2BQIMGDSpW7D/sF6SqqH79%2BuGnn34CUBAC37x50yHYctXzZcmSJbjzzjuRnZ2NjRs3YuvWrbh%2B/ToMBgP0ej1at26NO%2B%2B8E2PGjIGPj0%2Bpt/3yyy9L/67Jkyfj1VdfhSiK2LFjB3766SecPXsWycnJ8PLyQpMmTdC/f39MmDAB9erVK/PfZS83NxebN29GZGQk/vrrL6SmpsJisSAoKAhNmzZF3759MWrUKKfmurV/P9i2bRuaN2%2BOqKgofPrppzhz5gx8fX3RrFkzDBs2DDdu3MCXX37pcIyffvpJ%2BncDFX%2Be9enTB02aNMGVK1cAALt27UJWVpbDlA%2Bl%2Be2336R5cwHggQceKHX/U6dO4ddff8WBAwdw8%2BZNGAwG%%2B7d0utr0qRJiImJAVCweNeUKVOQn5%2BPzZs345dffsGlS5eQlpYGHx8ftGjRAoMGDcL48ePLvVBjVX1GVfRxra73zfKyWCzYvXs3Dh48iKNHjyIpKQkGgwEWiwV6vR5BQUHo2rUrBg4ciCFDhkClKrnvzcaNG6UF1zp37ozvv/8eAHDt2jVs2rQJe/bsQUJCAjIyMhAYGIjmzZtjyJAhGDduXLnel4CC%2B33nzp2IiYnBrVu3kJWVBX9/f4SHh6NPnz4YMWIE2rRpU/E7pgy34/1m%2B/65f/9%2BXLp0CXl5eQgLC0P79u1x33334Y477qjUfeIsrVaLu%2B66S5pT/tdff8Vzzz3n9PW3bt0qbY8cORKnT58udw3Hjh3D3r17ERsbi7i4OBgMBuTm5sLX1xcBAQFo164d%2BvTpg5EjR8Lb27vE4xT9bnXixAl4eHhg27Zt%2BPzzz3H58mUEBgaiVatWuOeeezBy5EhoNPIoJj8/H9u2bcP27dvx999/IzU1Fd7e3qhXrx7uuOMOTJgwAfXr10dqaioiIiKk6xX33cD%2BM69%2B/frFDtG3f49944038OCDDwIA9uzZg61bt%2BL48eNISkqCKIoIDQ1F9%2B7dcc8992DgwIHlvJeJbm8MTYmIXEwURSxbtgxLly6V9SwECk7KExMTERkZia%2B//hrvv/%2B%2BQlUW7%2BjRo/i///s/GI1GAEB2djZSUlJw9OhRDBo0yOFk9ccff8RHH31U7ErwcXFxiIuLw59//olFixbhv//9Lx555JEqqfPgwYPSdp8%2BfWRzOrqrolMHbNu2rdwnLkOHDsX27dsREBAAf3//Uk/OXOHs2bP473//K4V1NikpKYiKi ...

# %% [markdown]
# __Notes__
#
# - The middle thick line is a <span style="color:green">hyperplane</span> and the dashed outer lines are the edges of the <span style="color:red">margin</span>.
# - The circled points are the class examples that fall on the margin. These will later be termed _support vectors_.

# %% [markdown]
# # 2. What is a Hyperplane? <a id='hyperplane'></a>
# In $p$-dimensional space, a hyperplane is a flat affine subspace of dimension $p-1$.
#
# - *Two-dimensions*: A flat one-dimensional line
# - *Three-dimensions*: A two-dimensional subspace
# - *p-dimensions*: A $p-1$ dimensional subspace

# %% [markdown]
# __Notes__
#
# - "Affine" just means _"does not need to pass through the origin"_
#
# - *Two-dimensions*: Figures 5 & 6
# - *Three-dimensions*: Figure 7
# - *p-dimensions*: ...you'll have to use your imagination
#
# - If you want to interact with the 3D plot use `%matplotlib notebook`

# %%
# Three Dimension
def three_dim(title):
    sns.set(font_scale=0.8)
    with sns.axes_style("white"):
        
        X = iris.data.values[:, :3]  # we only take the first three features.
        Y = iris.target

        # make it binary classification problem
        X = X[np.logical_or(Y==0,Y==1)]
        Y = Y[np.logical_or(Y==0,Y==1)]
        
        ax = fig.add_subplot(111, projection = '3d')

        # SVM
        model = SVC(kernel='linear')
        clf = model.fit(X, Y)

        # The equation of the separating plane is given by all x so that np.dot(svc.coef_[0], x) + b = 0.
        # Solve for w3 (z)
        z = lambda x,y: (-clf.intercept_[0]-clf.coef_[0][0]*x -clf.coef_[0][1]*y) / clf.coef_[0][2]

        xm, xM = X[:,0].min(), X[:, 0].max()
        ym, yM = X[:,1].min(), X[:, 1].max()

        number_of_squares = 10
        x = np.linspace(xm, xM, number_of_squares)
        y = np.linspace(ym, yM, number_of_squares)
        x, y =np.meshgrid(x, y)
        ax.plot_surface(x, y, z(x,y), alpha=0.5)

        x = X[:, 0]
        y = X[:, 1]
        z = X[:, 2]

        ax.set_xlabel(iris_df.columns[0], fontsize=7)
        ax.set_ylabel(iris_df.columns[1], fontsize=7)
        ax.set_zlabel(iris_df.columns[2], fontsize=7)

        ax.scatter(x, y, z, c=Y, cmap="PuOr")

        ax.view_init(elev=23., azim=168.)

        plt.suptitle(title, fontsize=7, y=0.85)

fig_num+=1
fig = plt.figure(figsize=(width_inch, height_inch))
three_dim("Figure %d: Support Vector Hyperplane in Three Dimensions"%(fig_num))
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%...%2BwNDQ0PmZdBX279/P5z//%2BRmvf/Ob3%2BR//I//MeP1hx9%2BmD//8z%2Bft/3MhU9%2B8pP88Ic/LHvt%2BPHj7Nix46zGPRseeeQR/vqv//qc7mOu5/hPf/rT4rm5adMmrr/%2B%2BuL/o9EoK1asIBaLncMZF/jmN7/JFVdcUdz3zTffzKc%2B9SnC4TAABw4c4GMf%2B9g5n0clLsR9Q%2BYcIzYQy5cvF6PR6IWeRkU%2B%2BtGPit/85jdn3e6WW24Rn3/%2B%2BeL/f/rTn4q33HLLuZzarPz85z8XP/ShD814fXJyUly/fr3o9/vLXr/vvvvEp59%2Bet72Mxc%2B8YlPiD/4wQ/KXjt27Ji4ffv2sxr3bJiP73UuefDBB2f8XufrWnrooYfEL33pS8X/53I58Qtf%2BIL4vve975zvW%2BbiQ3WhBbMexsbGuPfee3nllVeIxWL84z/%2BI4cOHcJut9PS0sLy5cv50Ic%2BxIoVK9izZw9Go5Hjx4/zF3/xFzz99NN885vfZM%2BePXg8Hq666ir%2B8i//ks9%2B9rMMDQ2RyWS46667eP/73191/8888wynTp3iK1/5ClB4anzooYf47ne/O2Nbt9tNIpEo/v%2Buu%2B7CbrcjiiK/%2BMUvePbZZ3nooYcA%2BPKXv4zBYOBDH/oQO3bsYMeOHezZs4dYLMaHP/xhbrnlFh555BEee%2BwxMpkMbreb/v5%2BvvSlL2E2mzl8%2BDCf%2B9zniEajaLVa/vZv/5atW7eWfd9169bx8ssvE41G%2BfznP88//MM/FOfW3t7OlVdeyWOPPcaDDz4IFKwZr9fLtddey9GjR/nCF75ANBpFoVDw4Q9/mG3btpHJZPjnf/5ndu3ahUKh4IYbbuDd7343Dz30UNl%2Bvv/97/Pf//3fKBQKli1bxj/90z9hs9nYsWMHa9eu5fjx4/zzP/8zmzZtqus8EEWRm266iS9%2B8YtccsklALz73e/mgx/8IL/%2B9a%2BBgoUbCAS45ZZb%2BOhHPwrA7373O7773e%2BSy%2BVwOBx8%2BtOfpre3l/e85z2YzWaGhob4q7/6K7761a9W/A1K2bt3L1/96ldJJpP4fD7uvPNO/uZv/oZXXnmFb3zjG7S3t3PixAlUKhVf/epX6e/vZ3x8nM985jN4vV5yuRzvfe97ueuuu6qe49/85jeZmJjA6XQyPj7OkiVL%2BPrXv45Op6vrOEl89atfZd%2B%2BfYTDYT71qU%2Bxc%2BfOOV0L//Vf/8XPfvYzRFGku7ub//W//hfNzc0196lQKPjYxz7GVVddxYkTJ/D7/Xz5y1/mkUce4ZOf/CR6vZ59%2B/bh8/n40z/9UyYnJ3nllVfIZrN861vfYtGiRVXPu1rH5X//7//N008/jVqtpru7my9/%2Bcv4fL7iMU2n03z2s59l7969CILAzp07%2BfCHP8z4%2BDjvf//72bp1KwcPHiSZTPLZz36WSy65hFdffZUvf/nLiKKIUqnkE5/4RPG8k7lAXFi9LGf58uXibbfdJt5xxx3iHXfcId5///2iKIri6OioeNlll4miKIr/8i//In7yk58U8/m86PF4xGuuuUZ86KGHip%2BXnipLn8ofeugh8c477xRzuZwoiqL4t3/7t%2BLPf/5zURRFMZlMiu9617vEZ599tuq8brvtNnHXrl11fYdf/OIX4qZNm8TrrrtO/PjHPy7%2B7Gc/E5PJpCiKM5/Uv/SlLxXnvn37dvFzn/ucKIqiODg4KF566aWix%2BMRf/7zn4tbtmwRR0ZGRFEUxb/7u78Tv/CFL4jpdFrcvn27%2BMILL4iiKIqHDx8Wr7jiCtHn8834vrUshGeffVa85557iv//whe%2BIH7rW98S0%2Bm0eOutt4onT54URbFgjW3btk30%2BXzif/zHf4jve9/7xFQqJaZSKfGd73ynuHfv3rL9vPDCC%2BItt9wihkIhURQLv9tHP/rR4nf9j//4j4rz%2BcQnPiFec801xXPgjjvuEG%2B66abib/md73xH/NSnPlU8Tjt37hTz%2Bbz4iU98Qnz7298uxuNxMRqNirfffrv45JNPigMDA%2BLdd98tRiIRURRF8ZlnnhHvu%2B8%2BURQLlol0zGf7DaTv9Td/8zfivn37RFEURZ/PJ65du1b0%2BXzi7t27xTVr1hSP1%2Bc%2B9znxH//xH0VRFMV3vetd4u7du0VRFMVQKCTedNNN4rFjx8q%2Bd%2Bk5/tBDD4k333yzGIvFxGw2K959993ir3/964rHS/oelSysH/3oR6IoiuJTTz1VtPLrvRZeeuml4m8siqL4wx/%2BUPzwhz88Y9/TLSyJe%2B%2B9V3zsscfE3bt3i3fffbcoioXf9sEHHxSz2ax49OhRcfny5cXr7u///u/Fr3/96zXPu2rHZWJiQty6dauYyWREURTFr371q%2BK%2BffvKjunXvvY18eMf/7iYy%2BXEZDIpPvjgg%2BLDDz8sjo6OisuXLxdffvllURTF4rktiqL4R3/0R%2BKTTz4piqIovvTSS%2BK3v/3tqr%2BBzPmh4Sysn/zkJxiNxqrvP//883z6059GEASam5u58cYb6xp348aNKBSK4hhHjhzh%2B9//PgDxeJxjx45x7bXXzvjc7t27UalUXHnllXXt56677uKmm27i1Vdf5dVXX%2BU73/kO3//%2B9/nZz34262ff/e53A7B48WLWrFnD66%2B/DsC1117LokWLALjnnnv49Kc/zdDQEEqlkquvvhqAVatWsXz5cvbt2zfj%2B9bimmuu4TOf%2BQwnT56kp6eHxx9/nEceeYShoSFGRkaKVgqAIAgMDAywe/du7rzzTjQaDQA/%2BtGPABgcHCxuu2vXLm699VYsFgsADz74IHfeeWfx/c2bN1ed0wc%2B8IGixQcUrWWAe%2B%2B9l5tvvpl4PM7Pf/5z7rvvPgRBKL6n1%2BsBuPnmm3nppZdwuVxMTEwUjy2A3%2B8nnU5XnEe130DiS1/6Es8%2B%2Byzf%2Bta3GBwcJJ/PFy3q3t5e%2Bvv7gcLv8dxzzxGLxdi7dy9f/OIXi2Ok02mOHj3K8uXLqx6DrVu3YjAYAFi2bBmhUKjqttWQrMPly5fj8/mKr9dzLQQCAY4fP87b3/52APL5PEqlsu59C4JQ0SLcsWMHSqWS7u5ugOJ11dPTg9PprHneQeXj0traSl9fH/fccw/XXXcdO3fuZMOGDYyNjRXH2LVrF5/61KdQKBRotVruu%2B8%2BnnrqKa688koMBgOXX345ACtXrixa6zfeeCP/8A//wFNPPcXVV1/N%2B973vrq/v8y5oeEEazaUSiWiKBb/P/2mLL2XyWTKXpduZFC4%2BP7v//2/xYvG7/eXvV/K7373O%2B6444665jY4OMijjz7KRz7yEa699lquvfZaPvzhD3PjjTeyZ88eBEEom/v0OapUp38OURSL/y%2B9UYhT7ol8Pj9j/6Ioks1mZ3zfWigUCt7%2B9rfzi1/8grVr17J582ZaW1vx%2B/00Nzfzq1/9qrity%2BWiqampbJ4Ak5OTxZtI6Vym/7/0%2B87VvSXhcDi44ooreOKJJ3j88cd5%2BOGHi%2B9VOk65XI7rrruOL33pSwDkcjm8Xm9RbKcfp2q/gcS73/1u1q5dy1VXXcVdd93Fs88%2BW/yuWq22uJ0koqIoIggCP//5z4tjeTwerFZrze9Zenymnzf1Iu1v%2BufruRa%2B/vWv8453vIMPfehDAKRSKaLRaF37TaVSDAwMsHTpUiYnJ8veU6vVNf%2Bfy%2BWqnne7d%2B%2BueFyUSiU//vGP2bt3Ly%2B99BIf%2B9jHeO9731v2AFrrfJTOhdIxofBb79ixg%2Beff55HH32U ...

# %% [markdown]
# In more detail$^1$:
#
# *Two-dimensions*: $\beta_0 + \beta_1\mathbf{x}_1 + \beta_2\mathbf{x}_2 = 0$
#
# *Three-dimensions*: $\beta_0 + \beta_1\mathbf{x}_1 + \beta_2\mathbf{x}_2 + \beta_3\mathbf{x}_3 = 0$
#
# *P-dimensions*: $\beta_0 + \beta_1\mathbf{x}_1 + \beta_2\mathbf{x}_2 + ... + \beta_p\mathbf{x}_p = 0$

# %% [markdown]
# <br />
#
# If $x = (\mathbf{x}_1, ..., \mathbf{x}_p)$ satisfies above, then it is a point on the hyperplane.

# %% [markdown]
# <br />
#
# If $\beta_0 + \beta_1\mathbf{x}_1 + \beta_2\mathbf{x}_2 + ... + \beta_p\mathbf{x}_p > 0$, it lies on one side of the hyperplane,
#
# so if, $\beta_0 + \beta_1\mathbf{x}_1 + \beta_2\mathbf{x}_2 + ... + \beta_p\mathbf{x}_p < 0$, its on the other side.

# %% [markdown]
# __Notes__
#
# - In-other-words, $p$-dimensional space is dividided into two halves.

# %% [markdown]
# ### Classifying data
# We aim to classify an $n \times p$ matrix of $n$ observations in $p$ dimensional space, with these observations falling into two classes $y_1,...,y_n \in \{-1,1\}$.
#
# If we were to perfectly separate the classes the hyperplane would have the property that$^1$:
#
# $\beta_0 + \beta_1\mathbf{x}_{i1} + \beta_2\mathbf{x}_{i2} + ... + \beta_p\mathbf{x}_{ip} > 0 \quad \text{if} \ y_i = 1$,
#
# $\beta_0 + \beta_1\mathbf{x}_{i1} + \beta_2\mathbf{x}_{i2} + ... + \beta_p\mathbf{x}_{ip} < 0 \quad \text{if} \ y_i = -1$.

# %% [markdown]
# <br />
#
# For a new test observations $x^*$, we would look at the sign of:
#
# $$f(x^*) = \beta_0 + \beta_1x_1^* + \beta_2x_2^* + ... + \beta_px_p^*.$$
#
# We would assign it to class 1 if $f(x^*)$ is positive and class -1 if negative.
#
# Furthermore, we could use the magnitude of $f(x^*)$ to indicate how far the point lies from the hyperplane.

# %% [markdown]
# # 3. Maximal Margin Classifier <a id='MMC'></a>
# We need a reasonable way of constucting a hyperplane, out of the possible choices.
#
# Maximal margin hyperplanes look at getting the hyperplane that is the furthest from the training observations - we compute the perpendicular distance from each training observation to a given separating hyperplane.
#
# The maximal margin hyperplane is the separating hyperplane for which the margin is largest.
#
# We hope the classifier with a large margin on the training data will generalise well to unseen test observations.

# %% [markdown]
# Another way of defining our hyperplane is:
#
# $$\mathbf{w} \cdot \mathbf{x} + b = 0,$$
#
# which uses the dot product between a weight vector, $\mathbf{w}$, and our input vector $\mathbf{x}$, plus our bias, $b$ (sometimes defined as $w_0$).
#
# In statistics the dot product of two n-dimensional vectors $\mathbf{a}$ and $\mathbf{b}$ is often noted as $\mathbf{a} \cdot \mathbf{b}$. The dot product is a type of _inner product_, often denoted as $\left<\mathbf{a},\mathbf{b}\right>$.

# %% [markdown]
# __Notes__
#
# - $\mathbf{a} \cdot \mathbf{b} = \sum\limits^n_{i=1}\mathbf{a}_i\mathbf{b}_i$

# %% [markdown]
# In Machine Learning, vectors are typically represented as _column vectors_, so the dot product is defined as $\mathbf{a}^{\mathrm T} \mathbf{b}$. Using this notation, our hyperplane is$^{10}$:
#
# $$\mathbf{w}^{\mathrm T}\mathbf{x} + b = 0.$$
#
# Our margins, where our labels $y \in \{-1,1\}$, are then:
#
# $$
# \mathbf{w}^{\mathrm T}\mathbf{x}_i + b \geq 1 \text{ if } y_i = 1, \\
# \mathbf{w}^{\mathrm T}\mathbf{x}_i + b \leq -1 \text{ if } y_i = -1, \\
# \text{for } i = 1,\ldots,n,
# $$
#
# which can be more compactly written as:
# $$
# y_i\left(\mathbf{w}^{\mathrm T}\mathbf{x}_i + b\right) \geq 1 \quad \forall_i
# $$

# %%
def plot_svc_margin(clf, xmin=0, xmax=5.5, highlight=False, highlight_line=False, 
                    margin_line=False, axes_limit= [0, 5.5, 0, 2], ax = None, scale=1):
    sns.set(font_scale = scale)
    w = clf.coef_[0]
    b = clf.intercept_[0]

    # At the decision boundary, w0*x0 + w1*x1 + b = 0
    # => x1 = -w0/w1 * x0 - b/w1
    x0 = np.linspace(xmin, xmax, 200)
    decision_boundary = -w[0]/w[1] * x0 - b/w[1]

    margin = 1/w[1]
    gutter_up = decision_boundary + margin
    gutter_down = decision_boundary - margin

    svs = clf.support_vectors_
    
    with sns.axes_style("dark"):
        if ax:
            plt.sca(ax)
        else:
            fig = plt.figure(figsize = (width_inch*scale, height_inch*scale))
        plt.fill_between(x0, gutter_down, facecolors='white')
        plt.fill_between(x0, gutter_up, xmax, facecolors='white')
        if highlight:
            g = sns.scatterplot(x = svs[:, 0], y = svs[:, 1], s=180*scale, facecolors='#FFAAAA')
        if margin:
            plt.plot(x0, decision_boundary, "g-", linewidth=2*scale, alpha=0.3)
        else:
            plt.plot(x0, decision_boundary, "g-", linewidth=2*scale)
        plt.plot(x0, gutter_up, "r--", linewidth=2*scale)
        plt.plot(x0, gutter_down, "r--", linewidth=2*scale)
        
        # I've been a bit lazy here and not drawn the lines properly
        
        if highlight_line or margin_line:
            plt.arrow(svs[0, 0],svs[0, 1], 0.7, 0.125, fc='k', ec='k', linewidth=1*scale, length_includes_head=True)
            plt.arrow(svs[1, 0],svs[1, 1], -0.7, -0.125, fc='k', ec='k', linewidth=1*scale, length_includes_head=True)
        
        if highlight_line:
            plt.text(svs[0, 0],svs[0, 1]+0.1, r'$ x_2 $')
            plt.text(svs[1, 0],svs[1, 1]+0.1, r'$ x_1 $')
        
        if margin_line:
            plt.arrow(2.1, 0.05, 1.4, 0.25, fc='y', ec='y', linewidth=1*scale, linestyle=':',length_includes_head=True)
            plt.text(2.55, 0.22, r'$ \frac{2}{||w||} $', fontsize=15*scale, rotation=20)
            plt.text(svs[0, 0]-0.04,svs[0, 1]+0.04, r'$ w^Tx_2 + b = -1 $', fontsize=8*scale, rotation=18)
            plt.text(svs[1, 0]-0.7,svs[1, 1]-0.08, r'$ w^Tx_1 + b = 1 $', fontsize=8*scale, rotation=18)
        
    plt.axis(axes_limit)
    
    if not ax:
        return fig

fig_num+=1
#plt.figure(figsize=(width_inch, height_inch))
fig = plot_svc_margin(svm_clf, scale=2)
reduced_plot(iris_reduced, X_AX_LABEL, Y_AX_LABEL, 
             "Figure %d: Support Vector Margin"%(fig_num), scale=2)
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2BCRNU/LOdwiiKIogIiIiIiIiIiIiIgCAJtwFEBEREREREREREVUnDE2JiIiIiIiIiIiIfDA0JSIiIiIiIiIiIvLB0JSIiIiIiIiIiIjIB0NTIiIiIiIiIiIiIh8MTYmIiIiIiIiIiIh8MDQlIiIiIiIiIiIi8sHQlIiIiIiIiIiIiMgHQ1MiIiIiIiIiIiIiHwxNiYiIiIiIiIiIiHwwNCUiIiIiqsGcTme4S6jx%2BBwTERHVPLpwF0BERHSpGTVqFDZv3lwp5xo9ejSee%2B452X0tW7aUbj/yyCN49NFHK%2BVadPFEUcTy5cvx559/YteuXcjJyYHD4UBcXByaNGmCLl264LbbbkPDhg3DXaqM2WzG2rVrsXbtWhw%2BfBi5ubmwWCyIjIxEYmIikpKS0LFjR/Ts2ROdOnWCwWAId8lUCRwOB7744gtkZ2fjlVdeueDzTJo0CQsWLJC2J06ciAceeOCi63v44YexYsUKaXvhwoVo0aLFRZ9XTfn5%2Bfjwww%2BRmJiIcePGhbucSjdv3jw888wzfvc/%2BeST%2BPe//33B512wYAEmTZoku69x48b466%2B/Lvicl7qnn34a8%2BfPBwA0aNBA9rtBREThwdCUiIiIKARHjhzBk08%2BiQMHDvi15ebmIjc3F9u2bcMXX3yBf/3rX3jiiSfCHj6azWZMnToVv/76K1wul1%2B7y%2BVCfn4%2BTpw4IdVep04d3H///Rg1ahR0Ov5X8VK1cuVKTJ48GWfOnMGwYcMu6ly33XabLDT97bffLjo0zcnJwZo1a6TtDh06XHKB6bx58/DOO%2B8gNzcXjzzySLjLUdXvv/9%2BUaHpwoULK7EaIiKiqsH/CRMREV2kxo0bX/CxiYmJlVgJVZW9e/di9OjRKCwslN0fHx%2BPqKgo5OTkSKGkx%2BPBV199hUOHDuHTTz8NW3B64MAB3H///cjOzvZrM5lMiI6OhtPphNVqlQ0tzsnJwZQpU/Dnn3/i008/hclkUrFqqiyvvfYa0tPTK%2BVcnTt3RrNmzXD06FEAwKFDh7Bv3z60adPmgs/522%2B/we12S9t33HHHRdepNqUemLXFvn37cPz4cTRt2rTCx%2Bbm5mLjxo1VUBUREVHlYmhKRER0kWrzcMLaoKioCOPHj5cFpjfffDPGjRuHK664AkDJfIYrVqzAW2%2B9hYyMDABAWloa3n33XTz99NOq15yTk%2BMXmA4aNAgjR45Ex44dERMTI93v9Xpx9OhRLF26FN9%2B%2By3y8/MBANu3b8fDDz%2BMmTNnQq/Xq/4YqHq5/fbb8eabb0rbCxYsuKjQdN68edLtuLg43HjjjRdVH6lvyZIlGD9%2BfIWP%2B/3332WBORERUXXFhaCIiIiqmYMHD0r/OJ9p%2BM2ePRvnzp2Tth988EG8%2B%2B67UmAKAAaDATfccAN%2B/vlnNGrUSLp/1qxZsmPV8u6770qBqSAIeOutt/Dhhx/i2muvlQWmAKDRaNC8eXM88sgjWLRoEZo3by61bd%2B%2BHbNmzVK1dqqehgwZIus1vXjxYng8ngs61%2B7du3H48GHZuSMiIi66Rqp6DRo0kG7//vvvF3SORYsWSbeNRuNF11RTTJkyRfrbz/lMiYiqB4amREREREEsW7ZMul2vXj089thjAfdNSkrCU089JW273W4sX768Susry2azyeYLHDFiBIYOHRrSsampqfjkk09kQcY333wDr9db2WXSJSYhIQHXX3%2B9tJ2Tk4O0tLQLOtcvv/wi274Uh%2BbXVr49gg8fPoxDhw5V6PgzZ85gx44dAIDk5GRceeWVlVofERFRZWJoSkRERBTEiRMnpNvt27cvd3Gknj17yrZPnjxZFWUFtGvXLtkcpdddd12Fjr/ssstw0003SduZmZnSXJZUu912222ybd/FoULlcDiwZMkSabtDhw6y3s1UvfXq1Qvx8fHStu/PMhS%2BvUxvuukmaLXaSquNiIiosnFOUyIiomqmZcuW0u1HHnmk3CH6GRkZmDt3LtavX49jx46huLgYiYmJaN68OW666SYMHjwYer0eM2bMwNtvvw0A6Nq1q9%2Bw6zNnzmDAgAHS9ptvvonhw4eXW2///v2lBWeGDRuGKVOmBN3niy%2B%2BwLXXXou9e/fivffew44dOxAREYHGjRtj4MCBGD58uOICWcXFxVi0aBHWrFmD/fv3Izc3F16vF0lJSWjevDl69eqFoUOHIjY2ttyaK8I3gLTb7RU%2BPlgvTd/nBQCWL1%2BOhg0bVvgaviwWy0UdD5QEv/PnzwdQMnz/3LlzfsGWWq%2BXTz75BAMHDkRhYSHmzZuHxYsX4/Tp07BarYiLi0PLli0xcOBADB06FNHR0UGv/fTTT0uPa/To0XjuuecgiiKWLl2K%2BfPn4%2BDBg8jJyUFkZCSaNGmCXr164bbbbkP9%2BvXLfVy%2BiouLsXDhQqSlpeHvv/%2BG2WyGx%2BNBYmIimjZtih49emDw4MFITU0t91y%2B7wdLlixBs2bNsH79enz44Yc4cOAAYmJicPnll2PQoEE4c%2BYMvvrqK79zzJ8/X3rcwIW/zrp164YmTZpIXySsWLECBQUFflM%2BBPPnn39K8%2BYCwJ133hl0/7179%2BL333/Hxo0bce7cOVitVsTExCA1NRVdunTBDTfcgM6dO1f4sRw4cAALFy7Eli1bcOLECRQWFiIyMhL16tVDhw4dMHjwYMXz%2Br6GfH388cf4%2BOOPpe2DBw8GvHZmZibmz5%2BPTZs24ciRI7BYLNDr9UhKSkLr1q3Ru3dv3HLLLYiMjAz6GDZt2oTRo0cDAOrUqYN169ZBFEV8//33mDVrFs6ePYs6deqgbdu2uPnmmzFo0KBQn56A9Ho9rr/%2BesydOxdAyRD9xx9/POTjFy9eLN2%%2By0REBDA0JSIiumSJoojp06dj2rRpsmAPKPlQnpmZibS0NHzzzTf43//%2BF6Yqle3YsQP/%2Bte/4HA4AACFhYXIzc3Fjh070KdPH7/Q9JdffsF7772nuBJ8eno60tPTsWrVKnz00Ud47LHHcO%2B991ZarY0bN5YCkG3btqGwsDBoOLdmzRrZtm/opYaUlBTZ9pIlS9C3b98KnWPAgAH4448/YDKZEB8fD40mvIOTDh48iMcee0zW6xcoWYV7/fr1WL9%2BPT799FO88sorshCkPBaLBU899ZTfz8zlcmH37t3YvXs3vvzySzz88MN46KGHQnoefvzxR7z33nuK4fXZs2dx9uxZrF%2B/Hh999BHuuecePPHEE7K5QsuzdOlSPP7441IYX1xcjOzsbGzbtg133313yOe5UCNHjsQ777wDoORLhN9//92vB2owvgtAxcfHB1wAKjMzE6%2B%2B%2BqpseoxSeXl5yMvLw4EDBzBr1iz07NkTr776akhBcLDz2mw22Gw2HDp0CHPmzEHfvn3x%2Buuvo06dOiE/vmCKi4sxdepU/Pjjj3C5XLI2p9OJwsJCnDp1CkuXLsUHH3yAJ554AiNGjKjQNd544w3MnDlT2j5z5gzOnDmD9PT0SglNgZKF8EpD0xMnTuDvv/9G27Ztyz3uwIED0nD%2BJk2a4KqrrqrQdfft24fXX38dW7duVWy3WCywWCw4ceI ...

# %% [markdown]
# There are two equidistant points from the maximal margin hyperplane, lying on the dashed lines. These observations are called *Support Vectors*.
#
# We can call these two points, $x_1$ and $x_2$ as below:
#
# $$\mathbf{w}^{\mathrm T}x_1 + b = 1,$$
#
# $$\mathbf{w}^{\mathrm T}x_2 + b = -1.$$

# %%
fig, ax = plt.subplots(figsize = (width_inch, height_inch))
plot_svc_margin(svm_clf, highlight=True, highlight_line=True, ax=ax)
fig_num+=1
reduced_plot(iris_reduced, X_AX_LABEL, Y_AX_LABEL, "Figure %d: Support Vectors"%(fig_num))
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='data:image/png;base64,...%2B32%2B107tyZ888/n5ycnNNea8%2BePSQnJzNs2DB/h6k5ePAgv/76a61dXxCEqtMHOgBBEIS6pGvXrnTt2rXcx1u2bAlAu3btePDBB7nwwgvPUGS1Q1EUHnzwQZYvX05SUhK33HIL2dnZfP7556xYsYKZM2cSHR1drWtv2bKFe%2B65B7fbTZ8%2BfbjiiiuwWCxs376dt99%2Bm2%2B//ZavvvqKxo0b%2B/lVnR1ee%2B01Pv30U%2BbPn19uG5PJxNVXX828efNYvHgxQ4YMKbftzz//DMDgwYP9HSoAu3fv5qabbuK2227j6quvrpXnEASh6kQyLwiCUAVdu3bloYceqrBdu3btaNeu3RmIqHbNnz%2Bf5cuXc9FFF/Hpp58SGhoKwMqVK/m///s/Xn31VaZOnVrl6yqKwtixYzGZTMybN4/mzZv7PP7%2B%2B%2B/z7rvv8tJLL/H%2B%2B%2B/75bWcbbKysirVbtCgQcybN49ffvml3GReVVV%2B%2BeUXgoODGTBggD/D1OTl5eF0Omvl2oIgVJ8YZiMIgiCU65dffgFg7NixWiIPcNlll9GzZ08WLFhAdnZ2la%2B7b98%2Bjh49Sp8%2BfUol8gCjRo0iPj6e5cuXN/gE8uKLL6ZZs2Zs3ryZjIyMMtts2bKFlJQUBgwYQEhIyBmOUBCEQBLJvCAIQi0ob8z8%2BvXrGTZsGBdffDHdu3fn%2BeefZ%2B/evSQnJzNt2jStXd%2B%2BfencuXOp627cuJHk5GQmT56sHRs2bBh9%2B/Zl5cqV9O3blwsuuIBHHnlEe3znzp2MGjWKbt260bFjR66//nq%2B/vprVFWt8HUcO3YMvV7P%2BeefX%2Bqx5ORk3G43f/31l0/cycnJHDt27LTXdblcgCepVxSl1OOSJPHaa6/x4Ycf%2BsSSnJzMqFGjSrWfNm2az5yF4lhuu%2B02du/ezbBhw7jgggvo3bs3L774Irm5uT7nDxs2jEsvvZTjx49z//33c9FFF9GjRw%2BefPJJUlJSSj1feno6zz//PJdddhnt27fnsssu4/nnnyc9Pd2n3dixY0lOTmbHjh0MHDiQDh06cOutt9KnTx9%2B/PFHwNPz3rdv39O%2BX9dffz2KovDbb7%2BV%2BXjxEJtBgwZpxwoLC3n99dfp378/7du3p3fv3kyYMKHMOwJWq5V3332Xq666igsuuIC%2BffsyceJE7YPatGnTGD58OAAzZ84kOTmZjRs3auevXbuWu%2B66i06dOtGxY0cGDx7MnDlzSn1tk5OTGTt2LNOnT6dz58507txZ%2BxlZs2YNd955J5dccgkdO3bk2muv5aOPPsLhcJz2vRGEhk4MsxEEQThDFi9ezJgxYwgJCWHAgAGYzWZ%2B%2BeUX1q1bV%2BNr5%2BTkMGbMGPr160doaCitWrUCPMNhHnzwQQwGA1deeSXR0dGsXr2aF154gX///ZeXXnrptNc1Go0oioLb7cZgMPg8VlBQAOCT7A4fPpyCggLCw8NPe93WrVsTGxvL33//zbBhwxg6dCi9evXyOa9bt25Veg/Kkp6ezvDhw0lKSmLo0KFs376dOXPmsGnTJubOnevTi22z2Rg%2BfDh6vZ5bb72V/fv3s2DBAjZu3Mi3335LfHw8AEeOHOG2224jMzOTHj16cPXVV7Nnzx7mzp3LsmXL%2BPrrr2natKlPHA888AAdOnSgZ8%2BeBAcHExUVxY8//sju3bsZMmQI55xzzmlfx6BBg3jvvfdYtGhRqQmuTqeT33//naSkJO09Kygo4Pbbb2fv3r1ccsklXHnllRw7dox58%2BaxevVqvvnmG%2BLi4gBPIn/bbbexa9cu7cPGkSNH%2BOqrr9iyZQtff/01Xbt2ZfDgwfz444/ah6KkpCQAZs2axaRJkwgLC%2BOKK64gODiY1atX8%2BKLL7JlyxbefPNNJEnS4l29ejV//PEHgwcPJjMzkwsuuIAtW7Zw//33ExUVxcCBAzGZTKxbt44333yTw4cP8/LLL1fzO0AQ6j%2BRzAuCIFTBpk2bfHrQvQ0ePJgmTZqU%2BZjFYmHixImEhoYyb948WrRoAcA999zjlwmLFouFu%2B66i7Fjx2rHrFYrY8eOJSwsjHnz5mmxPfHEE4wZM4Z58%2BbRv39/LrvssnKv2759e/bu3cuSJUu45pprtON2u137EFKc1AOMGDGiUvEaDAZee%2B01Ro0axZYtW9iyZQuyLNOuXTu6detGv379yrwzUVXHjh2jb9%2B%2BvPfee%2Bh0OgAmTZrErFmz%2BPzzz33mP%2BTl5dGsWTNmz56N2WwG4PPPP%2BeVV17hrbfe0uYGPPfcc2RmZjJp0iRuvvlm7fyvvvqKiRMn8uyzzzJjxgyfODp16lTq%2B2b37t3s3r2b2267rcL5FU2aNKFz585s2bKF1NRUn0nBq1atIjc3l6FDh2pJ85tvvsnevXt5/vnnGTp0qNZ26dKljBo1ismTJ/POO%2B8A8PHHH7Nr1y7uvPNOxo0bp13jo48%2B4s033%2BTbb7/lrrvuAtCS%2BeL37ejRo0ydOpXExERmzpypfYixWCw88MADLFq0iMsuu8znjkFmZiYffvihz92Ihx9%2BGKfTyVdffaVdw%2Bl0cvPNNzN//nzGjx/vM8xLEIQSYpiNIAhCFWzatIn33nuvzH/Hjx8v97w1a9aQmZnJ0KFDtUQeIDExUUuUaurKK6/02V%2B2bBnZ2dncfffdPh8yZFnm8ccfB%2BD7778/7TWLe6pffPFFFi5cSEFBAQcPHmTMmDFaqcTKDNcpyyWXXMLChQsZOnQojRo1QlEUdu7cyeeff87QoUO5/fbbT1u2sTIkSeKpp57SEnmARx55hODgYG1oirfHHntMS%2BQB7rzzTpKSkvj9999xOBycOHGCDRs20LlzZ59EHuD222%2BnQ4cObNiwodQwo1O/NtUxaNAgVFVl0aJFPsd//vlnJEnSPhS6XC7mz59P69atfRJ5gH79%2BtGpUyf%2B%2BOMPCgsLAc%2B8iNDQUB5//HGfHvQ77riDe%2B65h3PPPbfcmBYsWIDL5WL06NE%2BdyOCg4N59tlngdLfY2azudQHyOLhOH///bd2zGAw8Mknn7Bx40aRyAvCaYieeUEQhCp48MEHK1XN5lTFSUrHjh1LPdapU6caxwWUuivwzz//AJ4x82XdTdDpdOzevfu012zXrh2vvPIKzzzzjPYBAOC8887j0UcfZfLkyQQFBVU75qSkJJ5//nmee%2B45du3axYYNG1i9ejUbN25k69atjBgxgoULF1b7OWJjY7VyocXCwsJo2bIlO3fuxGq1ateWJKnU3QCdTsf555/P4sWLOXLkCEeOHAEo965Bp06d%2BPvvv9m9e7fP16O8OzZVcdVVVzFp0iQWLVrEyJEjAc%2B4%2BOXLl3PxxRdryfTBgwexWCy43e4yv%2B52ux23282ePXs477zzOHz4MF26dMFkMvm0CwkJ4cknnzxtTMXfP126dCn1WOvWrQkPDy/1Pda4cWOfD1cAN998M0uWLOHRRx/lnXfeoXfv3lx66aV0794do9FYwTsjCA2bSOYFQRDOgOJe7JiYmFKPFY9drinvHmUoGf5SXJGmLHl5eRVe95prrqFr164sX76cvLw82rRpQ%2B/evfnmm28AaNSoUQ2i9pAkifPOO4/zzjuPkSNHsn//fh544AEOHz7MokWLuPHGG6t13eJx7qcq/joUFBRoyXxUVFSZiaN32%2BLe7LCwsDKvW/y1tNlsPsdP/dpUR2hoKP369dMWmmratClLlizBZrP5DNUqXszrwIEDvPfee%2BVeLy8vT2tb3Z7vyrwfhw8f9jlW1ntx2WWXMXPmTD777DPWrVvHrFmzmDVrF ...

# %% [markdown]
# If we move our support vectors our hyperplane will too.
#
# This is because the maximal margin hyperplane only depends on these support vectors.
#
# Other data points could be moved without the hyperplane moving.

# %%
# get a list of support vector indexes
S_i = list(svm_clf.support_)

X = iris_reduced.drop(S_i)[[X_AX_LABEL, Y_AX_LABEL]].values
y = le.transform(iris_reduced.drop(S_i)[["Species"]].values.ravel())

svm_clf2 = SVC(kernel="linear", 
              C=float("inf") # Inf is for demo purposes (dont use in practice!)
             )
svm_clf2.fit(X, y)

fig, ax = plt.subplots(1,2, figsize = (width_inch*2, height_inch), sharey=True)
ax = ax.flatten()
plot_svc_margin(svm_clf, highlight=True, ax=ax[0], scale =1)
reduced_plot(iris_reduced, X_AX_LABEL, Y_AX_LABEL)
plot_svc_margin(svm_clf2, highlight=True, ax=ax[1], scale =1)
reduced_plot(iris_reduced.drop(S_i), X_AX_LABEL, Y_AX_LABEL, scale =1)
fig_num+=1
plt.suptitle('Figure %d: Changing the Maximal Margin'%(fig_num))
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2B7MrNkCvinr1it3LVRBRUUAURZSiVOlNaiC0kN6TbTOzM/P7Y7Ozu2STTSCbySbn8zw%%2B%2Beejd%2B/eGDlyJP7xj39g6dKlEEUx5ON8P%2BPMzMyIxdbU3nvvPfTo0aPePx81ZGVlBW2fPn1a%2BVk4HA6VogKeeeYZJY5hw4bV%2BrkJ9PnnnyuPmTRpUhNEGWzJkiXo0aMHbrjhhiZ/7nB87%2BesWbPqdbzvtfj%2BO3jwYNjH7N%2B/P%2BgxzRX920EIISSaadUOgBBCCIkG3bt3h8ViqfOY9u3bN1E0zR/P83jyySdht9vrdfz%2B/fvx73//O6Ixffvtt3jllVfAcRxYlkVqaio6dOiAnJwcbNiwARs2bMAXX3yBDz/8EGlpaRGNhdTtxIkTmD59Omw2G2bPnq12OHUqLy/H1q1bMWLEiDqPW7FiRRNF1Pr89ttv6NWrV53H0PtPCCGERB4lGQkhhJB6eP755zFs2LB6Hz9r1iy4XC4kJydHMKrmyeFw4LHHHsOWLVvqdfzevXtx3333wel0RiymN998E3PmzIFOp8M999yDu%2B66CwkJCcr%2BP/74A6%2B%2B%2Bir279%2BPyZMnY9GiRbBarRGLpzmYOHEirrrqqrDJczUsW7YMf/75J8aNG6d2KHXSarXweDxYuXJlnUnG/Px87Nmzpwkjq%2Bmyyy5D//79YTQaVY2jMQW%2B///85z/rPPa3335roqjOTWv%2Bt4MQQkj0o%2BXShBBCSASkp6cjIyMDNptN7VCa1L59%2B3DTTTfhjz/%2BCHusKIqYP38%2BJk6ciNLS0ojFtGHDBvzvf/%2BDRqPBW2%2B9hSeeeCIowQgAF154IebPn4/4%2BHicOHEC7733XsTiaS4SEhKQkZGB1NRUtUOJWkOHDgUArFq1CrIs13rcr7/%2BClmWw862iySr1YqMjAy0bdtWtRgaW7du3RAfH48jR47gxIkTtR536NAhnDhxQtX3v75a678dhBBCWgZKMhJCCCGkUXz00Ue46aabkJWVhf79%2B%2BPWW2%2Bt9ViO43DDDTfglVdegSAImDp1akSSH5IkYcaMGZBlGddffz2uuOKKWo9NTU3FvffeCwD47rvv4HK5Gj0e0rL07NkTHTp0QEFBQZ0zFVesWAGtVotLL720CaNr%2BViWxSWXXAKg7pmKv/zyCwDU%2BftPCCGEkHNHSUZCCCEkAuoq3v/nn3/i7rvvxsiRIzFw4EBMmDABq1evxpYtW2o0hQjX6CIzMzNkIwPf8%2B/cuRMzZszAoEGDMGjQIEyZMgWSJCnHbdu2DVOnTsXIkSPRp08fjB07FtOmTcPJkycb/Jr/%2BusvGAwG/N///R%2B%2B%2BuorJCUl1Xosx3E4dOgQunbtivnz59er%2BUjge1Hfpdhbt27FqVOnAAB33XVX2OOvv/56zJo1Cz///DNiYmJq7JdlGYsWLcL48eMxYMAADB06FHfddRf%2B/PPPkOfjOA4LFizA5MmTMWLECPTp0weDBw/GTTfdhM8%2B%2Bww8zwcd7/sM%2BJaPv/3227jsssvQt29fjBo1Ck888QSOHz8e8rkqKirw7rvv4oorrkC/fv1wwQUX4OWXX0Z5ebnyeQh830I1fvG9x9dccw08Hg/%2B%2B9//4pprrkG/fv0wbNgwPPjgg/jrr79CPr/b7cZnn32Gv/3tbxgwYABGjBiBp59%2BGnl5eUpjjyVLloT9GfTo0QPvv/8%2BAO8MwNoapXg8Hnz%2B%2Bee49tpr0a9fPwwfPhxTp07Fvn37aj33qlWr8I9//APDhg1D3759cemll%2BKVV15BYWFh2Lhqc/nllwOoPclVWFiIXbt2Yfjw4YiLi6v1PHa7HZ9%2B%2BiluvfVWDBs2DL1798bQoUNx%2B%2B2347vvvgv6vc3MzESfPn3Qo0cPfPrppzXO9cMPP6BHjx7o27cvDh8%2BDKD2xi89evTA4MGDIcsyvvrqK/ztb39D//79MWrUKDzzzDMoKSkBABw4cAD3338/hgwZgn79%2BuGWW27B2rVrQ76W4uJivPPOO7jhhhswZMgQ9OnTByNGjMA//vEP/Prrr7W/mWch3Pvv22exWDB69OhajxFFET/88APuvfdejB49Gn369MGgQYPw97//HbNnz0ZVVVXQ8YG/q9u3b8e1116LPn364KKLLgp6jcePH8ezzz6Liy%2B%2BGP369cNVV12Fzz77DKIo1vm3O/DfDt/PbubMmSgtLcXMmTNx4YUXKn%2BzX3rppXP6DBNCCCGNhWoyEkIIIU3os88%2BUzqopqSkoHPnzti/fz8efPBBZUZOY5o1axZ2796N7t27o7y8HMnJyWBZ7zXGDz/8EO%2B%2B%2By4AID4%2BHt27d0d2djYWL16M5cuX491338XYsWPr/VzXXXcdpk%2BfjpSUlLDH6vV6zJo1C9dccw202sgNRzZv3gwASE5ORkZGRtjj4%2BPjcd1119W6f/r06di5cyfi4%2BPRuXNnnDhxAhs3bsSmTZvwn//8J2imVFVVFSZPnoz9%2B/dDo9GgQ4cOaNOmDXJycrB3717s3bsXmzZtwpw5c2o8j8PhwG233YaDBw8iLS0NGRkZyMzMxLJly7Bu3TosXrw4qNFQQUEBpkyZgmPHjkGn0yk/7y%2B//BLr16%2BHTqdrwLvmTeDdd9992LBhA5KSkpCRkYGjR49i9erVWL9%2BPebPn48BAwYox9vtdtx7773YsWMHWJZFt27dwHEcli5dinXr1qFjx471fu5BgwYhLy8PeXl5iIuLQ5cuXdC9e/cax91///3YuXOn8nt0/PhxrFq1CmvXrsX8%2BfMxcOBA5VhZlvHiiy/i22%2B/BeD9PHTr1g3Hjx/H/Pnz8fPPP%2BPTTz9F3759G/Q%2BAcC4ceMwZ84crFq1Ck899VSN/b/99htkWcYVV1wBjuNCniM3Nxd33HEHsrOzodfrlc9KdnY2tm3bhm3btuGvv/7CzJkzAXgbUT300EN455138MEHH%2BDKK69UPg/5%2Bfl45ZVXAACPPfZYvTopy7KMJ554Aj/99BPatGmDDh06ICsrC99//z3279%2BPxx9/HA899BC0Wi06deqEnJwc7N69G/fffz%2B%2B%2BOILDBkyRDnXwYMHceedd6KsrAwmkwnt2rUDAGRnZysNlh5//HFl1vC5GjlyJGw2G/bt24f8/PwaTZsyMzNx7NgxXHvttdDr9SHPIQgCHnjgAaxfvx4A0KFDB6SmpiI/Px%2BHDh3CoUOHsGrVKixatKjGOU6fPo17770XWq0WGRkZyMrKQs%2BePQF4L3Lcf//9cDgcsFqt6NatG06fPo1Zs2Zh27ZtDX6thYWFuOGGG5Cfn4%2B2bduiU6dOOHLkCL755husX78eS5cupWXWhBBCVEUzGQkhhJAmsnfvXrzxxhtgWRbTp0/HunXrsGTJEqxduxZjx47F6tWrG/05d%2B/ejffffx/Lli3D2rVr8dxzzwHwJj7effddWCwWvPPOO9i8eTOWLFmCTZs24Z/// ...

# %% [markdown]
# We want to maximise the distance between the margin lines, on which the points lie$^{10}$.
#
# $$x_1-x_2$$

# %% [markdown]
# <br />
# $$
# \frac{\phantom{\quad}\mathbf{w}^{\mathrm T}x_1 + b = 1\\ -
# \mathbf{w}^{\mathrm T}x_2 + b = -1 \\}{\\ \mathbf{w}^{\mathrm T}(x_1 - x_2) = 2}
# $$

# %% [markdown]
# <br />
# We can normalise this equation by the length (Euclidean norm) of the vector $\mathbf{w}$:
#
# $$
# ||\mathbf{w}|| = \sqrt{\sum^p_{j=1}w^2_j}
# $$
#
# $$
# \frac{\mathbf{w}^{\mathrm T}(x_1 - x_2)}{||\mathbf{w}||} = \frac{2}{||\mathbf{w}||}
# $$

# %% [markdown]
# __Notes__
# 1. we want the distance between $x_1$ and $x_2$
# 2. our $b$ cancels out
# 3. we want to remove $\mathbf{w}^{\mathrm T}$
# 4. we do this with norm of $\mathbf{w}^{\mathrm T}$. However we cannot remove $||\mathbf{w}||$, so we are left to maximise $\frac{2}{||\mathbf{w}||}$.

# %%
fig = plot_svc_margin(svm_clf, highlight=True, margin_line=True, scale=2)
fig_num+=1
reduced_plot(iris_reduced, X_AX_LABEL, Y_AX_LABEL, 
             "Figure %d: Margin Distances"%(fig_num))
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2BKKKj4Ol4V8cWBeyJOEMSFoiLIsOxCoaAMRZZsKHSnTUfmOb8/akNDTkqB9iS29%%2BlpKR4nD9//nz/Nl7NJEnCuHHjMHnyZMW6LMv48ssvMXr0aHTs2BGdO3fG%2BPHjsXr16st63vLXt3PnzrDZbD7Py8vLwxVXXIHExEQ88cQTl/Wcl%2BuJJ55AYmIi9u3bV23XVHoftmnTBldeeSUGDRqE6dOnY8%2BePYqPTUxMxHXXXXdJz3v06FGsWLHiclonIiIiumhafzdARERERFXTvXt3dO/e3We9WbNmAIC2bdtiypQp6NSpk0qdqWPWrFnYs2cPBg8erFh/5plnsHjxYjRq1Ajjxo2D3W7H6tWr8eCDD%2BKJJ57AxIkTL%2Bv5S0pKkJqa6vP5f/31V7hcrst6juoyZMgQNGjQADExMdV%2B7YrvQ1mWUVxcjCNHjmDFihX45ZdfMGPGDNx0000ej5kyZcol9bJ//36MHTsWN998M0aMGFEt/RMRERFVBUNTIiIion%2BJ7t2748EHH7zgeW3btkXbtm1V6EgdVqsVzzzzDJYuXerznF27dmHx4sXo1KkT5s%2Bfj6CgIADA1KlTMWbMGLzxxhsYNWoU4uLiLqmH6Oho5OXl4ddff/UZmq5atQrBwcEoKSm5pOeoTkOGDMGQIUNq5Nq%2B3od79uzB3XffjZkzZ6JFixZISkpy16ryvlVSUFAAh8Nxyb0SERERXSpOzyciIiKigLVlyxaMGjUKS5cuRXJyss/zyqfg33fffe7AFABiYmIwfvx42O12bN269ZL7iI2NxZVXXol169bB6XR61c1mM7Zt24ZBgwZd8nP823Xs2BHPPfccXC4X3nrrLX%2B3Q0RERHRZGJoSERER1TK%%2BO4uJiAGWv57333ovu3buja9euePjhh5GZmYkrrrjCYx3V89c0PXXqlPvPec2aNRg7diw6duyIXr164emnn0ZeXl6VX4fKjBgxAg0aNMD27duRlZXlPq60punChQsxZswYdO7cGV26dMEtt9zisXbpu%2B%2B%2Bi9tvvx0AsGDBAq8/rx9//BETJkxAt27d0L59eyQnJ%2BPRRx/FyZMnPZ5n0KBBmDBhAg4fPoz77rsPXbt2RefOnXHPPfdg//79Xl/DqVOn8N///hf9%2BvXDlVdeiVGjRuGzzz7zGvGanZ2N5557Dv369UP79u0xaNAgvPrqqygqKvI4z%2Bl04r333sM111yDTp06oXv37rjrrruQlpZ2ka8uERERqYnT84mIiIjqgNWrV2PatGkICQnB8OHDYTQasXz5cmzZsuWyr52fn49p06Zh8ODBCA0NRYsWLQAAGzZswJQpU6DT6TBs2DBERUVh06ZNeO655/DXX3/hf//73wWvPXbsWDz99NMIDQ3FqVOnfJ7Xp08f9OnTR7FWvkFWy5Yt3cdGjx6N7t27o0GDBlX%2BOocNG4ZXXnkFq1evRq9evTxqq1atQrt27dCoUSOvx506dQpjx45FaWkphg4dinr16iEzMxOrVq1yj8y87bbbPB4zffp0NG/eHBMmTEBxcTFCQkKwc%2BdOTJw4ES6XC8OHD0d0dDRWrlyJm2%2B%2Bucoh9Lp16zBnzhwMGDAAPXr0wObNm7F48WL8/fff%2BPrrr6v8WvgiCAI6d%2B6M06dP4/fff8dVV12leN5HH32E119/He3atcP48ePhcDiwcuVKTJs2DTabDddffz26d%2B%2BO0aNH44cffsCVV16Jvn37uv%2B8Zs%2Bejc8%2B%2Bwxt2rTB6NGjIQgCtm/fjmXLluG3337DypUrYTQa3c935swZjB8/Hk2bNsWNN96Io0ePYt26ddi1axdWrVqFqKgoAMDBgwcxYcIEFBQUYMCAAWjWrBnS09Mxe/ZsHDhwALNnzwYAZGRk4Oabb0ZmZiYGDhyIFi1aYN%2B%2Bffjkk0%2BwZcsWLFq0CMHBwQCA//3vf/j666/RvXt39OvXDxaLBb/88gvuuusuzJs3Dz169Ljs152IiIiqH0NTIiIion%2BJ9PR0jxGhFY0ePRoNGzZUrJWUlGDmzJkIDQ3Ft99%2Bi6ZNmwIA7r77bowePfqy%2ByopKcHEiRM9RjqWlpbiiSeeQFhYGL799lt3b9OnT8e0adPw7bffYsiQIejfv3%2Bl11Ya8XoxfvjhB%2BzcuROtW7dGly5d3MfHjBlz0ddq1KgRrrjiCqSkpODZZ5%2BFIAgAgMLCQqSlpeGhhx5SfNxHH32E/Px8zJs3D71793Yfv%2B222zBu3DgsW7bMKzRNSEjA559/DlE8NzHs2WefhcPhwKJFi9ybfE2ePBk33ngjJEmq0tewd%2B9evPXWW%2B5NlaZNm4bRo0dj586dOHz4sDvwvhzx8fEAykZi%2BvLpp5%2BicePG%2BPbbb6HVlv1Icvfdd2Po0KFYuHAhrr/%2BeneYWB6alq%2BLmpmZifnz56Nbt274/PPPodFo3Nf9v//7P2zYsAE7duzwWM7h5MmTuPXWW/HMM8%2B4/9yeeeYZfPvtt1i1ahVuvvlmAMDMmTNRUFCAd955B8OGDQNQttnV3XffjR9//BG333472rVrh%2Beeew6ZmZmYO3cuBgwY4H6eBQsW4IUXXsB7772H//znPygqKsK3336Lbt26YeHChe7zxo0bh7Fjx2LRokUMTYmIiAIUp%2BcTERER/Uukp6fjvffeU/zv9OnTPh%2BXmpqKnJwc3Hrrre7AFADq169/2TvKlysPmMqtXbsWeXl5uOuuuzzCXFEU8eijjwIAvv/%2B%2B2p5bl%2B2bNmCZ599FjqdDrNmzfIIIC/VsGHDkJWVhd27d7uPrV27Fg6Hw%2BeoymuvvRYvvviiR2AKlK0BajQakZub6/WYoUOHevS7d%2B9eHDx4EKNGjXIHpgAQHh6OKVOmVLn/Ro0aeexCr9Pp3KNmK3sPXYzy5RDOn6ZekSzLyMvL85hKn5CQgBUrVuDLL7%2B84PVfeeUV/Pe///UITAGgW7duAKD4mt5zzz3uwBSAO7Av/7rPnj2LHTt2oHfv3h7vZ0EQ8Mgjj2DKlCnQ6/XIysrCxo0b0b9/f4/AFCgLwuvVq4cffvgBACBJEmRZxpkzZzxC5A4dOiAlJQWvv/56pV8rERER%2BQ9HmhIRERH9S0yZMuWSdiH/448/AJSFdOerOPrycpw/yvXPP/8EUBb2KY2O1Wg0iutJVpd169Zh6tSpcDqdeOWVV3DllVdWy3WHDRuGt956C6tXr3aHlytXrsQVV1yBxo0bu9cQrSgpKQlJSUkwm83Yt28fTpw4gaNHj2LXrl2w2WxwuVxejzn/9ayuP8OKoXm5sLAwAIDdbq/ydSpTvv5 ...

# %% [markdown]
# We want to $\text{max}\frac{2}{||\mathbf{w}||}$, while classifying everything correctly, $y_i(\mathbf{w}^{\mathrm T}\mathbf{x}_i+b) \geq 1 \quad \forall_i$.
#
# Or, instead:
#
# ${\text{min} \atop \mathbf{w}, b}\frac{1}{2}||\mathbf{w}||^2 \quad \text{s.t.} \quad y_i(\mathbf{w}^{\mathrm T}\mathbf{x}_i+b) \geq 1 \quad \forall_i$,
#
# which is easier because this is a _convex quadratic optimisation problem_ which is efficiently solvable using quadratic programming algorithms.

# %% [markdown]
# __Notes__
#
# - $\frac{1}{2}$ is added for convience.

# %% [markdown]
# ### Primal Problem
#
# This requires a _Lagrangian_ formulation of the problem so we introduce Lagrange multipliers, $\alpha_i, i = 1, \ldots , n$:
#
# $$
# \min L_P = \frac{1}{2}||\mathbf{w}||^2 - \sum^n_{i=1} \alpha_iy_i(\mathbf{w}^{\mathrm T}\mathbf{x}_i+b) + \sum^n_{i=1} \alpha_i \qquad \text{s.t.} \quad \forall_i \alpha_i \geq 0
# $$

# %% [markdown]
# ### Duel Problem$^{2,6,7}$
#
# Removes the dependence on $\mathbf{w}$ and $b$,
#
# $$
# \max L_D = \sum_i^n\alpha_i - \frac{1}{2}\sum_i^n\sum_k^n\alpha_i\alpha_ky_iy_k\mathbf{x}_i^{\mathrm T} \mathbf{x}_k \qquad \text{s.t.} \quad \forall_i \alpha_i \geq 0.
# $$
#
# To achive this we first need to set a constaint,
#
# $$\sum^n_i\alpha_iy_i = 0.$$
#
# Now we can find the vector $\hat\alpha$ that maximises the equasion using a _QP solver_.

# %% [markdown]
# __Notes__
#
# - The duel problem allows us later to use the kernel trick.
# - $\sum_i\alpha_iy_i = 0$ removes our $b$.
# - There is a Lagrange multiplier $\alpha_i$ for every training point. Points for which $\alpha_i > 0$ are called "support vectors", and lie on one of the margins, with all other training points having $\alpha_i = 0$.
# - $\alpha_i$ will only be zero if all training points have the same class.

# %% [markdown]
# Knowing our $\hat\alpha_i$ means we can find the weights, $\mathbf{\hat w}$, which are a linear combination of the training inputs, $\mathbf{x}_i$, training outputs, $y_i$, and the values of $\alpha$,
#
# $$\mathbf{\hat w} = \sum_{i \in s}\hat\alpha_iy_i\mathbf{x}_i,$$
#
# where $s$ is the collection of indicies of support vectors$^6$. We only need the support vectors as they are the only ones with $\hat\alpha_i > 0$.
#
# Out bias term, $\hat b$, is then determined by$^2$:
# $$
# \hat b = \frac{1}{n_s}\sum^n_{i =1}\left(y_i-\mathbf{\hat w}^{\mathrm T}\mathbf{x}_i\right)
# $$
# where $n_s$ is the number of support vectors.

# %% [markdown]
# __Notes__
#
# - We only need to focus on those with $\alpha_i > 0$.
# - Solving the SVM problem is equivalent to finding a solution to the Karush-Kuhn-Tucker (KKT) conditions.
#     - it is through the use of using the following Karush-Kuhn-Tucker (KKT) condition we can find $b$:
# $$
# \alpha_i(y_i(\mathbf{w} \cdot \mathbf{x}_i + b) - 1) = 0 \quad \forall i.
# $$
# - It is numerically safer to take the average value over all support vectors, $\frac{1}{N_S}$.
# - For more reading on quadratic programming for support vector machines, I recommend you read:
#     - Appendix C in Géron, A. (2017). Hands-on machine learning with Scikit-Learn and TensorFlow: concepts, tools, and techniques to build intelligent systems. " O'Reilly Media, Inc.".
#     - Burges, C. J. (1998). A tutorial on support vector machines for pattern recognition. Data mining and knowledge discovery, 2(2), 121-167.
#     - https://www.adeveloperdiary.com/data-science/machine-learning/support-vector-machines-for-beginners-duality-problem/

# %% [markdown]
# ## Inner products, similarity, and SVMs$^8$
#
# __Question__: But why bother doing this? That was a lot of effort, why not just solve the original problem?
#
# __Answer__: Because this will let us solve the problem by computing the just the inner products ($\mathbf{x}_i^{\mathrm T} \mathbf{x}_k$) which will be important when we want to solve non-linearly separable classification problems.
#
# - Inner products provide a measure of _"similarity"_
# - Inner product in 2D between 2 vectors of unit length returns the cosine of the angle between them. In otherwords, how _"far apart"_ they are.
#     - if they are parallel their inner product is 1 (completely similar).
#     - If they are perpendicular (completely unlike) their inner product is 0 (so should not contribute to the correct classifier).

# %% [markdown]
# $$
# L_D(\alpha_i) = \sum_i^n\alpha_i - \frac{1}{2}\sum_{i,k}^n\alpha_i\alpha_ky_iy_k\mathbf{x}_i^{\mathrm T} \mathbf{x}_k \qquad \text{s.t.} \quad \forall_i \alpha_i \geq 0, \ \sum_i^n\alpha_iy_i = 0.
# $$
#
# __Case 1__
# Two observations $\mathbf{x}_i$, $\mathbf{x}_k$ are completely _dissimilar_ (orthogonal), so their dot product is 0. They don't contribute to $L$.
#
# __Case 2__ Two observations $\mathbf{x}_i$, $\mathbf{x}_k$ are similar and predict the _same_ output value $y_i$ (ie. both $+1$ or $-1$). This means $y_i \times y_k = 1$ and the value $\alpha_i\alpha_ky_iy_k\mathbf{x}_i\mathbf{x}_k$ is positive. However this _decreases_ the value of $L$, due to subtracting from the first term sum, $\sum_i^n\alpha_i$, so the algorithm downgrades similar feature vectors that make the _same_ prediction.
#
# __Case 3__ : Two observations $\mathbf{x}_i$, $\mathbf{x}_k$ predict opposite predictions about the output value $y_i$ (ie. one $+1$ and the other $-1$), but are otherwise similar. The value $\alpha_i\alpha_ky_iy_k\mathbf{x}_i\mathbf{x}_k$ is negative and since we are subtracting it, this adds to the sum. These are the examples that maximise the margin width.

# %%
# TODO - this is pretty quick code - tidy it up
import math

def rotate(origin, point, angle):
    """
    Rotate a point counterclockwise by a given angle around a given origin.

    The angle should be given in radians.
    """
    ox, oy = origin
    px, py = point

    qx = ox + math.cos(angle) * (px - ox) - math.sin(angle) * (py - oy)
    qy = oy + math.sin(angle) * (px - ox) + math.cos(angle) * (py - oy)
    return qx, qy

def plot_svc_case_example(clf, main_title, axes_limit= [-2, 5.5, 0, 4]):
    w = clf.coef_[0]
    b = clf.intercept_[0]

    xmin=axes_limit[0]
    xmax=axes_limit[1]
    # At the decision boundary, w0*x0 + w1*x1 + b = 0
    # => x1 = -w0/w1 * x0 - b/w1
    x0 = np.linspace(xmin, xmax, 200)
    decision_boundary = -w[0]/w[1] * x0 - b/w[1]

    margin = 1/w[1]
    gutter_up = decision_boundary + margin
    gutter_down = decision_boundary - margin

    svs = clf.support_vectors_
    
    with sns.axes_style("whitegrid"):

        fig, axes = plt.subplots(1,3, figsize = (width_inch*3, height_inch), sharey=True)
        axes = axes.flatten()
        
        for i, title in enumerate(["Case 1","Case 2", "Case 3"]):
            plt.sca(axes[i])
        
            if title == "Case 1":
                orth = rotate((0,0), svs[0, :], 1.5708)
                sns.scatterplot(x = [orth[0]], y = [orth[1]], s=180, facecolors='#FFAAAA')
                sns.scatterplot(x = [svs[0, 0]], y = [svs[0, 1]], s=180, facecolors='#FFAAAA')
                plt.arrow(0.,0,svs[0, 0],svs[0, 1], fc='b', ec='b', linewidth=1, length_includes_head=True)
                plt.arrow(0.,0,orth[0],orth[1], fc='b', ec='b', linewidth=1, length_includes_head=True)
                iris_reduced_ = pd.concat([iris_reduced, pd.DataFrame([orth[0],orth[1], "Setosa"],index = iris_reduced.columns).T])
                reduced_plot(iris_reduced_, X_AX_LABEL, Y_AX_LABEL, title)
            
            else:
                if title == "Case 3":
                    g = sns.scatterplot(x = svs[:, 0], y = svs[:, 1], s=180, facecolors='#FFAAAA')
                    plt.arrow(0.,0,svs[0, 0],svs[0, 1], fc='b', ec='b', linewidth=1, length_includes_head=True)
                    plt.arrow(0.,0,svs[1, 0],svs[1, 1], fc='orange', ec='orange', linewidth=1, length_includes_head=True)

                else:
                    sns.scatterplot(x = [svs[0, 0]], y = [svs[0, 1]], s=180, facecolors='#FFAAAA')
                    sns.scatterplot(x = [iris_reduced.iloc[24,0]], y = [iris_reduced.iloc[24,1]], s=180, facecolors='#FFAAAA')
                    plt.arrow(0.,0,svs[0, 0],svs[0, 1], fc='b', ec='b', linewidth=1, length_includes_head=True)
                    plt.arrow(0.,0,iris_reduced.iloc[24,0],iris_reduced.iloc[24,1], fc='b', ec='b', linewidth=1, length_includes_head=True)
                
                reduced_plot(iris_reduced, X_AX_LABEL, Y_AX_LABEL, title)
            plt.axis(axes_limit)
            
            plt.plot(x0, decision_boundary, "g-", linewidth=2)
            plt.plot(x0, gutter_up, "r--", linewidth=2)
            plt.plot(x0, gutter_down, "r--", linewidth=2)
            
            axes[i].get_legend().remove()
        
        
        fig.suptitle(main_title, y=1.05)
        
        return fig
        
fig_num+=1
fig = plot_svc_case_example(svm_clf, "Figure %d: Similarities and SVM"%(fig_num))
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2BwtalRUkCZFeu8dZub7g3gGFBDlwBmO%2B7eWa/kMM8yeI5AT3tnnVej1ej2IiIiIiIiIiIiIiIiIiKjNKaUOQERERERERERERERERER0p%2BACLRERERERERERERERERFRO%2BECLRERERERERERERERERFRO%2BECLRERERERERERERERERFRO%2BECLRERERERERERERERERFRO%2BECLRERERERERERERERERFRO%2BECLRERERERERERERERERFRO%2BECLRERERERERERERERERFRO%2BECLRERERERERERERERERFRO%2BECLRERERERERERERERERFRO%2BECLRERERERERERERERERFRO%2BECLRERERER3TJ/f/8W/3n77beFx917773w9/fHr7/%2BKmF6aWVlZWHgwIF44oknmr1fYmIinn/%2BeYwePRqBgYEYN24cXnrpJSQkJIieqaamBuvWrcOyZcswatQoBAYGYtiwYQgJCcHKlSuRlZXV6ONeeOEF%2BPv74/333xc90zWpqanC11JZWZlw%2B4QJE%2BDv74%2BDBw%2B22XNfc%2B35Y2Njb/hYfHz8Ld3/TldWViYcn9TU1Ft6bEFBAb744guEhIRg6NChCAwMxOjRo/HPf/4Tv/76K6qqqhrc/%2BLFi8JznT17tkXPERMTIzzm6tWrAAw/t/z9/TF79uwWfZ633npLeMwLL7xwS6%2BTiIiIiIjkTy11ACIiIiIi6rj8/PxgZWXV7H28vLzaKY3xq66uxv/93/%2BhtLS02ftFRETgnnvuQUVFBSwtLeHr64uMjAxs2rQJu3btwqefforx48eLkik7OxvLli1DbGwslEolOnfuDDc3N%2BTm5uLy5cu4dOkSfvrpJ7z99tuYNm2aKM8pBzk5OXj77beRkpKCTZs2SR1H9k6dOoUnnngChYWFMDU1RZcuXWBiYoKMjAycOHECJ06cwA8//ID//e9/8PX1BQD06dMHPj4%2BiI%2BPR2hoKAYOHHjT59mxYwcAYMCAAejSpcsNH4%2BOjkZKSkqzP9f0ej327Nlzm6%2BUiIiIiIjuBFygJSIiIiKi2/byyy9j6NChLb7/%2B%2B%2B/j4qKCjg5ObVhKuNUVlaGZ555BqdOnWr2fhUVFXj88cdRUVGBkJAQvPzyyzA3N0dtbS0%2B//xzfP3113j22Wdx4MAB2NratjrX8uXLERsbiwkTJuD111%2BHs7Oz8LHs7Gx8%2BOGH2L59O5577jl07twZgYGBwsefeeYZPPjgg7C3t291jqa4uLggNDQUAGBhYdFmz9Oca89ff1Hu6NGjCAsLQ0BAQIvuT7cvJycHjz/%2BOEpKSrBixQosW7YM5ubmwscjIyPx6quv4tKlS3jggQcQFhYmfHzOnDn46KOPsGfPHvz73/%2BGUtn0hcT0ej127doFAJg3b94NH1er1aitrcXevXuxbNmyJj/PuXPnkJ2dfbsvl4iIiIiI7gC8xDEREREREbUbd3d3%2BPj4wMbGRuoo7SoiIgILFizAoUOHbnrfgwcPIjMzE127dsVrr70mLDSp1Wo89dRT8PPzQ2lpqSgNvdOnT%2BPChQtwdnbGp59%2B2mBxFgCcnZ3x/vvvY8iQIaipqcG33357w8d9fHzg4ODQ6ixN0Wg08PHxgY%2BPDxQKRZs9T3OuPb%2BJiUmb3J%2Bat27dOpSUlGDy5MlYvnx5g8VZAAgICMA333wDBwcHZGRkYPPmzcLHZs%2BeDaVSiZycnJu%2BOeKvv/5Ceno6zM3NERwcfMPHhwwZAgDYt29fs5/n2vdmz549W/T6iIiIiIjozsMFWiIiIiIioja0atUqLFiwAPHx8ejbty8WL17c7P0tLCwwY8YM3HXXXdBoNA0%2BplAohMu3ZmRktDrb5cuXAdRdqtrU1LTR%2ByiVSsyfPx8AcOnSpVY/J9GtioyMBAD07t27yfs4OjoKl/2OiIgQbndxccHw4cMBAGFhYc0%2Bz7XLG0%2BaNKnRS7ePGjUKFhYWCA8Pb7Ihq9frsXfvXjg4OAgLukRERERERNfjAi0REREREbWbe%2B%2B9F/7%2B/vj1119v%2BNjJkyfxwAMPYMSIEejfvz/uuusu7N%2B/H6dOnYK/vz/uvfde4b6pqanw9/eHv78/ysrKbvhcsbGxwscbe/5z587h9ddfx4ABAzBgwADcf//90Ol0wv3OnDmDxx9/HCNGjEBgYCDGjh2Ll156CVevXr3l13zp0iWYmpriqaeewm%2B//YZOnTo1e/9x48bho48%2Bwv3333/Dx7RaLaKiogDghv0xN2/e3Ohrbo5aXbfrTUREBPLy8pq835QpU7Bt2zasW7euwe0vvPAC/P398f777wu3Xfv3euyxx1BaWooPPvgAEyZMQO/evTFx4kR8/vnnqK2tBVC3YLZw4UL069cPgwYNwmOPPYaEhIQGz3Gzf%2BvGHDx4ECtWrMDYsWPRu3dv9O/fH8HBwXj33XeRk5PT6OefMWMGrly5gkWLFqF3794YNWqU8HV67fljY2MBABMmTMCLL74IoG7x0N/fHxMmTBA%2B5/X3r%2B9Wv7by8vLw7rvvIigoCIGBgRgwYABmz56NTz/9FIWFhS06HtdUVVVhzZo1WLJkCYYPH47AwEAMGjQICxYswA8//IDq6uoG97/2b/nwww%2BjvLwcH3/8MSZPnozevXtj5MiRePbZZ5GYmNjoc5WWluLzzz/H1KlT0adPH%2BHfvqam5pYyAxDeqHD06FHo9fom7/fUU08hNDRU%2BLe5Zs6cOQDqmq3XvvauV11djd27dwMA5s6d2%2Bh9TE1NMXbsWOj1%2BiZbtBcuXEBGRgYmT54MlUrV7OsiIiIiIqI7F/egJSIiIiIiyf3www/CIp%2BzszO8vb0RGRmJxx57DBMnThT9%2Bd5//32Eh4fDz88PhYWFcHJyEvam/Oqrr7By5UoAgL29Pfz8/JCSkoJNmzYhNDQUK1euxNixY1v8XHPmzMFrr712w%2BWDb1VmZiY%2B/PBDJCYmonPnzo1egvVWDRs2DABQWFiIRYsWYdmyZQgKCrrhksUWFhbo0aPHLX3u4uJiLFq0CPHx8fDx8YGzszNSU1PxxRdfIDc3F506dcIXX3wBe3t7eHt7Iy4uDvv370d4eDh27dp12/va/vvf/8bGjRsB1F1S28/PD7m5uUhISEBCQgLCwsKwbdu2Gz5/SUkJli1bhuLiYvj6%2BiIhIQE%2BPj6NPkdgYCA0Gg2SkpKEY9OSfZVv9WsrLy8PISEhSE9Ph6WlJXx9fVFbW4srV64gOjoaoaGh2LBhQ4v2Ii4pKcGSJUsQGRkJlUqFzp07w83NDWlpabh48SIuXryIEydO4LvvvrvhsWVlZfjHP/6BqKgouLq6wsfHB7GxsdixYweOHDmCTZs2NdhvNzc3F//85z8RGxsLjUaD7t27o7CwEF988QX%2B/PPPm2a93rBhw7Bnzx6cOXMG9957L5YsWYLRo0fDzMyswf2cnZ0b/T6bPHkyLC0tUVhYiOPHjzf6/XvkyBEUFRXBzc1NaNw2JigoCGFhYdi3bx/uvvvuGz5%2B7fLGU6dOxdGjR2/1pRIRERER0R2CC7RERERERCSpixcv4oMPPoBSqcR//vMfLF68GAqFAgUFBXj%2B%2Beexf/9%2B0Z8zPDwcX3zxBSZPngydTofi4mIAwN69e7Fy5UpYWVnhzTffxLRp0wBA2H915cqVeOaZZ7Bjxw64u7u36LmmTJnSqqzr1q3DDz/8gJSUFGi1WgwYMAAffPDBDZcknjx5Mvr27XtLn9vX1xdLlizBzz//jJSUFLz22mt4/fXX4efnhyFDhmD48OEYNmwYLC0tbzn3mTNn4OTkhI0bNyIwMBAA8OWXX%2BKzzz7D%2BvXrodfr8eKLL2 ...

# %% [markdown]
# ## Recap$^1$
#
# The solution to the maximal margin classifier problem involves only the _inner products_ of the observations:
#
# $$
# \left<x_i,x_{i^{\prime}}\right> = \sum^p_{j=1}x_{ij}x_{i^{\prime}j}.
# $$
#
# Assume we have a new point $x^*$. If wanted to compute $f(x^*)$ using our linear classifier we would need to the inner product between $x^*$ and each training point $x_i$:
#
# $$f(x) = \sum^n_{i=1}\hat\alpha_i\left<x^*,x_i\right>+ \hat b.$$
#
# In the above case, for estimating the parameters $\hat\alpha_1...,\hat\alpha_n$ and $\hat b$, we need the $n(n-1)/2$ inner products $\left<x_i,x_{i^\prime}\right>$ between all pairs of training observations.
#
# However, $\hat\alpha$ is nonzero only for support vectors, so if we have a collection of their indicies, $s$, we can do the following instead:
#
# $$
# f(x^*) = \sum_{i\in s}\hat\alpha_i \left<x^*,x_i\right> + \hat b.
# $$

# %% [markdown]
# ## Limitations
#
# - If we have a large number of features, this approach often leads to overfitting.
# - Maximal Margin Classifiers are sensitive to outliers.

# %%
# adapted from https://github.com/ageron/handson-ml2/blob/master/05_support_vector_machines.ipynb
def outlier_margin(title, scale=1):
    X = iris_reduced[["Petal length (cm)", "Petal width (cm)"]].values
    y = le.transform(iris_reduced[["Species"]].values.ravel())
    X_outliers = np.array([[3.4, 1.3], [3.2, 0.8]])
    y_outliers = np.array([0, 0])
    Xo = np.concatenate([X, X_outliers[1:]], axis=0)
    yo = np.concatenate([y, y_outliers[1:]], axis=0)

    svm_clf = SVC(kernel="linear", C=float("inf"))
    svm_clf.fit(Xo, yo)

    svc_decision_boundary(svm_clf, scale=2)
    g = sns.scatterplot(x = Xo[:,0], y = Xo[:,1], hue=yo, style = yo, s=60*scale)
    leg = g.axes.get_legend()
    new_labels = ['Setosa', 'Versicolor']
    for t, l in zip(leg.texts, new_labels): t.set_text(l)
    plt.axis([0, 5.5, 0, 2])
    plt.title(title)
    plt.xlabel("Petal Length (cm)")
    plt.ylabel("Petal Width (cm)")
    
fig_num+=1
fig = plt.figure(figsize=(width_inch*1.5, height_inch*1.5))
outlier_margin("Figure %d: Effect of outliers"%fig_num, scale=2)
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2BwAAAKMCAYAAABxWjJmAAAAOXRFWHRTb2Z0d2FyZQBNYXRwbG90bGliIHZlcnNpb24zLjMuNCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8QVMy6AAAACXBIWXMAABJ0AAASdAHeZh94AAEAAElEQVR4nOzdd3hUZdrH8e%2BZnkmvJKEXRaQIqBSlVwGRJmCD1W2uyuquuvZV7Cu65VXXvusqotI7BESUJggqIE16Twjpffp5/4gTMkyCCUwyZ5L7c1177cU8ZyZ3ktuT%%2B%2B9t0bH79u3j44dO/LYY49d0tcdNGhQjX7%2Bb7zxhs/z3nvvPQYMGECnTp3o27cvZWVlrFu3jtGjR9O5c2d69uzJli1bLqm2C9m4cSM//vhjwF93wYIFDBs2jE6dOnHddddx7NixgH%2BNX1JUVMQnn3zi89igQYO45pprKv797bff0r59e1588cX6Lk8IIUQdMgS7ACGEEKIqPXr0oEePHtWOt27dGoAOHTowbdo0unbtWk%2BV1Y8XXniBH3/8kcGDB//isS6XiyeeeAKXyxWwrz9t2rQLjlf%2B3WzYsIG///3vJCUlMXXqVMxmMw6HgwceeAC328348eMJDw%2Bnbdu2Aauvsk8//ZRnn32Wf//73wF93cOHD/Pkk08SERHBbbfdhk6nIzU1NaBfoyaGDx9OYmIid9xxR7XHNG3alGnTpnHVVVfVY2VCCCHqmgR2IYQQmtSjRw/%2B%2BMc//uJxHTp0oEOHDvVQUf2w2Wz89a9/ZcmSJTV%2BzgcffMDevXsDWkdNfvZe3q99//33M3HiRAC2b99OWVkZo0eP5tlnnw1obefLycmpk9fdt28fHo%2BH2267jT//%2Bc918jVqIicnh8TExAse06xZs1r9zoQQQoQGmRIvhBBCaMQ333zDqFGjWLJkCX369KnRcw4fPsy///1v%2BvfvX8fVVc/hcAAQGxt7wcdCTUP4HoQQQoQ2CexCCCFCWnX3sG/evJkpU6Zw9dVX06tXL55%2B%2BmkOHDjgd//1%2BfcCe1V1T/CUKVMYNGgQ69atY9CgQVx11VU88MADFeN79uzh3nvvpWfPnnTp0oUxY8bw2Wefoapqjb6XJUuWUFJSwksvvVSjq9Iej4cnn3ySpk2bct9991V73JQpU2jfvj3ffvttjeqojfbt2/Pmm28CcN9999G%2BfXsGDRrE1KlTAfj4449p3769z731x48f5%2BGHH%2Ba6666jU6dOjBgxgnfffRen0%2Bn3%2BqdOneLJJ5%2BkX79%2BXHXVVYwaNYr//ve/FcdOmTLF7%2Bv/kqNHj/p8/SFDhjBjxgyKiooqjhk0aBCPP/44AC%2B//HKV9%2B2fr6ioiBkzZjBkyJCKe94feughjh496nPcG2%2B84bMOQ2WV%2B9HbgwA//fTTBWuo7h72rKwspk%2BfTr9%2B/ejUqRODBg3i1Vdfpbi42Oe4C/X28ePHeeCBBxg4cGDFa0yfPp2srKwL/jyEEEJcOpkSL4QQosFZvXo1f/rTnwgPD2f48OFYLBaWL1/ON998c8mvnZeXx5/%2B9CcGDx5MRERExX3Z69atY9q0aRiNRoYNG0ZcXBwbNmxg%2BvTp7N27l%2Beff/4XX/vmm2/mqaeeIiIiglOnTv3i8R9//DE7duzgk08%2BwWQyVXvcuHHj6NGjB02bNq35N1pD06ZNY%2BvWrWzdupWRI0fSpk0bIiMj%2Bemnn1i4cCFXXXUVffv2rbhtYc%2BePfzqV7/CZrMxbNgwUlNT%2Be677/jHP/7Btm3bePfdd9Hr9QAcOHCAKVOmUFBQwIABA2jdujVbt27llVdeYf/%2B/bzyyiuMGzcOwOfrX8jOnTu58847sdlsDBw4kObNm7Njxw7%2B85//8NVXX/HZZ58RExPD1KlT2bp1K19%2B%2BSV9%2BvSha9euF1xTIS8vj1tvvZWjR4/StWtXBg8ezMmTJ1mxYgVff/01//3vf2t9f7n3vvQ333yThIQEbrnllgvWcL709HRuvfVWMjMzGThwIG3btmXfvn188MEHfPPNN8yaNQur1erzPZzf27m5udx5553k5eUxfPhwkpKS2L9/P5999hnffvstS5YswWg01ur7EkIIUXMS2IUQQmjS1q1bq72aOG7cOJo1a1blWGlpKc8%2B%2BywRERHMmTOHVq1aAfDb3/62ItxditLSUu666y6fK8ZlZWU89thjREZGMmfOnIraHn74Yf70pz8xZ84chgwZ8ovT1qu60l%2BdkydP8q9//YvJkydzzTXXsG/fvmqPHT9%2BfI1f1%2BtCV5PNZjO///3vgfJ73d944w22bt3KqFGjGDJkCFB%2Bxdcb2L33VquqymOPPYbD4eDzzz%2BnU6dOFa/58ssv87///Y/PP/%2Bc22%2B/HYBnn32WgoICXn/9dYYNG1bxGr/97W9ZtGgRU6dOZfz48Zw%2Bfdrv61fF7XbzyCOP4HA4ePfdd%2BnXr1/F2Guvvcb777/PjBkzeOmll7jzzjuJioriyy%2B/pG/fvtx5550X/Hm9%2BuqrHD16lHvuuYc//elPFY%2BvW7eOu%2B%2B%2Bm0ceeYQVK1ZUfBhRE9770r2Bvbb3qE%%2BXkrisKDDz5I165dLziroCrbt2/n2LFjjBkzxiesQ/mCeUuWLGHp0qVMnz69Vq/tcDhYvnw5TZs25f777/cZ69%2B/P8OGDWPVqlV899139OzZs1Y1X6yzZ8%2Byfv16%2Bvfv7xeo77jjDv773/%2BycOFCn8AO/r3t8XiA8pkRY8eOrfjA4c9//jP33HPPLy6GJ4QQ4tJIYBdCCKFJ06ZNu6hVr3ft2gVAly5d/Ma6d%2B9%2ByXUBfh8W7N69GygPNVVdmdbr9fz0008B%2BdoAc%2BbMYcuWLbz11ltEREQE7HUr279/f8Bfc8%2BePQCcOHGiyp9TeHg4%2B/fvR1XViq9f1XZ9HTt2pGPHjrX%2B%2Bt5ZCNdee63fmMlkonPnzqxZs4YjR45wxRVX1Ph1jx49is1mo3v37uh0/ssDXX311axatYqffvqp3gL73r17UVWV/Pz8Kn/WRqORjIwMMjMzadKkScXj5/f28OHD%2Bfe//82sWbNYsWIFffr0oV%2B/fvTv31/CuhBC1AMJ7EIIIRqUvLw8ABISEvzGkpKSAvI1LBaLz7%2B9i5UtX7682ucUFBQE5GtnZmYyY8YMbrjhhhrt0a4lhYWFQPm%2B7Rs2bKj2uJKSkoqfVyA/kPAutFbda3r7o6ys7KJeNzIy8oKva7PZavW6l8L7s96xYwc7duyo9rj8/HyfwH5%2Bbzdp0oR58%2Bbx9ttv8%2BWXX7J06VKWLl2K0Whk ...

# %% [markdown]
# __Notes__
#
# - In figure 13 above, we can see that the reliance on a small number of observations means there is now a small margin.
# - We want to be confident that a distance from the hyperplane is a measure of our confidence in its classification, and that we have no overfit to our training data.

# %% [markdown]
# In other cases, no exact linear separating hyperplane exists. Therefore we may want to use a hyperplane that *almost* separates the two classes, allowing some errors, using a *soft margin* (Support Vector Classifier).

# %%
def soft_margin(title, hyperplane=False, scale=1):
    virgin_versi = iris_vis[["Petal length (cm)", "Petal width (cm)", "Species"]]
    virgin_versi = virgin_versi[virgin_versi.Species != "Setosa"]

    X = virgin_versi[["Petal length (cm)", "Petal width (cm)"]].values
    y = virgin_versi[["Species"]].replace({'Versicolor':0, 'Virginica':1}).values.ravel()
    
    if hyperplane:
        svm_clf = SVC(kernel="linear", C=100)
        svm_clf.fit(X, y)

        svc_decision_boundary(svm_clf, 2.9, 7)
    labels = virgin_versi[["Species"]].values.ravel()
    sns.scatterplot(x = X[:,0], y = X[:,1], hue=labels, style = labels, s=60*scale)
    plt.axis([2.9, 7, 0.9, 2.75])
    plt.title(title)
    plt.xlabel("Petal Length (cm)")
    plt.ylabel("Petal Width (cm)")

fig_num+=1
fig = plt.figure(figsize=(width_inch*2, height_inch*2))
soft_margin("Figure %d: No Exact Linear Separating Hyperplane"%fig_num, scale=1.5)
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%%2Bm%2B%2B%2BeahbXiMBYNBXXDBBbrxxhvLLV%2B/fn2l98fr9e7XeUP7L1q0qMI6jz/%2BuNLT07V48eL9OkdFevXqVaXPfuzYsTE974FYvny5FixYsM96Y8eOVXp6uj7%2B%2BOMq1w318dpuyZIlGj16tLp166bWrVvr1FNP1ZVXXqlPP/1UwWDwUDfvoPJ6vRo/fnzEtrvuukvp6en67bffDkmbNm7cqPT0dGVkZFRaLyMjQ%2Bnp6dq4cWOcWhY/6enpGjx48KFuBgAAMWM91A0AAOBw0rlzZ3Xu3LnC8hYtWkiSTjjhBI0aNUrt27ePU8vi47HHHtPy5cvVu3fvcst///13SVL//v117LHHRpVbLJYDOv%2BDDz6ozz//XA6H44COsz9GjRpVaXll/SKe5syZoxtuuEFjxoxRt27dYnbczp07a9SoUeE%2BXpuNHz9eTz31lOrWraszzjhD9erV044dO/Tdd99pzJgx%2BuKLL/Tyyy/LZrMd6qYeFJdeeqnWrl2rK6%2B8MrytT58%2Batq0qerVq3cIWwYAAA4nhJIAAMRQ586ddfPNN%2B%2Bz3gknnKATTjghDi2Kj%2BLiYt1///36/PPPK623atUqSdJ1112nVq1axbwdf//9t1566SX94x//iPmx96Uqn3tNkJWVdVBG%2BnXp0kVdunSJ%2BXHjbcOGDfrXv/6l9u3b680331RCQkK4zOv16uabb9bcuXP17rvv6rLLLjuELT14du7cGbWtT58%2B6tOnzyFoDQAAOFzx%2BjYAADgg3333nQYMGKDPP/98nyPvVq1aJZvNppYtW8a8HU2aNFFKSoreeOON8IhMoLrmzp2rYDCoiy66KCKQlCSHw6G7775bkjRjxoxD0TwAAIDDBqEkAACHQEVzSi5cuFAZGRk6%2BeST1bVrVz3wwANavXp11JyEvXr10imnnBJ13MWLFys9PV2PP/54eFtGRoZ69eqluXPnqlevXmrXrp1Gjx4dLl%2B5cqVuvPFGdenSRW3bttXgwYP13nvvyTCMKl3L559/roKCAj3xxBN6%2BOGHK627atUqtWjRokqvvYbmhqvqHJDJycm666675Pf7df/991d5NODatWt1xx136LTTTlPr1q3Vp08fPf3008rLy6vS/tX1%2BeefKz09Xeeff35EG3ft2qVu3bqpffv2%2Bvvvv8Pbf/zxR40aNSo8t2GnTp10xRVXlDt/ZlZWlp544gn16tVLbdu2Vd%2B%2BffX888%2BroKBAUum8gKFQ7Z///GdM594rb07J9PR03XXXXfrpp5%2BUkZGhDh06qFOnTrr11lvLPe%2B6desiPot%2B/frp1VdfVUlJSVTdqt6XffX/vfn9fknS6tWryy1v0aKF/vOf/5Q7Gverr77SxRdfrA4dOqhjx4667LLLotoTmhvx%2Beef11dffaUBAwaEP6vx48eX228//fRTZWRkqFOnTmrdurW6deum22%2B/XRs2bIioF7rfr7zyik455RSdcsop4WdMQUGBXnrpJQ0ePFgdOnRQmzZtdPbZZ%2Bvpp59WYWFhRNs2bdqkvLy88PGk6DklQ3XHjh2rb7/9VsOGDVPbtm116qmn6r777lNWVlbUdUyfPl3Dhg1Thw4d1L17dz3zzDP67rvvqjxv6f647LLLlJ6ernXr1kWVffrpp0pPT9cHH3wgqfS5eskll%2Bj3339XRkaG2rVrp%2B7du%2BuRRx7Rrl27ovbPzMzUQw89pB49eqh169bq1auX/vWvfyk/Pz%2BiXmV9MD09XXfccYcWLVoUvoe9evXS888/X6U5drOysvTUU0%2BpX79%2Bateundq1a6cBAwbolVdeCfdlac/Pho8//lhTpkzRoEGD1KZNG/Xo0UNPPfWUioqKoo69cOFCXXHFFTr55JPVvn17XXTRRZo%2Bffo%2B2wQAQFURSgIAUEN88803uuqqq/T777%2Brb9%2B%2B6t%2B/v77%2B%2BusKF42pjuzsbN16663q2LGjhgwZEg40586dq4svvliLFi1Sz549demllyoYDOqhhx7SAw88UKVjDxs2TDNnztTQoUMrrVdYWKgNGzYoNTVVDz/8cDg4GzJkSLmvfQ8ZMkSjRo1S06ZNq3ydQ4YM0Wmnnably5dr4sSJ%2B6y/bNkynX/%2B%2Bfriiy/Uvn17jRgxQnXr1tUbb7yhCy%2B8sNwg4kCde%2B656tmzp1auXKl33nknvP2RRx5RZmam7rzzTh1zzDGSpJkzZyojI0NLly5Vnz59dNlll6lDhw5auHChrrrqqohFRzIzMzVs2DC99dZbatasmUaMGKFGjRrplVde0U033SS/368%2BffqE5/vs1q2bRo0apeTk5JhfY1krV67UyJEjZTabdckllyg9PV1fffWVLr/8cvl8voh6Q4cO1fTp09W1a1ddfvnl8ng8eu6553TDDTcoEAiE61bnvkgV9//ynHrqqZKkN998U3feeacWLlwY0U5JOuecc9SxY8eIbf/5z3906623avv27RoyZIiGDBmiP//8U1dccYU%2B%2B%2ByzqPPMnz9ft912m5o3b66LL75YkvTUU0/pnnvuiaj31FNPacyYMcrNzdWQIUM0YsQINWjQQNOmTVNGRoaKi4ujjvvaa6/pvPPOU7du3dSuXTv5/X5dccUVGjt2rOrXr6/hw4dr6NChKi4u1htvvBEOHpOTkzVq1Ci53W7Z7XaNGjVqn69sz549W6NGjVL9%2BvWVkZGhhg0b6sMPP4x6br311lsaPXq0tm7dqsGDB6tHjx6aNGlSlZ8z%2B%2Bu8886TJE2dOjWqLDT/bL9%2B/cLbtm/frpEjRyo/P18jRozQUUcdpXfeeUeXXnppONyXpM2bN2vYsGF6//33ddJJJ%2Bnyyy9XixYt9PrrrysjIyMc9IZU1gdXrVqlq6%2B%2BWgkJCRoxYoQ8Ho9eeeUVXXvttZX%2BcSUvL08XXnih3n77bR133HEaOXKkBg4cqMzMTD3//PN69tlno/aZNGmSHnroIR1//PHKyMiQw%2BHQ%2BPHjdd9990XU%2B/DDD3XFFVdo1apV6t%...%2B7//%2B7%2BIPhVy//33G2lpacbXX39tGEZ036vMCy%%2BG6/l8PmPAgAFGWlqa8eeffxqGYRhbtmwx2rRpY/Tp0yfiM1u5cqVx0kknVamPhc7Xs2fPSr9roe9j6JmWn59vtG/f3jjnnHMijrd9%2B3bjhBNOMG655ZaI605LSzOuv/76iPv96KOPRj2Dr7nmGiM9Pd2YPXt2xHHfeustIy0tzXjqq ...

# %% [markdown]
# # Associated Exercises
#
# Now might be a good time to try exercises 1-4.
#
# # References
# 1. James, G., Witten, D., Hastie, T., & Tibshirani, R. (2013). An introduction to statistical learning. New York: springer.
# 2. Géron, A. (2017). Hands-on machine learning with Scikit-Learn and TensorFlow: concepts, tools, and techniques to build intelligent systems. " O'Reilly Media, Inc.".
# 3. Fisher, R. A. (1936). The use of multiple measurements in taxonomic problems. Annals of eugenics, 7(2), 179-188.
# 5. Murphy, K. P. (2012). Machine learning: a probabilistic perspective. MIT press.
# 6. Burges, C. J. (1998). A tutorial on support vector machines for pattern recognition. Data mining and knowledge discovery, 2(2), 121-167.
# 7. Fletcher, R. Practical Methods of Optimization. John Wiley and Sons, Inc., 2nd edition, 1987
# 8. http://web.mit.edu/6.034/wwwbob/svm-notes-long-08.pdf
# 9. https://bookdown.org/koehlerj/qr_book/introducing-the-iris-dataset.html
# 10. Raschka, Sebastian, and Vahid Mirjalili. "Python Machine Learning: Machine Learning and Deep Learning with Python." Scikit-Learn, and TensorFlow. Second edition ed (2017).

# %%
import sys
from shutil import copyfile

# where the HTML template is located
dst = os.path.join(sys.prefix, 'lib', 'site-packages', 'nbconvert', 'templates', "classic.tplx")

# If its not located where it should be
if not os.path.exists(dst):
    # uses a nb_pdf_template
    curr_path = os.path.join(os.getcwd(),"..", "Extra", "classic.tplx")
    # copy where it is meant to be
    copyfile(curr_path, dst)

   
# Create HTML notes document (preferred)
# !jupyter nbconvert 1_Maximal_Margin_Classifiers.ipynb \
    --to html \
    --output-dir . \
    --template classic
# Create html slides (issues)
# !jupyter nbconvert 1_Maximal_Margin_Classifiers.ipynb \
    --to slides \
    --output-dir . \
    --TemplateExporter.exclude_input=True \
    --TemplateExporter.exclude_output_prompt=True \
    --SlidesExporter.reveal_scroll=True

# Create pdf notes document (issues)
# !jupyter nbconvert 1_Maximal_Margin_Classifiers.ipynb \
    --to html \
    --output-dir . \
    --output 1_Maximal_Margin_Classifiers_no_code \
    --TemplateExporter.exclude_input=True \
    --TemplateExporter.exclude_output_prompt=True
# Out:
# [NbConvertApp] Converting notebook 1_Maximal_Margin_Classifiers.ipynb to html
# [NbConvertApp] Converting notebook 1_Maximal_Margin_Classifiers.ipynb to slides
# [NbConvertApp] Converting notebook 1_Maximal_Margin_Classifiers.ipynb to html
