# %%
# This line will add a button to toggle visibility of code blocks,
# for use with the HTML export version
from IPython.core.display import HTML
HTML('''<button style="margin:0 auto; display: block;" onclick="jQuery('.code_cell .input_area').toggle();
    jQuery('.prompt').toggle();">Toggle code</button>''')
# Out:
# <button style="margin:0 auto; display: block;" onclick="jQuery('.code_cell .input_area').toggle();
#     jQuery('.prompt').toggle();">Toggle code</button>

# %% [markdown]
# <img src="./Images/UoE_Horizontal_Logo_282_v1_160215.png" alt="drawing" width="600"/>
#
# # Week 8 - Support Vector Machines
# __Dr. David Elliott__
#
# 4. [Support Vector Classifier (SVC)](#svc)
#
# 5. [Support Vector Machine (SVM)](#svm)

# %% [markdown]
# __Common Notation__
#
# - $\mathbf{X}$ is a matrix containing all the feature values of all the observations
# - $n$ is the number of observations in the dataset
# - $\mathbf{x}_i$ is a vector of all the feature values (except the label) of the $i$th instance in the dataset.
# - $y_i$ is the label (desired model output) of the $i$th instance in the dataset.
# - $p$ is the number of features in the dataset
# - $\mathbf{x}_j$ is a vector of all the observations values of the $j$th feature in the dataset.

# %% [markdown]
# __Notes__
#
# We can't always perfectly separate the data with a $p − 1$ dimensional hyperplane. To overcome this problem we could either:
# - Tweak the constraints on the hyperplane to allow some points to be misclassified (_soft margin_),
# - Transform the data to be separable by a hyperplane in another space (_kernel method_).

# %%
# %matplotlib inline

import os # locating directories

import numpy as np   # Arrays
import pandas as pd  # DataFrames

# Plotting
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['animation.embed_limit'] = 30000000.0
import seaborn as sns; sns.set()

from sklearn.datasets import load_iris           # for the Iris data
from IPython.display import Image                # displaying .png images
from sklearn.svm import SVC, LinearSVC           # SVM
from mpl_toolkits.mplot3d import Axes3D          # 3d plots
from sklearn.preprocessing import StandardScaler # scaling features
from sklearn.preprocessing import LabelEncoder   # binary encoding
from sklearn.pipeline import Pipeline            # combining classifier steps
from sklearn.preprocessing import PolynomialFeatures # make PolynomialFeatures
from sklearn.datasets import make_classification, make_moons  # make example data

import itertools
from time import time
import joblib # saving models
import warnings # prevent warnings

# colours for print()
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'
    
image_dir = os.path.join(os.getcwd(),"Images")
# Initial fig number
fig_num=15

# displays the graph in the middle of the notebook
#HTML("""
#<style>
#.output_png {
#    display: table-cell;
#    text-align: center;
#    vertical-align: middle;
#}
#</style>
#""")

plt.rcParams['figure.dpi'] = 120
# golden ratio for figures ()
gr = 1.618

height_pix = 500
width_pix = height_pix*gr

height_inch = 4
width_inch = height_inch*gr

# %%
iris = load_iris(as_frame=True)  # data stored in a `sklearn.utils.Bunch`
iris_df = iris['data']           # get features DataFrame
target = iris['target']          # get target Series
# get the labels of flowers capitalised for visualisation
target_names = list(map(lambda s: s.capitalize(), iris['target_names']))

# create a dictionary with the original labels decoded (inverse of LabelEncoder)
decode_label = dict(zip(range(3), target_names))

# make a label encoder to use later if needed
le = LabelEncoder().fit(target_names)
# add the target labels to df for visualisation purposes
iris_vis = pd.concat([iris_df, target],axis=1)
# turn the ints to labels
iris_vis["target"] = iris_vis["target"].replace(decode_label)
# Capitalize column names for plotting
iris_vis.columns = [x.capitalize() for x in list(iris_vis.columns)]
# reduce the data for example
X_AX_LABEL = "Petal length (cm)"
Y_AX_LABEL = "Petal width (cm)"
REMOVE = "Virginica"

iris_reduced = iris_vis[[X_AX_LABEL, Y_AX_LABEL, "Target"]]
iris_reduced = iris_reduced[iris_reduced.Target != REMOVE]

# %%
# Centered figures in the notebook and presentation
# ...was a real pain to find this:
# https://gist.githubusercontent.com/maxalbert/800b9f06c7b2dd365ea5

import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import urllib
import base64
from io import BytesIO, StringIO

def fig2str(fig, format='svg'):
    """
    Return a string containing the raw data of the matplotlib figure in the given format.

    """
    assert isinstance(fig, matplotlib.figure.Figure)
    imgdata = BytesIO()
    fig.savefig(imgdata, format=format, bbox_inches='tight')
    imgdata.seek(0)  # rewind the data
    output = imgdata.getvalue()
    if format == 'svg':
        return output
    else:
        return urllib.parse.quote(base64.b64encode(output))

class MatplotlibFigure(object):
    """
    Thin wrapper around a matplotlib figure which provides a custom
    HTML representation that allows tweaking the appearance

    """
    def __init__(self, fig, centered=False):
        assert isinstance(fig, matplotlib.figure.Figure)
        self.centered = centered

    def _repr_html_(self):
        img_str_png = fig2str(fig, format='png')
        uri = 'data:image/png;base64,' + img_str_png
        html_repr = "<img src='{}'>".format(uri)
        if self.centered:
            html_repr = "<center>" + html_repr + "</center>"
        return html_repr

# %% [markdown]
# # 1.4. Support Vector Classifier (SVC) <a id='svc'></a>
#
# SVC's are a generalisation and extension of the maximal margin classifier so it can be applied to a broader range of cases$^1$.
#
# In practice they are more robust to individual observations and better classify most training observations than the Maximal Margin Classifier. This is because they take the approach it is better to missclassify some training examples in order to do a better job classifying the rest.
#
# This is called a *soft margin* as it allows some violations by the training data by a small subset of training observation, not only on the wrong side of the margin, but wrong side of the hyperplane.

# %% [markdown]
# __Notes__
# - _"Developed in the computer science community in the 1990s"_$^2$

# %%
def svc_decision_boundary(clf, xmin=0, xmax=5.5, highlight=True, axes_limit = [0, 5.5, 0, 2]):
    w = clf.coef_[0]
    b = clf.intercept_[0]

    # At the decision boundary, w0*x0 + w1*x1 + b = 0
    # => x1 = -w0/w1 * x0 - b/w1
    x0 = np.linspace(xmin, xmax, 200)
    decision_boundary = -w[0]/w[1] * x0 - b/w[1]

    margin = 1/w[1]
    gutter_up = decision_boundary + margin
    gutter_down = decision_boundary - margin

    svs = clf.support_vectors_
    if highlight:
        g = sns.scatterplot(x = svs[:, 0], y = svs[:, 1], s=180, facecolors='#FFAAAA')
    plt.plot(x0, decision_boundary, "g-", linewidth=2)
    plt.plot(x0, gutter_up, "r--", linewidth=2)
    plt.plot(x0, gutter_down, "r--", linewidth=2)
    
    plt.axis(axes_limit)


def soft_margin(title, hyperplane=False):
    virgin_versi = iris_vis[["Petal length (cm)", "Petal width (cm)", "Target"]]
    virgin_versi = virgin_versi[virgin_versi.Target != "Setosa"]

    X = virgin_versi[["Petal length (cm)", "Petal width (cm)"]].values
    y = virgin_versi[["Target"]].replace({'Versicolor':0, 'Virginica':1}).values.ravel()
    
    if hyperplane:
        svm_clf = SVC(kernel="linear", C=100)
        svm_clf.fit(X, y)

        svc_decision_boundary(svm_clf, 2.9, 7)
    labels = virgin_versi[["Target"]].values.ravel()
    sns.scatterplot(x = X[:,0], y = X[:,1], hue=labels, style = labels)
    plt.axis([2.9, 7, 0.9, 2.75])
    plt.title(title)
    plt.xlabel("Petal Length (cm)")
    plt.ylabel("Petal Width (cm)")
    
fig_num+=1
fig = plt.figure(figsize=(width_inch, height_inch))
soft_margin("Figure %d: No Exact Linear Separating Hyperplane"%fig_num)
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2BCgiKigjQFFERAQJpUaQLSm/SeQALpW%2Bf9I2Rh2U0jmxDgfJ6HR3NmZufOzWRzcveeO4qqqipCCCGEEEIIN5o73QAhhBBCCCEKKkmWhRBCCCGEyIAky0IIIYQQQmRAkmUhhBBCCCEyIMmyEEIIIYQQGZBkWQghhBBCiAxIsiyEEEIIIUQGJFkWQgghhBAiA5IsCyGEEEIIkQFJloUQQgghhMiAJMtCCCGEEEJkQJJlUWAtWLCAiIiILP%2BtWrXKZf8ff/zxzjbcyxwOB48//jgvv/xyhvscP36cV199lYYNG1K7dm26d%2B/OkiVLcnXe9P7dsmVLhvt8%2BOGHREREsHXr1lyd61atWrXK1vd%2B4sSJXj1vbuzZs4eNGzdmud/EiROJiIhgwYIF2d43/R6/223fvp0hQ4bQpEkTqlWrRqNGjXjmmWdYuHAhDofjTjcvT5nNZqZOneoSe%2BONN4iIiODgwYN3pE1nz54lIiKCqKioTPeLiooiIiKCs2fP5lPL8k9ERARdunS5080QBZzuTjdAiKxERkYSGRmZ4fZy5coBULlyZQYNGkStWrXyqWX5Y8yYMezZs4fWrVt73L5//3769euHzWajY8eO%2BPn5sWLFCoYNG8aVK1d46qmncnX%2B9957j0WLFmE0GnP1Ordj0KBBmW7P7L7IT2vXrmXAgAG8/vrrNGnSxGuvGxkZyaBBg5z3%2BN1s6tSpfPzxxxQuXJjmzZsTGhrK5cuX%2Bfvvv3n99df5448/mDRpEnq9/k43NU/07duXEydO8Mwzzzhjbdq0oWTJkoSGht7BlgkhsiLJsijwIiMjeeWVV7Lcr3LlylSuXDkfWpQ/UlNTeeedd1i0aFGG%2BzgcDt58803sdjszZ86kRo0aALzyyis8%2BuijjB8/nieffDJXie7Jkyf5%2Buuvee211277NW5Xdr7vBUFsbGyejIw2aNCABg0aeP1189uZM2f45JNPqFWrFj/%2B%2BCM%2BPj7ObWazmVdeeYV169bx008/5fqPu4LqypUrbrE2bdrQpk2bO9AaIUROyDQMIQqgv//%2Bm06dOrFo0aJMRyq3bdvG4cOHeeqpp5yJMkBQUBCvvvoqjz76qMdf0tkVFhZGcHAwP/zwA4cOHbrt1xH3t3Xr1uFwOHjiiSdcEmUAo9HIm2%2B%%2BRkJCQreNzatGiRURERPDYY4%2B5tPHq1as0adKEWrVqcfLkSWd8x44dDBo0yDl3tn79%2BvTv39/j/OzY2FjGjh1Lq1atqFGjBu3bt2f8%2BPEkJSUBafNO05O9jz76yKtzOz3NWY6IiOCNN95g586dREVFUbt2berXr8%2Brr77q8bynTp1y%2BV506NCBb7/9FqvV6rZvdvslq/v/VjabDYAjR4543F6uXDm%2B/PJLj59eLFu2jCeffJLatWtTp04dnnrqKbf2pM%2B9HT9%2BPMuWLaNTp07O79XUqVM93rcLFy4kKiqK%2BvXrU61aNZo0acKwYcM4c%2BaMy37p/T158mTq1atHvXr1nO8xSUlJfP3113Tp0oXatWtTvXp12rVrx//%2B9z%2BSk5Nd2nbu3DkSEhKcrwfuc5bT9504cSKrV6%2BmR48e1KhRg0aNGvH2228TGxvrdh3Lly%2BnR48e1K5dm6ZNm/Lpp5/y999/Z3te/O146qmniIiI4NSpU27bFi5cSEREBPPmzQPS3ld79erFoUOHiIqKombNmjRt2pTRo0dz9epVt%2BNjYmIYNWoUzZo1o1q1arRq1YpPPvmExMREl/0yuwcjIiIYPnw4W7ZscfZhq1atGD9%2BPGazOcvri42N5eOPP6ZDhw7UrFmTmjVr0qlTJyZPnuy8l%2BHG74YFCxbw66%2B/0rlzZ6pXr06zZs34%2BOOPSUlJcXvtzZs3079/f%2BrWrUutWrV44oknWL58eZZtEneWJMvinrZixQqeffZZDh06RPv27enYsSN//vlnpsVy2RUXF8err75KnTp16NatmzPRXrduHU8%2B%2BSRbtmyhZcuW9O3bF4fDwahRo3j33Xez9do9evRg1apVdO/ePdP9jh49CkCZMmX48ssvadWqFdWrV6dLly4e34C7devGoEGDKFmyZLavs1u3bjz00EPs2bOHmTNnZrn/7t27eeyxx/jjjz%2BoVasWffr0oXDhwvzwww/07NnT4y/I3Hr00Udp2bIl%2B/fvZ/bs2c746NGjiYmJYcSIETzwwAMArFq1iqioKP7991/atGnDU089Re3atdm8eTPPPvusS7FVTEwMPXr0YPr06ZQqVYo%2BffpQvHhxJk%2BezMCBA7HZbLRp08Y5n7xJkyYMGjSIwMBAr1/jzdLnqWs0Gnr16kVERATLli3j6aefxmKxuOzXvXt3li9fTsOGDXn66acJCgri888/Z8CAAdjtdue%2BOekXyPj%2B96RRo0YA/Pjjj4wYMYLNmze7tBPg4Ycfpk6dOi6xL7/8kldffZXo6Gi6detGt27d%2BO%2B//%2Bjfvz%2B///6723k2bNjA0KFDKV26NE8%2B%2BSQAH3/8MW%2B99ZbLfh9//DGvv/468fHxdOvWjT59%2BlC0aFGWLFlCVFQUqampbq/73Xff0bVrV5o0aULNmjWx2Wz079%2BfiRMnUqRIEXr37k337t1JTU3lhx9%2BcCbEgYGBDBo0iICAAAwGA4MGDcpy6sVff/3FoEGDKFKkCFFRURQrVoxffvnF7X1r%2BvTpDBkyhIsXL9KlSxeaNWvGrFmzsv0%2Bc7u6du0KwOLFi922pdc3dOjQwRmLjo6mX79%2BJCYm0qdPH8qUKcPs2bPp27ev849OgPPnz9OjRw/mzJlD1apVefrppylXrhzff/89UVFRzj9A0mV2Dx4%2BfJjnnnsOHx8f%2BvTpQ1BQEJMnT%2BaFF17I9I/%2BhIQEevbsyYwZM6hYsSL9%2BvXjkUceISYmhvHjx/PZZ5%2B5HTNr1ixGjRrFgw8%2BSFRUFEajkalTp/L222%2B77PfLL7/Qv39/Dh8%2BTMeOHXniiSe4cuUKQ4YMYfLkyZl3urizVCEKqPnz56vh4eFq37591QkTJnj8d%2BbMGbf9p02bpqqqqiYlJakPPfSQWr9%2BffXEiRPO/c6dO6dGRkaq4eHh6oQJE5zxli1bqnXr1nVrx5YtW9Tw8HB1zJgxzljfvn3V8PBw9aOPPnLZNzk5WW3YsKHaqFEjl7bZ7Xb1lVdeUcPDw9W1a9fmqB/OnDmjhoeHqwMGDHDb9uijj6rVqlVT%2B/fvr0ZGRqojR45UR44cqdavX18NDw9XZ8%2BenaNz3Sw8PFx99NFHVVVV1VOnTqk1atRQa9WqpZ47d865z5gxY9Tw8HB1y5Ytqqqqqs1mU9u1a6dWqVJFXbduncvrffLJJ2p4eLj65ptvZnnuli1bOr8/Gf379ttvXY65dOmSWr9%2BfbVOnTpqdHS0unz5cjU8PFx99tlnXfZr3769GhkZqcbExLjEp0yZooaHh6ufffaZM/Z///d/LvdUunfeeUcNDw9X//zzT1VV3e%2B9zEyYMEENDw9X58%2Bfn%2B19V65c6YyFh4er4eHh6nfffeeMORwO9ZlnnlHDw8Od/e5wONRHHnlErV69urp3716X1x07dqw ...

# %%
fig_num+=1
fig = plt.figure(figsize=(width_inch, height_inch))
soft_margin("Figure %d: Soft Margin Hyperplane"%fig_num, hyperplane=True)
plt.savefig(os.path.join(image_dir,"Soft_Margin_Hyperplane.png"))
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2B/sjNDRNOqBpWsp5v168tM%2B9N/fk9CZ98uScc2WSJEkIgiAIgiAIgmBHXtQNEARBEARBEITiSiTLgiAIgiAIgpADkSwLgiAIgiAIQg5EsiwIgiAIgiAIORDJsiAIgiAIgiDkQCTLgiAIgiAIgpADkSwLgiAIgiAIQg5EsiwIgiAIgiAIORDJsiAIgiAIgiDkQCTLgiAIgiAIgpADkSwLgiAIgiAIQg5EsiwIj6Dly5dTvXr1PP9t2bLFZv8///yzaBvuZGazmX79%2BjFy5Ei7bR9%2B%2BGGe/fPhhx8%2B9Lnj4%2BP55ptv6NatG/Xr16dhw4Z0796db7/9lvj4%2BII8LQCmT59OmzZtqFOnDq1atSIjIwOdTsesWbPydXzmc2zQoAE6nS7X51GrVq0C94czZP7Ozp4967TH3L9/f76eW7t27ahevbrTzltc3Lx5k%2BrVqzt8jQiCkD/Kom6AIAgPLzw8nPDw8By3V6pUCYCaNWsyatQo6tev76KWucakSZM4ceIE7du3t9vWoUMHypQp4/C4RYsWERsbS5MmTR7qvJcvX2bQoEEkJyfTunVrWrdujdFo5MyZM/zxxx8sWbKEv/76ixo1ajzU4%2B/atYvvvvuO4OBghg4dikajwd3dnX79%2BnHlyhVefPHFfD9Weno6u3fvdthHAJs3b8ZkMj1UO50t83cWGBhY1E0RBEGwEsmyIDzCwsPDefPNN/Pcr2bNmtSsWdMFLXINrVbLJ598wurVq3Pcp0OHDnTo0MEuvnnzZmJjY3nuuefo06fPQ51//PjxpKWlsWDBArsPICtXruSDDz7go48%2BYsWKFQ/1%2BGfOnAHgrbfeol%2B/ftb43bt3H%2BhxSpUqRXx8PJs3b84xWd64cSMeHh6kp6c/VFudKaffmSAIQlESwzAEQXik/PfffzzzzDOsXr2ali1bPtCxycnJfPLJJ5QqVYpx48Y91PnT0tI4cOAA9evXd1ip79mzJw0aNODMmTPcuHHjoc6h1%2BsB8Pf3f6jjMwUFBVGvXj22b9%2BO0Wi0256YmMj%2B/ftp165dgc4jCIJQkolkWRAeAzmNWd67dy8RERE0atSIZs2a8emnnxIZGUn16tWZOnWqdb927drRuHFju8fNHA/6xRdfWGMRERG0a9eOHTt20K5dO%2BrVq8fbb79t3X769GlGjhxJ06ZNqVu3Lj169ODvv/9GkqR8PZfVq1eTlpbG5MmT%2Beyzzx6oH3777TcSEhJ499138fX1tdkWERFB9erV2b9/f66PkZl0Xr9%2BHa1W63CfsWPH8vvvv9sluydOnLA%2B9yeffJJu3brx22%2B/WZNjsIw1njZtGgBvvPEG1atXt/7%2Bbt26RUpKygONL%2B7UqROJiYkcPHjQbtuWLVswGo107tzZ4bG3bt1i/PjxdOjQgSeffJIGDRrQu3dv/v77b5v9pk6dSvXq1dm7dy/9%2BvWjTp06dO7cmbS0NMDyO3/11VcJDw%2BnUaNGvPvuu0RHR1OrVi2b55F9zHLmeNupU6eydetW%2BvbtS926dWnevDnjxo1zytjwnHTs2JF69eqRmppqt23atGlUr16dPXv2AJbf2ejRo9m3b5%2B1je3atWPKlCkOx4tfu3aN0aNH06JFC%2BrUqUPXrl35/fffMRgMNvu1a9eOiIgIli1bRosWLWjQoAFfffWVtV%2BmTJnC%2BvXreeaZZ6hbty6dO3dm1qxZmM3mPJ9ffn%2B3mdfe3r17mTlzJp06daJOnTp06NCBX3/91eEQnvXr1zNgwAAaNGhAw4YNeeGFF9i3b1%2BebRKE4koky4LwmNq0aRMvvfQS586do3PnznTr1o2NGzc6ZSJQQkIC77zzDg0bNqRXr17WRHvHjh0MGDCAffv20bZtW4YMGYLZbGbChAl8%2Bumn%2BXrsvn37smXLlgceQhEdHc28efOoXLkyvXv3ttveq1cvRo0aleM450y%2Bvr7Url2bqKgo%2Bvfvz9KlS4mLi7PZp27durRp0wYvLy9rbMuWLQwcOJBdu3bRokULBgwYgEKhYMqUKQwfPtyaMI8aNco6Dr1bt26MGjXKOubc29sbtVrNqFGj8j1coVOnToDl953dxo0bqV27NuXKlbPbdvPmTfr06cPKlSupX78%2Bw4YNo2PHjly6dIkJEyYwb948u2NGjx6Nm5sbERERNG3aFE9PT44ePcrgwYP577//aN26NX379uXIkSMMHDgw3x%2BQtm/fzqhRowgKCiIiIoKQkBCWLFlSqJPWevTogVartU6SzWrNmjWEhITQvHlza%2Bz8%2BfOMGDECd3d3Bg8ejK%2BvL7/99huvvPKKTfJ6%2BvRp%2BvTpw4YNG2jWrBnDhg3D19eX77//ntdff90u%2Bbxw4QITJ06kQ4cOdOnSxebbjF27dvHuu%2B9Srlw5BgwYAMDXX3/N2LFjc31uD/O7/d///se0adNo1KgRgwcPRqvV8sMPP/DTTz/Z7Pfjjz/yzjvvEBMTQ69evejVqxcXL15k%2BPDhrFq1Ktd2CUJxJcYsC8Ij7MCBAzYV4Kx69epF2bJlHW5LT0/ns88%2Bw8vLi8WLF1OxYkUARowYQa9evQrcrvT0dIYPH25TNczIyODDDz/E29ubxYsXW9s2evRo3nnnHRYvXkyHDh14%2Bumnc31sRxXu/FiwYAE6nY4XX3wRhUJht91RAp2TL7/8kuHDh3P%2B/Hk%2B/vhjAKpWrUrTpk1p27YtLVq0sDlHamoqY8eOxc3NjTlz5lC7dm3AUqX%2B8MMPWbNmDX/88QdvvPEGb775JlOnTuXAgQM888wz1qS4Zs2arFixguTk5HyNU89Urlw5atWqxZYtW/j000%2BRyWSAZUjK3r17eeuttxweN336dBISEpg9ezYtWrSwxocMGUK/fv1Yu3YtQ4YMsTkmNDSUv/76C7n8fh3m008/xWAwMH/%2BfGuiN3LkSPr375%2BvCihYEswffviBrl27AvDOO%2B/Qq1cvjh49yqVLl6hSpUqej3H27NkcXytg6Y%2BsevTowbRp01i7di09e/a0xk%2BcOMHVq1d56aWXbJ5nZGQkgwcPtn7oMxqNvPPOO2zevJmVK1fSu3dvJEniww8/RK/Xs3DhQurUqWM9/ssvv%2BTPP/9k4cKFDB482BpPSEhg3LhxREREWGM3b9609suYMWN46aWXrP0yfPhwVqxYQa9evWjatKnD5/owv9vr16%2BzcuVKKlSoAFi%2BienSpQtLly7l3XfftfbNr7/%2BSnh4ONOnT8fd3R2wfAB8/vnnGT9%2BPK1atSIgICDH34MgFEeisiwIj7ADBw4wbdo0h/9u3bqV43G7d%2B8mLi6OwYMHWxNlgLCwMIYPH%2B6UtmVWNDNt27aN%2BPh4XnrpJZskXi6X8/777wOwbNkyp5w7O71ez%2BLFiwkKCqJHjx4Ffrzq1auzdu1aXnnlFWsl%2BuLFi8yfP58RI0bQs2dP6yQ9sFSVk5KSGDp0qDVRBlAqldYkurCeO1h%2BFzExMRw/ftwa27ZtGwaDgS5dujg85rnnnmPy5Mk2yRRYquZubm4OJxt27NjRJoE8ffo0kZGRPPPMMzYVUV9fX0aNGpXv9pcrV86aKAOoVCprVTe36zyrc%2BfO5fhamTZtGikpKXbnbNSoEXv37rUZ7pE5qTT7deTh4WEz3EipVDJmzBjAUokGOH78OJGRkfTt29cmUQZ4%2B%2B23UalULF%2B%2B3K7t2V9LmcqUKcMLL7xg04Z33nnH5pyOPMzvtlOnTtZEGaBs2bJUqVKFuLg461CTpUuXIkkSY8aMsSbKYBl7//LLL5ORkcH69etzbJcgFFeisiwIj7BRo0Y9UJUx08mTJwHLH8fsGjZsWOB2AXZV7VOnTgGWBMpRhU%2BhUHD ...

# %% [markdown]
# We want to relax the following constraints when necessary:
#
# $$
# \mathbf{w}^{\mathrm T}\mathbf{x}_i + b \geq 1 \text{ for } y_i = 1, \\
# \mathbf{w}^{\mathrm T}\mathbf{x}_i + b \leq -1 \text{ for } y_i = -1
# $$
#
# This can be done by introducing positive slack variables $\xi_i, i = 1, \ldots, n$ in the constraints$^{5,6,10}$:
#
# $$
# \mathbf{w}^{\mathrm T}\mathbf{x}_i + b \geq 1 - \xi_i \quad \text{if} \ y_i = 1, \\
# \mathbf{w}^{\mathrm T}\mathbf{x}_i + b \leq -1 + \xi_i \quad \text{if} \ y_i = -1, \\
# \xi_i \geq 0 \quad \forall_i.
# $$

# %% [markdown]
# __Notes__
#
# - Slack variable $\xi_1,..., \xi_n$ allow individual observations to be on the wrong side of the margin or hyperplane.
# - $\sum_i\xi_i$ is an upper bound on the number of training errors.
# - $\xi_i$ tells us where the $i$th observation is located relative to the hyperplane; $\xi_i = 0$ being on the correct side of the margin, $\xi_i > 0$ being on the wrong side of the margin, and $\xi_i > 1$ on the wrong side of the hyperplane.
# - $\xi_1 = ... = \xi_n = 0$ is the maximal margin hyperplane optimisation.
# - Test observations are classified as before, $f(x^*) = \beta_0 + \beta_1x^*_1 + ... + \beta_px^*_p$.

# %% [markdown]
# ## Tuning Parameter (C)
#
# To ensure there is a penelty, $C$, for relaxing the constraint, we can change our objective function to be minimised from $\frac{1}{2}||\mathbf{w}||^2$ to,
#
# $$
# \begin{align}
# {\text{minimise}  \atop \mathbf{w}, b, \xi } & \quad \frac{1}{2}||\mathbf{w}||^2+C\sum\limits_{i=1}^n\xi_i, \\
# \text{subject to}                            & \quad y_i(\mathbf{w}^{\mathrm T}\mathbf{x}_i+b) \geq 1-\xi_i, \quad \xi_i \geq 0, \quad \forall_i.
# \end{align}
# $$
#
# $C$ is a tuning parameter that controls the bias-variance trade-off$^1$.
#
# The strength of the regularization is inversely proportional to $C$, meaning a large $C$ has a larger error penalty.

# %%
def soft_margin(c_list, main_title):
    virgin_versi = iris_vis[["Petal length (cm)", "Petal width (cm)", "Target"]]
    virgin_versi = virgin_versi[virgin_versi.Target != "Setosa"]

    X = virgin_versi[["Petal length (cm)", "Petal width (cm)"]].values
    y = virgin_versi[["Target"]].replace({'Versicolor':0, 'Virginica':1}).values.ravel()

    scaler = StandardScaler()
    svm_clf1 = LinearSVC(C=c_list[0], loss="hinge", random_state=42)
    svm_clf2 = LinearSVC(C=c_list[1], loss="hinge", random_state=42)

    scaled_svm_clf1 = Pipeline([
            ("scaler", scaler),
            ("linear_svc", svm_clf1),
        ])
    scaled_svm_clf2 = Pipeline([
            ("scaler", scaler),
            ("linear_svc", svm_clf2),
        ])

    scaled_svm_clf1.fit(X, y)
    scaled_svm_clf2.fit(X, y)

    # Convert to unscaled parameters
    b1 = svm_clf1.decision_function([-scaler.mean_ / scaler.scale_])
    b2 = svm_clf2.decision_function([-scaler.mean_ / scaler.scale_])
    w1 = svm_clf1.coef_[0] / scaler.scale_
    w2 = svm_clf2.coef_[0] / scaler.scale_
    svm_clf1.intercept_ = np.array([b1])
    svm_clf2.intercept_ = np.array([b2])
    svm_clf1.coef_ = np.array([w1])
    svm_clf2.coef_ = np.array([w2])

    # Find support vectors (LinearSVC does not do this automatically)
    t = y * 2 - 1
    support_vectors_idx1 = (t * (X.dot(w1) + b1) < 1).ravel()
    support_vectors_idx2 = (t * (X.dot(w2) + b2) < 1).ravel()
    svm_clf1.support_vectors_ = X[support_vectors_idx1]
    svm_clf2.support_vectors_ = X[support_vectors_idx2]

    fig, axes = plt.subplots(ncols=2, figsize=(width_inch*2, height_inch*1.5), sharey=True)

    plt.sca(axes[0])
    svc_decision_boundary(svm_clf1, 3, 7)
    legend_labels = virgin_versi[["Target"]].values.ravel()
    sns.scatterplot(x = X[:,0], y = X[:,1], hue=legend_labels, style = legend_labels)
    plt.xlabel("Petal length", fontsize=14)
    plt.ylabel("Petal width", fontsize=14)
    plt.legend(loc="upper left", fontsize=14)
    plt.title("$C = {}$".format(svm_clf1.C), fontsize=16)
    plt.axis([2.9, 7, 0.9, 2.75])

    plt.sca(axes[1])
    svc_decision_boundary(svm_clf2, 3, 7)
    g = sns.scatterplot(x = X[:,0], y = X[:,1], hue=legend_labels, style = legend_labels, legend=False)
    plt.xlabel("Petal length", fontsize=14)
    plt.title("$C = {}$".format(svm_clf2.C), fontsize=16)
    plt.axis([2.9, 7, 0.9, 2.75])
    plt.suptitle(main_title)
    plt.tight_layout()
    
    return fig

fig_num+=1
fig = soft_margin([1,100], "Figure %d: Tuning Parameter `C`"%fig_num)
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%%2B/Dq1Wi3r16uGFF15Ax44d/1MOsbGx6Ny58x0fN2LECIwcOfI/vfadmDNnDubOnYtHH320xLFyhoLc7FEoFNBoNAgJCUHr1q0xePBgREZG3uMMy6eLFy%2BievXqzk6j1CRJwh9//IF169bh%2BPHjSE5OhkqlQlhYGFq3bo3%2B/fujatWqzk6TiIiIqFJg4Z%2BIiIjIQWrVqgUPD48S92HBs5DRaMRbb72F7OzsEvdLSkpCv379EBMTA5VKhfvuuw/p6enYs2cP9uzZg5EjR2LEiBF3nYdGo0GTJk2KxOPj4xEfHw8PDw/UqlWryPbQ0NC7fs2Kyt5YWa1WZGVl4dq1a7h06RJ%2B%2B%2B03fPXVV2jZsqWTsnR92dnZmD59OrZs2YLdu3c7LY/4%2BHj06dMHCQkJ6N69Oz777LNi901MTMSbb76JgwcPAgB0Oh2qVasGvV6PK1eu4MKFC/jpp5/w9ttvY%2BDAgTbHjhs3Dr/99hs8PT2xbds2%2BPj4lOXbIiIiIqoUBEmSJGcnQURERFSeFcz4X7JkyR0VM69fvw69Xo/AwEB4eXmVVXouKScnB2%2B%2B%2BSb%2B%2BusvAChxFvvIkSOxZcsW1KpVC/PmzZNvnvz44494//33AQDLly9H06ZNHZpjwSz2Fi1aYOnSpQ49991IS0tDeno6PDw8EBwc7Ox0bJRmrOLj4zF8%2BHCcOnUKISEh2Lx5M7Ra7T3OtHzYt28fBg4cCB8fH%2Bzbt8%2BpuZw/fx7PP/88srKysHbtWtSsWbPIPrGxsXjuueeQkpKCBx54AG%2B88QYeeugheXtaWhrmzZsnfzbee%2B899OvXT95uNpsxbNgw/P3333j55Zfx1ltvlf0bIyIiIqrg2OOfiIiIyEnCwsJQvXr1Slf0P3nyJHr37i0X/UuSnZ2NP/74AwAwefJkmycm%2Bvbti0cffRQAsHr16rJI1aX4%2BfmhevXqLlf0L63Q0FB89tlnEAQBCQkJ2L59u7NTolKoWbMm5s2bB5VKhZkzZxbZbrVa8fbbbyMlJQVNmjTBsmXLbIr%2BQP5nd9KkSRgyZAgA4NNPP0ViYqK8XalUYtasWWjYsCF%2B%2BOEHm21EREREdHdY%2BCciIiKie2b%2B/Pno3bs3Ll68iIYNG6JPnz4l7p%2BSkgKLxQIAdtvt1KtXD0D%2B0xPk%2BqpXr44qVaoAAE6cOOHkbKi0mjVrhuPHj2PevHlFtq1ZswaHDh2CUqnEp59%2BCp1OV%2Bx5hg0bBj8/P%2Bj1evzyyy8229zc3PDzzz/j2LFj5fbmFhEREZErYeGfiIiIyEkGDBiA2rVr44cffiiybc%2BePXj55ZfRpk0bNG7cGH379sUff/yBffv2oXbt2hgwYIC8b2xsLGrXro3atWsjJyenyLmio6Pl7fZe//Dhw/jggw/QpEkTNGnSBIMGDYLVapX3O3DgAIYPH442bdqgXr16aN%2B%2BPSZMmICrV6/e8Xs%2BceIENBoNXn/9dSxfvhwBAQEl7h8YGAiFQgEAOHPmTJHt58%2BfB5D/9MStVq1aZfc9O1rB6/Ts2dPu9h9%2B%2BKHIvxcAdOrUCbVr10ZaWhq2bNmCfv36oUmTJmjcuDH69OmD33//vci55syZg9q1a2PUqFFyrODfvlu3bjCbzfjmm2/QrVs3NGjQAC1btsSwYcOKLbDn5eVh4cKF6N69Oxo1aoTWrVtj7NixiI%2BPx7hx41C7dm2sWrXqP4yOfZ6engBQ5LOanZ2NBQsWoE%2BfPmjZsiXq1q2LFi1aoH///vjll19sPpNA4Xh89913WL58Odq1a4cGDRqgW7duNp/NP//8EyNHjkT79u1Rv359NG7cGI8//jimTZuG5OTkIvnVrl0bzZo1gyRJWL58Obp3746GDRviwQcfxLhx45CamgoAOH36NIYOHYrmzZujQYMGeO655/D333/bfc9WqxWrVq3C888/j2bNmqFBgwbo2rUrvvjiC2RlZdnsO2DAALkH/o0bN%2Bx%2Bju/kfADkf8%2BNGzdizpw5aNmyJRo1aoSePXvedo2N2/n1118BAA8//PBt1zDRarX4%2BOOPsWzZMrzyyiv/6XWJiIiIqGRc3JeIiIjIxSxcuBCffPIJACAoKAj33XcfTp06hWHDhqFz584Of71PPvkER48eRa1atXDjxg0EBgZCFPPnh8ybNw%2BzZs0CAPj6%2BqJWrVqIiYnBr7/%2Big0bNmDWrFlo3759qV%2BrR48eeP/99xEUFFSq/d3d3fH4449j/fr1%2BOCDDzB//nyEh4cDANatW4f169dDqVTi2WefvcN37Rrmz5%2BPJUuWQKfToWrVqrh%2B/TqOHDmCI0eOIDk5GYMGDSrVecxmM4YMGYJdu3YhICAA1atXx4ULF/DHH39g586dWLp0KRo1aiTvn52djVdeeQWHDh2CKIqoWbMmDAYDVq9ejR07dsiz8stCTEwMACAkJESOXb9%2BHQMHDkRMTAzUajWioqIQGhqKmJgYHDhwAAcOHMCJEyfw4YcfFjnfli1bcPToUYSHhyM8PBy5ublyAXrixIlYuXIlgPybQ7Vq1UJKSgouXbqES5cuYePGjVizZg18fX1tzilJEsaMGYP169cjNDQUUVFRuHjxIn777TecOnUKo0ePxogRI6BUKlG1alXExcXh6NGjGDp0KJYsWYLmzZvL5zIajRg5cqTc2io8PBze3t44f/485s%2Bfj/Xr12PRokVyzgU/h9HR0VAqlWjQoIFNbnd6vlstXrwYR48eRdWqVWE2m6HVam%2B7IHlJDAYDjhw5AgBo3bp1qY65k98XRERERHT3WPgnIiIiciHHjx/Hp59%2BClEU8e6776JPnz4QBAHp6ekYO3as3O/ekY4ePYq5c%2Bfi4YcfhtVqRWZmJoD8guqsWbPg4eGByZMno2vXrgAAk8mEb775BrNmzcKbb76JdevWFZlxX5xHHnnkjvObPHkyrFYrNm7ciEcffRT33XcfsrKyEB8fj9DQULz77ruoX7%2B%2BzTEPP/wwGjZseMevda8tWbIEQ4cOxfDhw6FWq2E0GjFu3Dj8/vvvmDt3Lp5//nmoVKrbnufy5ctITEzEzJkz5X%2BnpKQkDB48GBcuXMCXX36Jb775Rt7/888/x6FDhxAVFYX58%2BejRo0aAICDBw9ixIgRcjHX0dasWYMbN24AsC0AT5s2DTExMWjevDlmz54NPz8/APlF7pkzZ2LhwoX4%2BeefMXLkSAQGBtqc8%2BjRo3jhhRcwfvx4CIKAtLQ0iKKI7du3Y%2BXKldDpdJg/fz5atWolH7N//34MGTIEiYmJWLlyJf73v//ZnDM7OxubNm3CJ598gh49egDIf/JlwIABiI6OxquvvoonnngCH374IXQ6HXJycvDSSy/hyJEj%2BP77720K/59%2B%2Bin%2B%2BusvVK9eHdOnT8cDDzwAAEhPT8e7776LLVu24LXXXsPKlSshiiLeeecdeXFfDw8P/Pjjjza53en5/j1W48ePl28opaWl3ck/XxHXrl2D2WwGALuL/hIRERGR87DVDxEREZGD ...

# %% [markdown]
# __Extra__
#
# Neither the $\xi_i$ or their Lagrange multipliers appear in the Wolfe dual problem. This means we now have$^6$:
#
# $\text{max} L_D \equiv \sum_i^n\alpha_i - \frac{1}{2}\sum^n_{i,k}\alpha_i\alpha_ky_iy_k\mathbf{x}_i\cdot \mathbf{x}_k \quad \text{s.t.} \quad 0 \leq \alpha_i \leq C, \quad \sum_i\alpha_iy_i = 0$.
#
# This also has the same solution as before:
#
# $\mathbf{\hat w} = \sum\limits^{N_S}_{i=1}\alpha_iy_i\mathbf{x}_i$.
#
# Also, sometimes $C$ is defined as $C = \frac{1}{\nu N}$, where $0 < \nu \leq 1$ controls the fraction of misclasified points during the training phase$^7$.

# %% [markdown]
# __Notes__
#
# - Alike to maximal margin classifiers, SVC's only rely on a few observations, those on the margin or those that violate the margin (*Support Vectors*).
#     - If they are on the correct side of the margin they dont change the classifier.
#     - This does mean that they are robust to observations far away from the hyperplane.
# - When $C$ is large we have narrow margins rarely violated, but highly fit to the training data (low bias-high variance).
# - Coversely, when smaller it is less strict about missclassification errors, meaning the margin is wider (high bias-low variance).
# - Like most hyper-parameters, it is often chosen using cross-validation.

# %% [markdown]
# # 1.5. Support Vector Machine (SVM) <a id='svm'></a>
# Aims to address the situation where the boundary between two classes is not linear.

# %%
from sklearn.preprocessing import PolynomialFeatures
import warnings

nl1, y1 = make_classification(n_samples=300, n_features=2,
                              n_redundant=0, n_informative= 2, 
                              n_classes=3, n_clusters_per_class=1, 
                              random_state=14, class_sep=30, 
                              hypercube=False)
y1 = np.where(y1==1,0,y1)
y1 = np.where(y1==2,1,y1)

nl2, y2 = make_moons(n_samples=300, noise=0.15, random_state=42)

def non_linear_examples(main_title):
    fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(width_inch*2, height_inch*2))
    axes = axes.flatten()
    plt.sca(axes[0])
    sns.scatterplot(nl1[:,0], nl1[:,1], y1, legend=False)
    plt.axis([-5, 5.5, -8, 8])

    plt.sca(axes[1])
    sns.scatterplot(nl2[:,0], nl2[:,1], y2, legend=False)
    
    svm_clf1 = LinearSVC(random_state=42).fit(nl1, y1)
    svm_clf2 = LinearSVC(random_state=42).fit(nl2, y2)

    # Convert to unscaled parameters
    b1 = svm_clf1.intercept_[0]
    b2 = svm_clf2.intercept_[0]
    w1 = svm_clf1.coef_[0]
    w2 = svm_clf2.coef_[0]

    # Find support vectors (LinearSVC does not do this automatically)
    t1 = y1 * 2 - 1
    t2 = y2 * 2 - 1
    support_vectors_idx1 = (t1 * (nl1.dot(w1) + b1) < 1).ravel()
    support_vectors_idx2 = (t2 * (nl2.dot(w2) + b2) < 1).ravel()
    svm_clf1.support_vectors_ = nl1[support_vectors_idx1]
    svm_clf2.support_vectors_ = nl2[support_vectors_idx2]

    plt.sca(axes[2])
    svc_decision_boundary(svm_clf1, -5, 4, highlight=False, axes_limit = [-5, 5.5, -8, 8])
    sns.scatterplot(nl1[:,0], nl1[:,1], y1, legend=False)

    plt.sca(axes[3])
    svc_decision_boundary(svm_clf2, -1.5, 2.5, highlight=False, axes_limit = [-1.5, 2.5, -1, 1.5])
    sns.scatterplot(nl2[:,0], nl2[:,1], y2, legend=False)
    
    plt.suptitle(main_title)
    plt.tight_layout()
    
    return fig
    
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fig_num+=1
    fig = non_linear_examples("Figure %d: Linear SVM on Non-Linear Data"%fig_num)
    plt.close()
    display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2B9XcAAAAOXRFWHRTb2Z0d2FyZQBNYXRwbG90bGliIHZlcnNpb24zLjMuNCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8QVMy6AAAACXBIWXMAABJ0AAASdAHeZh94AAEAAElEQVR4nOzdd3wVVfrH8c%2BUmx5ICCFAKIEAofdeREFBxcrau2t3V11dd%2B269rI/de3dtaxdUAQb0qQ36b2GEjqB9HLvzPz%2BiLkmplGSUPy%2BXy9fwsyZmXMnN9w7zznneQzP8zxEREREREREREREROS4YB7pDoiIiIiIiIiIiIiISPVR4F9ERERERERERERE5DiiwL%...%2BZM2fOAV//SCv5ep9//vkq2x/t/6bMmTMn%2BHoORvExa9asqaGeHV2K/y36/X/t2rWjW7duDBkyhJtvvpkff/yxRq6fnZ1drf%2B2ioiIiFQ3%2B0h3QERERP5Y2rRpQ1RUVKVtmjZtWku9OfoVFhbyj3/8g%2Bzs7ErbLVy4kOuvv57MzEx8Ph9t2rRh7969fPjhh3zzzTe8/vrrdO/evZZ6LVAUkH/vvffwPI%2B4uDhatWpFfn4%2BaWlpjB49mtGjR3PGGWfw9NNPY9tFX8vPPfdcPv74YzZt2sSyZcvo2LFjpddwXZdvv/0WoMKBlZ9%2B%2Bomrrrqq0vPMmjWL/fv3H/RrPNq88847nHbaabRt2/ZId0VqSVxcHM2bNw/%2B3fM8cnJy2Lp1KxMnTmTixIkMHDiQF154ocrPngM1btw4nnrqKR599FESEhKq5ZwiIiIi1U2BfxEREalV999/P3369Dng9k8//TR5eXnEx8fXYK%2BOTjk5Odxxxx1Vzr7OysrilltuITMzk%2B7du/Of//wnGIz65JNPeOSRR7j%2B%2BusZP3489erVq42ul3LKKafQpUsXwsLCav3aR8onn3zCf//7X%2BrXr8%2Bzzz5L3759g/scx2H06NE88cQTjBs3jvj4%2BOAKis6dO9OyZUs2bNjAd999V2Xgf86cOezatYvw8HBOO%2B20Mvtt22bBggXs3buXuLi4Cs9TU7Oia5vf7%2BeBBx7gs88%2BwzT/WIubv/vuO%2BCPN3B6wgkn8NRTT5XZ7jgOEyZM4MEHH2T69OncdtttvPHGG8FBtsPx3HPPsXv37sM%2Bj4iIiEhN%2BmN9GxYREZFjTuPGjUlOTqZOnTpHuiu1atmyZZx//vlMmTKlyrZffPEFu3fvJi4ujtdee63UDNSLL76Yc845h6ysLF588cUa7HHFoqOjSU5OJjEx8Yhc/0h46623AHjkkUdKBf0BLMvi/PPP5/777wfg448/LjXb/pxzzgHghx9%2BwPO8Sq/zzTffAHDyySeXO5u5d%2B/euK7LhAkTKjxHcYC0UaNGxMTEVPXSjmqGYbBkyRI%2B%2BOCDI92VWpecnExycjIhISFHuitHBcuyGD58OO%2B88w4%2Bn4/p06fz1VdfHeluiYiIiNQaBf5FREREjjKvvfYa559/PuvXr6dLly5cdNFFlbafMWMGUJQmprzA7SWXXALAt99%2Bi%2Bu61d5fKS0jI4O0tDQAOnXqVGG7M888k7CwMAoKCkrlZT/77LMxTZO0tDQWLVpU4fEFBQWMHz8eqDjNT3GtgOJ25ZkzZw779u1j%2BPDhFbY5Vlx44YUAvPDCC2zduvUI90aOBh07duSyyy4D4PXXX69yME1ERETkeKHAv4iIiBzVKivEOWvWLK699lr69%2B9Pt27duPjii5k4cWKwOObll18ebFuyAGhOTk6Zc61Zs6bcgprF11%2BwYAEPP/ww3bt3p3v37lx11VWlgujz5s3jL3/5C/3796djx44MHjyYe%2B%2B9l02bNh30a166dCmhoaH87W9/4%2BOPP6Z%2B/fqVtt%2B2bRsAHTp0KHd/UlISAJmZmaSmpga3v/TSS6SkpDBkyJCD7uPBqKi4b0pKCt26dcPzPL744gtGjhxJ165d6dGjB1dffXVwQKM8h3K/58%2Bfz5133smQIUPo0qULXbp04eSTT%2BaBBx4o97ji/u3cuZNrrrmGzp0707dvX5599tlKX2/JVCI///xzhe1CQkL48ssvmTBhAl27dg1ub9iwYXCVQHH%2B/vJMnjyZ7OxsGjVqVGZVQbEhQ4bg8/mYM2cOWVlZ5bb54YcfADj11FMrvFZVxo8fzzXXXEPv3r3p2LEjJ510Evfeey8bN24s07b4/fDII4%2BQnp7OI488woknnhj8OT700EPs2rXrkPpx66230rRpU3Jzc3nooYcO%2BvjMzExeeuklzjzzTLp06UK3bt0YOXIkb7/9Nvn5%2BWXaF//7sHTpUubMmRO8B126dOHcc8/lo48%2BqrXBtvKK%2BxYXwP3hhx9YtWoVt9xyC3379qVTp06cfvrpvP766xQWFpZ7vr179/L0008zfPhwOnfuTK9evbjyyiuD75fy7Nmzh%2Beff56RI0fSq1cvOnbsSL9%2B/bjmmmvKTSdV3L/vv/%2Bel156iT59%2BtC1a1dGjhxZZV2Tg3HeeecBRZ8Da9euLbXPcRzGjBnD9ddfz8CBA%2BnYsSPdu3fn7LPP5sUXXyz1e1P83i0e2LvxxhtJSUlh9OjRh3Q%2BERERkZqkwL%2BIiIgck959912uuuoqpk2bhmVZtGjRguXLl3PzzTfz/vvvV/v1nn76aT7%2B%2BGMSExOJjIwkPj4%2BmEP81Vdf5bLLLmPChAm4rkubNm3Izc1l1KhRnH322ZUGf8tzzjnnMH78eG666aaDykcdCATK3e73%2B4N/Lh4kOJo88MAD3H///WzdupWWLVviui4zZ87kmmuuKXem%2BqHc71dffZVLL72UsWPHUlhYSKtWrYiLi2Pr1q18/vnnjBw5kg0bNpQ5znEcrr/%2BeubOnUtycjJ%2Bv59mzZpV%2BnoiIyPp3LkzAA8//DCPP/44K1euLLdt69atadq0aZn0LGeffTZQFJSvKHA8duzYYNuK8tlHRUXRv39//H4/kyZNKrO/OA1Qw4YNSw0%2BHCjXdbnzzju55ZZbmD59OhEREaSkpJCRkRH8eVS02mDXrl2MHDmSjz/%2BGMuySEpKYseOHXz66adcdNFFZGZmHnR/wsLCeOSRRwCYPn06X3/99QEfm5qaytlnn83LL7/M%2BvXrSUpKokmTJqxYsYJ///vfXHDBBRXmdR8zZgxXXnkl8%2BfPp1GjRkRHR7NixQoeeeQRnnjiiYN%2BHdVt9uzZnHfeeUyePJn4%2BHjq16/P%2BvXref7557ntttvKtF%2B%2BfDlnnnkm7777Ltu2bSMpKYm6desye/ZsbrvtNu65554yM%2BdXrlzJGWecweuvv87GjRtp2LAhLVq0IC8vj%2BnTp3Prrbfy5ptvltu/9957j5dffpmYmBji4uIICwurtkK8AK1atSI6OhooGgAs5vf7ueGGG/jnP//Jzz//THh4OCkpKYSHh7Nq1SpeeeUVLr300uDgSFxcHN27dw/%2BvrZq1Yru3bsH62cc7PlEREREapIC/yIiInLMWbJkCc888wymafKvf/2LqVOnMnr0aH7%2B%2BWcGDx7MxIkTq/2aixYt4uWXX2bs2LH8/PPP3HfffUDRTOcXXniBqKgonn/%2BeWbPns3o0aOZOXMmt912G3l5edxxxx0HFXAfNmwYDRo0OOD2TZo0ASg107ek9evXB/9cMph66aWX8t133/Hee%2B8d8LWqW25uLqNHj%2BaBBx4I3rtp06bRu3dvPM/jP//5T6n2h3K/V61axUsvvYRlWTz77LNMnz6dUaNGMWnSJL7%2B%2BmsaNmxIdnZ2uXnhCwoK2LlzJ2PHjuWrr75i2rRpnHXWWVW%2Brvvuu4/Q0FD8fj8ffPAB55xzDgMGDAiu4tiyZUulxw8bN ...

# %% [markdown]
# ## Feature Engineering
#
# We could consider enlarging the feature space to make the dataset linearly separable.
#
# __Example:__
# We can see below that our $\mathbf{x}_1$ is not linearly separable but it is when we add in our second feature $\mathbf{x}_2 = (\mathbf{x}_1)^2$

# %%
# https://github.com/ageron/handson-ml2/blob/master/05_support_vector_machines.ipynb
def poly_info(main_title):
    X1D = np.linspace(-4, 4, 9).reshape(-1, 1)
    X2D = np.c_[X1D, X1D**2]
    y = np.array([0, 0, 1, 1, 1, 1, 1, 0, 0])

    fig = plt.figure(figsize=(width_inch*2, height_inch))

    plt.subplot(121)
    plt.grid(True, which='both')
    plt.axhline(y=0, color='k')
    plt.plot(X1D[:, 0][y==0], np.zeros(4), "bs")
    plt.plot(X1D[:, 0][y==1], np.zeros(5), "g^")
    plt.gca().get_yaxis().set_ticks([])
    plt.xlabel(r"$x_1$", fontsize=20)
    plt.axis([-4.5, 4.5, -0.2, 0.2])

    plt.subplot(122)
    plt.grid(True, which='both')
    plt.axhline(y=0, color='k')
    plt.axvline(x=0, color='k')
    plt.plot(X2D[:, 0][y==0], X2D[:, 1][y==0], "bs")
    plt.plot(X2D[:, 0][y==1], X2D[:, 1][y==1], "g^")
    plt.xlabel(r"$x_1$", fontsize=20)
    plt.ylabel(r"$x_2$  ", fontsize=20, rotation=0)
    plt.gca().get_yaxis().set_ticks([0, 4, 8, 12, 16])
    plt.plot([-4.5, 4.5], [6.5, 6.5], "r--", linewidth=3)
    plt.axis([-4.5, 4.5, -1, 17])

    plt.subplots_adjust(right=1)

    plt.suptitle(main_title)
    return fig
    
fig_num+=1
fig = poly_info("Figure %d: Adding Features to Linearly Separate Data"%fig_num)
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2Bs7yej4fHw1zb%2BZzvXOec77zP9/peXpZlWQIAAAAAAAAAZClv0wUAAAAAAAAAQF5EOAsAAAAAAAAABhDOAgAAAAAAAIABhLMAAAAAAAAAYADhLAAAAAAAAAAYQDgLAAAAAAAAAAYQzgIAAAAAAACAAYSzAAAAAAAAAGAA4SwAAAAAAAAAGEA4CwAAAAAAAAAGEM4CAAAAAAAAgAG%2BpgsAgMwSHByc5m27du2ql19%2BWZLUpUsXbd68WaNHj9bTTz%2BdWeVlOxs2bNDHH3%2BsnTt3KiYmRkWKFFFISIi6d%2B%2BuunXretzn0qVLmjVrllauXKmoqCgVLlxYoaGh6tevX7raP602b96sLl26SJI6duyo119//YaPdeDAAbVp00aStH///jTv17ZtW4WHh2v8%2BPFq27atJOn3339X165dVbRoUf3%2B%2B%2B83XFNmOHbsmFq2bJnm7UeOHKlnnnkm8wq6hgsXLujixYsqVaqUkcfPalnxfKdOnapp06YpNDRUCxcuTNM%2B2fl8vhktWrRQVFSUZs6cqebNm2fa48TGxmrJkiVau3atDh06ZL%2BfVqxYUffee686dOigwoULZ9rj50RnzpyRn59fprbLsmXLNHLkSI/r/P39FRgYqNtuu03333%2B/nnjiCQUEBGTo46ekpOjIkSOqXLlyhh4XAADkfISzAHI9h8OhQoUKXXOb8uXLZ1E12dOkSZM0c%2BZMSVLhwoVVtWpVRUZG6ocfftDatWs1evRoderUyWWfhIQE9ezZU1u2bJGfn58cDodOnjyp1atX68cff9SMGTPUpEmTDK1z%2BfLl9v9XrFihESNGKH/%2B/Bn6GLlZzZo15efnd81tTAWjK1as0IQJE/TGG2/kiXA2rz3fvOLPP/9Uz549deLECeXLl08VKlRQuXLldPLkSW3fvl3btm3T3LlzNXnyZIWGhpouN1uYN2%2Bepk6dqsWLF2dJaO3n56eaNWvaP1uWpYSEBP3111/avHmzNm/erIULF2r69OmqVq1ahjzmf//7X7322mtq2LChhg8fniHHBAAAuQfhLIBc75VXXlHDhg3TvP1bb72luLg4BQUFZWJV2ce6des0c%2BZM%2Bfr66pVXXlHHjh0lSUlJSZo5c6amTp2qcePGqU6dOqpRo4a936RJk7RlyxbVqlVLM2bMUFBQkJKTkzVlyhTNnDlTw4YN05o1a64bjKfVpUuX9N1338nf31%2B1a9fWli1b9O233%2Bqxxx7LkOPfjNq1a2vVqlXy9c3eH6uTJ0/WrbfearoMj9577z2dPn3adBlZJjs/35xyPmc38fHx6t27t06cOKH27dvrhRdecAkbIyIiNG7cOP3yyy/q16%2BfVq5cqdKlSxusOHsYP358lj5eUFCQFi9e7HHdf//7X40ePVp79%2B5Vr1699Omnn2bIlyeffPKJwsPD09UXAQAAeQdzzgLAVcqWLasqVarkmctO582bJ0nq3LmzHcxKkq%2BvrwYOHKgHHnhAycnJ%2Bvjjj%2B1158%2Bf15IlS%2BTt7a233nrLDrJ9fHw0dOhQNW3aVOfOndOnn36aYXWuWbNGFy5cUI0aNfSvf/1LkrR06dIMO/7NKFCggKpUqaKKFSuaLgW4aZzPN2bVqlWKiopSjRo19Prrr7t9hlSqVEnTpk3TbbfdpgsXLmjBggWGKkVqatWqpQULFqhChQo6ceKE3nnnHdMlAQCAPIBwFgDysOTkZG3btk2S9MADD3jcxjk3Y3h4uL3shx9%2BUGxsrOrUqaMqVaq47dOuXTtJl8OKjPLVV19Jkpo2bWqHs1u3btXhw4cz7DEA4EY53yNr1qwpb2/PXez8%2BfPr4YcflnR5lCayn8KFC9tz065atUqRkZGGKwIAALkd4SwAXKVLly4KDg52GSnq9Ntvv6lnz5666667FBISoo4dO2rt2rX6/fffFRwcbN%2BsSrp8I6bg4GAFBwfr4sWLbsc6cOCAvd7T42/fvl1jxoxR3bp1VbduXT3zzDNKSUmxt9uyZYsGDBigu%2B66SzVr1tQ999yjUaNG6ciRI2l%2BrpZlaerUqRozZowcDofHbWJjYyVdDnKddu7cKUkKCQnxuM%2Bdd94pSdqzZ4%2B9v3T5hiyenvP1nDlzRhs3bpR0%2BaY%2BZcuWVZ06dSRdf/Ts6dOn9eabb6ply5aqXbu2WrVqpQULFri05dUsy9Lnn3%2Budu3aKSQkRI0bN9bIkSN16tQpj9s7f/9XX7LaokULBQcHKzo6Wt9//706deqkunXrKiQkRB06dNDKlStTreHbb7/V008/rdDQUNWtW1fdu3fX1q1b7TYcMWLENZ93RklJSdGyZcvUuXNn1a9fX7Vr19ZDDz2k999/XzExMR73SU5O1ldffaXevXuradOmqlmzpurWratHH31UU6ZMcdnP%2BXyioqIkSX379lVwcLCWLVsmSRoxYoSCg4P11ltveXyswYMHKzg4WFOnTrWXOX8fffr00datW9WmTRvVrFlTzZs313fffWdvd%2BHCBU2bNk1t2rRRnTp1VLduXXXo0EGfffaZy/l%2BpR9%2B%2BEHdu3dXaGioatasqaZNm6p///7asGFDmtrzes/XadOmTS6v76ZNm2ro0KFZEuhlxvm8b98%2BDRs2TM2aNVPNmjXVpEkTDRkyRLt3777mPq%2B88ooeeOABhYSEqFatWrr33ns1bNgwly%2BLrq7v6NGjGjp0qO688041aNBAL730ksfjL1y4UMHBwXZY6sm0adMUHBysUaNGpbqNU758%2BSRdbr9Lly6lul3nzp31zTffaPLkyR7Xr1mzRj169FDDhg1Vq1Yt3XfffRo3bpzH9x/n%2BfTqq6/q5MmTGjZsmBo1aqSQkBC1bdtWn332WarvdZGRkfr3v/%2BtNm3aqG7duvZ5NmDAAG3atMlt%2B7R8NsXHx%2BuTTz5Rt27d1LhxY9WsWVP169fXk08%2BqY8%2B%2BkgJCQn28aZOneryWdCmTRsFBwe73YQuIz7r0qt58%2BYqUaKEkpOTtW7dOrf1W7du1QsvvKAWLVqoTp06qlOnju677z6NHj3apS5nP%2BDLL7%2BUJH300Uce37/TejwAAJA7Ec4CQBp99NFHeuaZZ/TLL7/Ix8dHlStXVnh4uPr376/58%2Bdn%2BOO99dZbWrRokcqVK6eCBQsqKCjIHo0VFhamp59%2BWmvWrFFKSoocDodiY2P1xRdf6NFHH/X4x6Qnvr6%2Buueee9ShQwcFBgZ63ObHH3%2BUJJcRss4/FlObv7RUqVLy9fVVSkqKjh07lubnnJpvvvlGycnJqlSpkqpXry5JeuihhyRdHlGbmJjocb/Dhw/rySef1Pz583XmzBlVq1ZNMTEx%2Bve//6033njD4z4pKSkaNmyYXn75Zf33v/9V6dKldcstt%2BjLL7/UU089pfPnz6e7/hkzZmjQoEHau3evKlasKD8/P%2B3YsUPPP/%2B8Pa3ElcaNG6fnnntOW7ZsUWBgoCpWrKjff/9dXbp00ffff5/ux79RCQkJ6tevn0aOHKmtW7eqcOHCqlKlio4ePaoZM2bo8ccfdxtVlpiYqD59%2Buill17SunXrVKBAAQUHB6tAgQLat2%2Bfpk%2Bfrs6dO9shTYkSJVS3bl37RmVVq1ZV3bp1VaJEiZuu/9ixY%2Brdu7dOnjypKlWq6PTp07r99tvtdW3bttXUqVN16NAh3XrrrSpVqpR27Nih0aNHq0%2BfPi5BkiTNmjVLAwcO1MaNGxUYGKjg4GClpKRo7dq16tGjh8cvdK6Wluf77rvvqlu3blqzZo28vLx0%2B%2B23KzExUatWrdJTTz2VpsfJTOk9n5ctW6YnnnhCK1asUFxcnBwOhyzL0urVq/XUU095/ILlyy%2B/VNu2bb ...

# %% [markdown]
# Using quadratic, cubic or higher-order polynomial functions we can project our data onto a higher-dimensional space via a mapping function $\phi$ where they are linearly separable (using a linear SVM model in this new feature space).
#
# __Example__
#
# $\phi(\mathbf{x}_1, \mathbf{x}_2) = (\mathbf{z}_1,\mathbf{z}_2,\mathbf{z}_3) = (\mathbf{x}_1,\mathbf{x}_2,\mathbf{x}^2_1+\mathbf{x}^2_2)$

# %%
# TODO - if time code something like this up
fig_num+=1
print(color.BOLD+color.UNDERLINE+"Figure %d: 2D Dataset into Separable 3D Feature Space"%fig_num+color.END)
# Image from https://github.com/rasbt/python-machine-learning-book-3rd-edition/blob/master/ch03/ch03.ipynb
Image(filename='Images/03_13.png', width=width_pix)
# Out:
# Figure 21: 2D Dataset into Separable 3D Feature Space

# %% [markdown]
# ### Gaussian Radial Basis Function$^2$
#
# We could instead use a _"similarity function"_, such as a Gaussian Radial Basis Function (RBF),
#
# $\phi_\gamma(\mathbf{x},\ell) = \exp(-\gamma||\mathbf{x}-\ell||^2)$.
#
# This is a bell-shaped function which measures how much an instance resembles a _landmark_, with the function varying from 0 (far away) to 1 (at the landmark).
#
# __Example:__ Below we set our landmarks to $x_1 = -2$ and $x_1 = 1$.

# %%
# copied from https://github.com/ageron/handson-ml2/blob/master/05_support_vector_machines.ipynb
def gaussian_rbf(x, landmark, gamma):
        return np.exp(-gamma * np.linalg.norm(x - landmark, axis=1)**2)

def rbk_info(main_title):

    gamma = 0.3
    X1D = np.linspace(-4, 4, 9).reshape(-1, 1)
    X2D = np.c_[X1D, X1D**2]
    y = np.array([0, 0, 1, 1, 1, 1, 1, 0, 0])

    x1s = np.linspace(-4.5, 4.5, 200).reshape(-1, 1)
    x2s = gaussian_rbf(x1s, -2, gamma)
    x3s = gaussian_rbf(x1s, 1, gamma)

    XK = np.c_[gaussian_rbf(X1D, -2, gamma), gaussian_rbf(X1D, 1, gamma)]
    yk = np.array([0, 0, 1, 1, 1, 1, 1, 0, 0])

    fig = plt.figure(figsize=(width_inch, height_inch))

    plt.grid(True, which='both')
    plt.axhline(y=0, color='k')
    plt.scatter(x=[-2, 1], y=[0, 0], s=150, alpha=0.5, c="red")
    plt.plot(X1D[:, 0][yk==0], np.zeros(4), "bs")
    plt.plot(X1D[:, 0][yk==1], np.zeros(5), "g^")
    plt.plot(x1s, x2s, "g--")
    plt.plot(x1s, x3s, "b:")
    plt.gca().get_yaxis().set_ticks([0, 0.25, 0.5, 0.75, 1])
    plt.xlabel(r"$x_1$", fontsize=20)
    plt.ylabel(r"Similarity", fontsize=14)
    plt.text(-2, 0.9, "$x_2$", ha="center", fontsize=20)
    plt.text(1, 0.9, "$x_3$", ha="center", fontsize=20)
    plt.axis([-4.5, 4.5, -0.1, 1.1])
    
    plt.suptitle(main_title)
    
    return fig
    
fig_num+=1
fig = rbk_info("Figure %d: RBF Landmarks"%fig_num)
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2Bk90zmvH/EBCKhpJ5J5v5c115LZk75zXHKPc88RaMoioIQQgghhBAmQqt2ACGEEEIIIZqSFMBCCCGEEMKkSAEshBBCCCFMihTAQgghhBDCpEgBLIQQQgghTIoUwEIIIYQQwqRIASyEEEIIIUyKFMBCCCGEEMKkSAEshBBCCCFMihTAQgghhBDCpEgBLIQQQgghTIqZ2gGEEHUTEhJyw9ved999vPLKKwDce%2B%2B9HDhwgNmzZ3PPPfc0Vjyjs2vXLpYuXcrx48fJy8vD0dGRbt268eCDD9K9e/ca90lJSWH%2B/Pns2LGD5ORkzMzMaNOmDRMmTOCuu%2B7C3Ny83rlWrlzJrFmzrnq/VqvF2toab29vevfuzaOPPkqrVq2qbZOQkMDw4cNr3N/MzAxnZ2fatm3LhAkTuO2229BoNFdsN2zYMBITE28o8/Dhw/nqq6%2Buu13lMd99911uv/32Gzq2sSgoKKh6XmzevBlfX1%2BVE9VO5fvD6tWradeuncpphDA%2BUgAL0cy1a9cOOzu7a27j5%2BfXRGmM0yeffMI333wDgIODA23atCE%2BPp5NmzaxefNmZs%2BezdSpU6vtc%2BLECR566CFycnIwNzcnMDCQ/Px8Tpw4wYkTJ9i0aRPfffcdlpaWDZLRwsKCsLCwK24vLy8nNTWVc%2BfOce7cOdasWcPy5csJCgqq8ThhYWFYWFhU/V1aWkpGRgZ79uxhz549bN26lblz59ZYBAMEBgbi4uJyzaxt2rSpxSMTQgjjIwWwEM3cq6%2B%2BSp8%2BfW54%2B/fff5%2BioiLc3d0bMZXx2L59O9988w1mZma8%2Buqr3H333QDo9Xq%2B%2BeYbPv/8c9566y26dOlCaGgoACUlJTz99NPk5OQwbNgw3nnnHZydnQE4dOgQzzzzDPv372fOnDnXbL2tDXd3d3766aer3n/gwAGeeuopsrKymDVrFj///HON282dO7fG1spjx47x8MMPs3HjRn755RfuvPPOGvefOXNms2utFUKI2pI%2BwEKYGG9vb4KDg3FwcFA7SpNYtGgRANOmTasqfqGia8CTTz7JqFGjKC8vZ%2BnSpVX3bdy4kaSkJDw8PPj444%2Bril%2BAnj178t///heAn3/%2BmZKSkiZ5HL179%2Ball14C4OjRo0RHR9dq/65du/Loo48CsHz58gbPJ4QQzYkUwEKIFqu8vJzDhw8DMGrUqBq3uemmmwAIDw%2Bvuu3AgQMADB48GBsbmyv2GTBgAObm5hQXF9e6EK2PwYMHV/27Luft0aMHADExMQ2WSQghmiMpgIUwMffeey8hISHVWjwr7d27l4ceeoj%2B/fvTrVs37r77bjZv3sz%2B/fsJCQnh3nvvrdo2ISGBkJAQQkJCKCgouOJYkZGRVffXdP4jR47wxhtv0L17d7p3787999%2BPwWCo2u7gwYM88cQT9O/fn7CwMIYMGcLLL7/MhQsXbvixKorC559/zhtvvHHVgUCFhYVARbFc6Z577uGDDz5g0qRJNe5TWlpatb1er6%2B6feXKlTU%2B5oai1V56y1YUpdb7V2atqag3JiUlJSxbtozp06fTr18/wsLC6NmzJ5MnT2bhwoWUlpZW277y%2BTlz5kwKCwuZM2cOI0eOpFOnTgwYMIDnnnuO8%2BfP13iu/Px8Pv/8c0aPHk3nzp0ZPnw4n3/%2BOWVlZTVu//nnnxMSEsKiRYuIjY3l2WefpV%2B/fnTp0oWJEyeyZs0aAMrKypg3bx6jRo0iLCyMgQMH8sYbb5Cfn1/jcbdu3cq//vUvhgwZQqdOnejWrRtjxozh3XffJT09vdq2la%2B9cePGERUVxZQpU%2BjUqRMDBw6s8XV9uQ0bNtCxY0fat29frRuNoij88ssvTJ06le7duxMWFsbQoUN59tlnOXHixDWPKURzJH2AhRAALFy4kPfffx%2BAVq1aERQURHh4OI8//vhVZxioj/fff59jx47Rrl07srOzcXd3ryrwvvrqK%2BbOnQuAs7Mz7dq1Iz4%2Bnl9//ZV169Yxd%2B5chgwZct1zmJmZXXe7LVu2ABAcHFx1W/v27Wnfvv1V99m6dSsGgwEzM7OrDkZrDH/%2B%2BScAGo2mxgFz17N582YABg4c2KC5GlJeXh7Tp08nPDwcnU6Hv78/Xl5eJCYmVg1A3LNnD/Pnz79i34KCAqZOncqZM2fw9PQkODiYyMhIVq9ezY4dO/j111%2BrDQjNyMjggQceIDIyEnNzc9q2bUt2djZffPEF%2B/btu2bO8PBw5s6di16vJzg4mJSUFE6fPs2zzz6LXq/n999/Z8%2BePfj4%2BBAQEEBUVBQ//vgj58%2Bfr%2BqWU%2BmVV15hxYoVQEUXpXbt2pGRkUFMTAwxMTGsX7%2Be33//vVpXnMprNWPGDHJzc2nTpg0xMTHVnsf/tGPHDp577jnKy8v5z3/%2Bw1133VV132uvvcby5cvRaDQEBARga2tLQkICa9asYf369Xz22WeMGDHimtdEiOZECmAhBCdOnOCDDz5Aq9VWfTBqNBqysrJ48cUXqwqnhnTs2DG%2B%2BOILRo4cicFgIDc3F6go8ubOnYudnR3//e9/GTt2LFDRovbdd98xd%2B5c/v3vf7N69Wq8vb3rlWHHjh3s2rULgAkTJtzQPoWFhVXF%2BZAhQ7C3t6%2B6b%2BTIkXTp0qVemWpiMBjYsmVL1ReUW265BR8fnxvat7S0lPT0dFavXs2iRYtwdHTkySefbPCMDeXLL78kPDyc4OBgvvvuu6rHWdlP%2B5133mHnzp2cOHGCzp07V9v34MGDuLu7s2jRIvr16wdUdBWZPn066enpLFiwgNdff71q%2B7fffpvIyEg6duzIl19%2BWfV8Wr169XUHN/7xxx/06NGDzz//HFdXV0pLS3n88cfZuXMns2bNwsHBoVqOjRs38tRTT7F3714iIiKqvmBt2bKFFStWYGNjw9dff03fvn2rznHgwAFmzpxJamoqK1as4OGHH66WISUlhcDAQFauXImrqyvZ2dk4OjrWmPfQoUP861//oqysjFdeeYVp06ZV3Xfu3DmWL1%2BOi4sLixcvpm3btkDFc%2Bfdd9/lxx9/5L333pMCWLQoUgAL0czdd99917z/yy%2B/vO4H19dff42iKEyfPr3aQDFnZ2fmzp3L2LFjSUpKapC8lbp168bIkSOBip/2nZycAPjss88AePnll6uKXwBzc3Mef/xxIiMjWb9%2BPYsWLeLll1%2Bu8/ljYmJ44YUXAOjVq9cNtXKXl5fz3HPPERcXh6WlJf/%2B97%2Br3W9vb1%2BtIK6N9PT0ate%2BUlFREYmJiVVfECp/Sr%2Baaz0OBwcHlixZcs1p8WbNmnXN4m/WrFncf//9V72/vg4cOIBGo2HWrFnVinydTsf06dNZunQpcXFxREVFXVEAQ8XzprLohIqW/alTpzJ37lyOHz9edXtiYiLr1q1Dp9Mxd%2B7cal%2Bmxo8fz/nz5/nyyy%%2BXGzduHOvXr2fHjh11LoBjYmK4//77ycrKwt3dnY8%2B%2Buiq8%2BJW0uv1vPDCC1Wt4bNnz27Q%2BXBLS0s5cuRIjfe5uLgwadIkxowZw6BBg655nH/OA6zX68nJySE%2BPp7c3Fwee%2Bwx3n/ ...

# %% [markdown]
# Using the example of $x_1=-1$ we can see it is a distance of 1 from the first landmark and 2 from the second.
#
# If we set $\gamma = 0.3$ then our new features are:
#
# $x_2 = \exp(-0.3 \times 1^2) \approx 0.74$
#
# $x_3 = \exp(-0.3 \times 2^2) \approx 0.30$
#
# In order to find the landmarks the simplist approach is just to create a landmark at each instance in the dataset.

# %%
import math

# copied from https://github.com/ageron/handson-ml2/blob/master/05_support_vector_machines.ipynb
def gaussian_rbf(x, landmark, gamma):
        return np.exp(-gamma * np.linalg.norm(x - landmark, axis=1)**2)

def rbk_info(main_title):

    gamma = 0.3
    X1D = np.linspace(-4, 4, 9).reshape(-1, 1)
    X2D = np.c_[X1D, X1D**2]
    y = np.array([0, 0, 1, 1, 1, 1, 1, 0, 0])

    x1s = np.linspace(-4.5, 4.5, 200).reshape(-1, 1)
    x2s = gaussian_rbf(x1s, -2, gamma)
    x3s = gaussian_rbf(x1s, 1, gamma)

    XK = np.c_[gaussian_rbf(X1D, -2, gamma), gaussian_rbf(X1D, 1, gamma)]
    yk = np.array([0, 0, 1, 1, 1, 1, 1, 0, 0])

    fig = plt.figure(figsize=(width_inch*2, height_inch))

    plt.subplot(121)
    plt.grid(True, which='both')
    plt.axhline(y=0, color='k')
    plt.scatter(x=[-2, 1], y=[0, 0], s=150, alpha=0.5, c="red")
    plt.plot(X1D[:, 0][yk==0], np.zeros(4), "bs")
    plt.plot(X1D[:, 0][yk==1], np.zeros(5), "g^")
    plt.plot(x1s, x2s, "g--")
    plt.plot(x1s, x3s, "b:")
    plt.gca().get_yaxis().set_ticks([0, 0.25, 0.5, 0.75, 1])
    plt.xlabel(r"$x_1$", fontsize=20)
    plt.ylabel(r"Similarity", fontsize=14)
    plt.annotate(r'$\mathbf{x}$',
                 xy=(X1D[3, 0], 0),
                 xytext=(-0.5, 0.20),
                 ha="center",
                 arrowprops=dict(facecolor='black', shrink=0.1),
                 fontsize=18,
                )
    plt.text(-2, 0.9, "$x_2$", ha="center", fontsize=20)
    plt.text(1, 0.9, "$x_3$", ha="center", fontsize=20)
    plt.axis([-4.5, 4.5, -0.1, 1.1])

    plt.subplot(122)
    plt.grid(True, which='both')
    plt.axhline(y=0, color='k')
    plt.axvline(x=0, color='k')
    plt.plot(XK[:, 0][yk==0], XK[:, 1][yk==0], "bs")
    plt.plot(XK[:, 0][yk==1], XK[:, 1][yk==1], "g^")
    plt.scatter(x=[math.exp(-0.3*(0.**2.)), math.exp(-0.3*(3.**2.))], y=[math.exp(-0.3*(3.**2.)), math.exp(-0.3*(0.**2.))], s=150, alpha=0.5, c="red")
    plt.xlabel(r"$x_2$", fontsize=20)
    plt.ylabel(r"$x_3$  ", fontsize=20, rotation=0)
    plt.annotate(r'$\phi\left(\mathbf{x}\right)$',
                 xy=(XK[3, 0], XK[3, 1]),
                 xytext=(0.65, 0.50),
                 ha="center",
                 arrowprops=dict(facecolor='black', shrink=0.1),
                 fontsize=18,
                )
    plt.plot([-0.1, 1.1], [0.57, -0.1], "r--", linewidth=3)
    plt.axis([-0.1, 1.1, -0.1, 1.1])

    plt.subplots_adjust(right=1)
    
    plt.suptitle(main_title)

    return fig

fig_num+=1
fig = rbk_info("Figure %d: RBF New Feature Space"%fig_num)
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='data:image/png;base64,...%2B/XoSEhLw9fWla9eu3HfffTRu3Lhc4po3bx4vvvhikeuNRiOurq4EBgbSqVMnHnzwQerWrZtvzMmTJ%2BnXr1%2Bh2zs4OODj40PTpk258cYbGTZsGAaDocC4vn37EhsbW6yY%2B/Xrx9SpU684Lu9eCw4OZuHChbi4uBQ5Nu86tGjRgnnz5hUrDnuqiOtVESwWC1FRUTRq1Mguxy8PCQkJ/PDDD6xatYqYmBhSU1Px8fGhSZMm9OvXjxEjRuDs7GzvMEVERESkklNSW0REpBIJCwvDw8PjsmOCgoKuUjSV06RJk5g2bRoAtWrVokmTJsTExLB8%2BXL%2B%2BOMPJkyYwO23355vm71793LHHXeQnp6Ou7s7TZo0IS4ujrlz57J48WImT55Mnz59yi1GJycnWrZsWWC52WwmPj6eI0eOcOTIERYtWsSsWbOKTFK2bNkSJycn2/dZWVmcO3eO9evXs379ev78808%2B%2BuijQhPbACEhIdSuXfuysTZp0qQEZwbR0dFMmTKF5557rkTbVQUVcb3Ky549e3j11Vfp3Lkz48ePt0sMZbVp0yYef/xxEhMTcXZ2pmHDhjg5OREXF2e7p2fMmMEXX3xht%2BssIiIiIlWDktoiIiKVyMsvv0znzp2LPf6dd94hPT0dPz%2B/Coyq8li9ejXTpk3DwcGBl19%2BmdGjRwOQk5PDtGnTmDJlCv/3f/9HmzZtaNGiBQDp6ek88sgjpKenc%2Butt/Lyyy/j6upKTk4OU6ZMYdq0aTz77LOsXLkSLy%2BvconTz8%2BPn376qcj1mzdv5vHHHychIYEXX3yRn3/%2BudBxH330EQ0aNCiwfOfOndx///0sW7aM2bNnc9tttxW6/bhx47j55ptLdxKX8fXXX3PDDTfQvHnzct%2B3PVXU9SoPP/zwA/v27SvRz4fK5OzZszzyyCMkJyfz2GOPMXbsWFxdXW3r9%2B3bx6uvvsqePXu47777%2BO233/KtFxERERG5lHpqi4iIVGGBgYGEhoZSq1Yte4dyVXz99dcAjBkzxpbQhty2HI8%2B%2BigDBw7EbDbz/fff29b9%2BeefnD59mpCQECZOnGhLlDk4OPDkk08SFhZGSkoKy5Ytu2rn0alTJ1544QUAduzYwbFjx0q0fdu2bXnwwQcBmDVrVrnHdzkGg4GcnBxefvllzGbzVT22VF2zZs0iOTmZAQMG8OijjxZIWLdo0YLPP/%2Bc2rVrExcXVyXa1oiIiIiI/SipLSIiIlWC2Wxm27ZtAAwcOLDQMXktRPbt22db5ubmxpAhQxg9ejSOjo75xhsMBlubg7i4uIoIu0g9e/a0fV3SpDZA%2B/btATh%2B/Hi5xVQct9xyCw4ODuzbt4%2BZM2de1WNL1ZX3nGzVqlWRY%2BrUqWN7Du/du/eqxCUiIiIiVZOS2iIiIlXYnXfeSXh4eL7K5DwbNmzgvvvuo2vXrrRr147Ro0fzxx9/sGnTJsLDw7nzzjttY0%2BePEl4eDjh4eGkpqYW2Nfhw4dt6ws7/vbt23nttdeIiIggIiKCe%2B65B4vFYhu3ZcsWHnnkEbp27UrLli3p1asXL730ElFRUcU%%2BD5DrmT07Zr1474%2BHjGjh1L69at6dKlCx988IFtjMViYd68eYwZM4YOHTrQunVrrr/%2BeiZPnkxycnKJrlHeG0pr16697P3%2B5JNPsmTJkgITrvbt25fw8HDOnj3LvHnzGDp0KK1bt6Z3796MHz%2BeEydOFLo/s9nMr7/%2BygMPPED37t1p2bIlERER3HTTTXz88cdFnsf58%2BeZPHkyN9xwA23btiUiIoIxY8awZMmSQsenpKTwySefMHToUNq0aUNERASjRo3iv//9rz7RICIiIlIBlNQWERGphmbMmME999zD2rVrMZlMNGrUiH379vHwww/zzTfflPvx3nnnHX788Ufq16%2BPu7s7fn5%2BtqTt1KlTueOOO1ixYgUWi4WwsDDS0tKYO3cuN910E6tXry7WMRwcHOjVqxejRo3C09Oz0DErV64EIDQ09Ir7O336NM8//zwnTpwgODiYwYMHF/Nsy8fvv/8O5FaLFzap5JX88ccfAHTv3r1c4yqOxx57jIYNG5KRkcGECRNKtG1J7odevXoBsH79%2BgL72bhxIwDZ2dns2LEj37o9e/Zw4cIFmjVrRmBgYElPr0RKc39PnTqVMWPGsHDhQrKysmjSpAl16tTh5MmT/Pe//%2BXmm2%2B2VeA7OzsTERFBnTp1APD39yciIoKQkJAyx242m3nggQfYvHkzoaGhZGdnExwcDOROSvrQQw/x4osvsnXrVmrVqkVoaCjR0dF89tlnDB8%2BvERvaHTp0gXIfQPgzjvvZPny5QXejACoW7fuZVsqffbZZ7z44ovExcXRtGlTkpOTmT9/Prfeeitbt27NNzY7O5tx48bx/PPPs3r1alxdXQkPD8fV1ZWDBw/y6aefMmbMGLKysvJtt3//foYNG8Znn31GVFQUjRo1wtvbm61bt/LUU0/x0Ucf5Rt/8uRJbr75ZqZMmcLx48dp0KAB/v7%2B7NixgwkTJjBu3LgCxxARERGRslFSW0REpJrZvXs37777LkajkYkTJ7JmzRrmzZvH6tWr6dWrly0ZWp527tzJJ598wsKFC1m9ejX//ve/gdzE7UcffYSHhweTJk1i48aNzJs3j/Xr1/PEE0%2BQnp7O008/XS7VtGvWrGHdunUA3HjjjUWOmzVrFgMHDqRv374sWrSIiIgIZsyYgbOzc75xAwYMYMmSJUVWZpaWxWJhxYoVvPPOOwDccMMN1K9fv1jbZmVlERsby7Rp0/j666/x8vLi0UcfLdf4isPZ2ZnXX38dyP1EwNy5c4u1XUnvhx49emA0GtmzZw8pKSm2/VgsFjZt2mT7fsuWLfmOs3btWiC3Sr8ileb%2BPnjwIFOmTMFkMvHBBx%2Bwbt065s6dy8qVK5k/fz4BAQGkpKTw7bffAn9POprXruaGG27gp59%2BsvVUL4vMzEzi4%2BNZuHAhv/zyC2vXrrU9d959911WrVpFaGgov/zyCytXrrSNue6664iJieGJJ57I94mMy7nlllto27YtkPt4Pfroo3Ts2JE77riDjz/%2BmK1btxarovmHH35g2LBhrF27lrlz57JmzRpuuOEGUlJSeOaZZ0hPT7eN/fnnn1m7di2%2Bvr78%2BuuvLF%2B%2BnLlz5/LXX38xefJkjEYjhw4dYsWKFbZtsrKyePrppzlz5gx9%2BvRhzZo1tvOfNGkSJpOJqVOn2lohmc1mHnvsMaKioujbty%2BrV69m8eLF/PbbbyxevJjQ0FDWrl3Le%2B%2B9V9yHRURERESKQUltERGRSuSuu%2B6ytbwo7N%2BlyZeifPbZZ1itVu666y5Gjx6NwWAAwMfHh48%2B%2BqhCKlfbtWvHgAEDgNy2Gt7e3gC2thEvvfQS119/vW28o6MjDz/8MIMHDyYlJcU2AWRpHT9%2BnOeffx6Ajh070q9fvyLH7ty5k8jISFsCLT4%2B3pYMv5SnpyehoaHFqvr%2Bp7NnzzJ69OgC/4YNG0bnzp155JFHSElJoXv37rz22mtF7qdfv375Hv9WrVrRt29fJk2ahI ...

# %% [markdown]
# ## Kernels
#
# However, by using feature engineering to enlarge our feature space, the larger the number of features, the higher computational burden.
#
# Instead it is common to enlarge the feature space using an extension of a SVC termed a Support Vector Machine, which uses _kernels_.

# %% [markdown]
# The Kernel trick can relies on the fact we can define our SVM in the form of inner products.
#
# $$
# L_D(\alpha_i) = \sum_i^n\alpha_i - \frac{1}{2}\sum_{i,k}^n\alpha_i\alpha_ky_iy_k\mathbf{x}_i^{\mathrm T}\mathbf{x}_k \qquad \text{s.t.} \quad \forall_i \alpha_i \geq 0, \ \sum_i^n\alpha_iy_i = 0.
# $$
#
# Imagine we had a mapping $\phi$ which maps the data to some high dimensional Euclidean space
#
# $$
# \phi: \mathbb{R}^d \mapsto H,
# $$
#
# then, we could do dot products between vectors after the mapping in $H$:
#
# $$
# L_D(\alpha_i) = \sum_i^n\alpha_i - \frac{1}{2}\sum_{i,k}^n\alpha_i\alpha_ky_iy_k\phi(\mathbf{x}_i^{\mathrm T})\phi(\mathbf{x}_k)
# $$
#
# Instead we could use a kernel function,
#
# $$
# K(\mathbf{x}_i,\mathbf{x}_k) = \phi(\mathbf{x}_i^{\mathrm T})\Phi(\mathbf{x}_k).
# $$

# %% [markdown]
# __Notes__
#
# - Roughly speaking, a kernel can be interpreted as a similarity function betwen pairs of samples$^4$.
# - $\mathbf{a} \in \mathbb{R}^k$ just means it is a vector of length $k$.
# - $\mathbf{A} \in \mathbb{R}^{r\times s}$ just means it is an $r \times s$ matrix.
# - $\mathbf{w}$ lives in $H$ ("high dimensional")
# - $H$ is often refered to as a Hilbert space.
# - _"it is clear that the above implicit mapping trick will work for any algorithm in which the data only appear as dot products (for example, the nearest neighbor algorithm). This fact has been used to derive a nonlinear version of principal component analysis by (Scholkopf, Smola and Muller, 1998b); it seems likely that this trick will continue to find uses elsewhere."_$^6$

# %% [markdown]
# __Second-Degree Polynomial Example$^2$__
#
# Suppose we wanted to apply a second-degree polynomial transformation to two 2D vectors, $\mathbf{a}$ and $\mathbf{b}$, and then compute the dot product. We could do this by:
#
# $$
# \phi(\mathbf{a})^{\mathrm T}\phi(\mathbf{b}) = \begin{pmatrix} {a_1}^2 \\ \sqrt{2a_1a_2} \\ {a_2}^2 \end{pmatrix}^{\mathrm T} \begin{pmatrix} {b_1}^2 \\ \sqrt{2b_1b_2} \\ {b_2}^2\end{pmatrix} = {a_1}^2{b_1}^2+2a_1b_1a_2b_2+{a_2}^2{b_2}^2.
# $$
#
# Instead we could use the kernel approach:
#
# $$
# K(\mathbf{a}, \mathbf{b}) = (\mathbf{a}^{\mathrm T}\mathbf{b})^2 = \begin{pmatrix} \begin{pmatrix} a_1 \\ a_2 \end{pmatrix}^{\mathrm T}\begin{pmatrix} b_1 \\ b_2 \end{pmatrix}\end{pmatrix}^2 = (a_1b_1+a_2b_2)^2 = {a_1}^2{b_1}^2+2a_1b_1a_2b_2+{a_2}^2{b_2}^2.
# $$
#
# This is useful as it means we didnt have to map our data using $\phi$ first. This saves us time!

# %% [markdown]
# __Notes__
#
# - A second-degree polynomial for a training set with two features, $\mathbf{x} \in \mathbb{R}^2$, would be:
#
# $$\Phi(\mathbf{x}) = \Phi((\mathbf{x}_1, \mathbf{x}_2)) = ({\mathbf{x}_1}^2, \sqrt{2\mathbf{x}_1\mathbf{x}_2}, {\mathbf{x}_2}^2)$$

# %%
# TODO: Time allowing, look at if this increases as polynomial degree increases

# https://github.com/ageron/handson-ml2/blob/master/05_support_vector_machines.ipynb
from sklearn.datasets import make_moons
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

polynomial_feat = Pipeline([
        ("poly_features", PolynomialFeatures(degree=2)),
        ("scaler", StandardScaler()),
        ("svm_clf", LinearSVC(C=10, loss="hinge", random_state=42))
    ])

polynomial_svm = Pipeline([
        ("scaler", StandardScaler()),
        ("svm_clf", SVC(kernel='poly', degree=2, C=10, random_state=42))
    ])

with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    print(color.BOLD+color.UNDERLINE+"Polynomial Feature Engineering (degree=2)"+color.END)
    # %timeit polynomial_feat.fit(nl2, y2)
    print(color.BOLD+color.UNDERLINE+"Polynomial Kernel (degree=2)"+color.END)
    # %timeit polynomial_svm.fit(nl2, y2)
# Out:
# Polynomial Feature Engineering (degree=2)
# 2.2 ms ± 129 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# Polynomial Kernel (degree=2)
# 3.4 ms ± 246 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# We still have all the same considerations, but replacing $\mathbf{x}_i^{\mathrm T} \mathbf{x}_k$ with $K(\mathbf{x}_i, \mathbf{x}_k)$ allows us to produce a SVM in infinite dimensional space.
#
# $$
# \sum_i^n\alpha_i - \frac{1}{2}\sum_i^n\sum_k^n\alpha_i\alpha_ky_iy_kK(\mathbf{x}_i, \mathbf{x}_k) \qquad \text{s.t.} \quad \forall_i \alpha_i \geq 0, \ \sum_i^n\alpha_iy_i = 0.
# $$
#
# In the test phase, we can use the support vectors$^6$:
#
# $$
# \begin{align}
# f(\mathbf{x}^*) &= \sum_{i \in s}\hat\alpha_iy_i\phi(\mathbf{x}_i)\cdot \phi(\mathbf{x}^*) + \hat b \\
#                 &= \sum_{i \in s}\hat\alpha_iy_iK(\mathbf{x}_i,\mathbf{x}^*) +\hat b,
# \end{align}
# $$
#
# avoiding computing $\Phi(\mathbf{x}^*)$.

# %% [markdown]
# __Note__
# - Put another way, in the test phase$^6$, we can use the support vectors, $\mathbf{s}_i$:
#
# $$
# \begin{align}
# f(\mathbf{x}^*) &= \sum_{i = 1}^{n_s}\hat\alpha_iy_i\Phi(\mathbf{s}_i)\cdot \Phi(\mathbf{x}^*) + \hat b \\
#                 &= \sum_{i = 1}^{n_s}\hat\alpha_iy_iK(\mathbf{s}_i,\mathbf{x}^*) +\hat b.
# \end{align}
# $$

# %% [markdown]
# ## Polynomial kernels
#
# The polynomial kernel of degree $d$ (a positive integer) can be defined as:
#
# $$K(\mathbf{x}_i,\mathbf{x}_k) = \left(\gamma \left<\mathbf{x}_i, \mathbf{x}_k\right> + r \right)^d$$
#
# ### Hyperparameters
# - $\gamma$ (`gamma`) broadly defines the width or slope of kernel function<sup>13</sup>.
# - $r$ (`coef0`) roughly controls how much the model is influenced by high-degree polynomials<sup>2</sup>.
# - $d$ (`degree`) is the degree of the polynomial.

# %% [markdown]
# __Notes__
# - You will sometimes see a kernel defined in a general sense using $K(\mathbf{x},\mathbf{x}^\prime)$, where $\mathbf{x}^\prime$ means another point in the dataset.
# - $\left<x_i, x_j\right> = x_i \cdot x_j = \mathbf{x}_i^{\mathrm T} \mathbf{x}_k$.
# - $\gamma$ is often 1.
# - _"The ‘curve’ of the decision boundary becomes very low when gamma value is low making the decision region very broad. The ‘curve’ of the decision boundary becomes high when gamma is high, which creates islands of decision-boundaries around data points."_<sup>13</sup>
# - $d$ is a positive integer.
# - If you start to overfit you should reduce the polynomial degree and underfitting try increasing it.

# %%
def plot_predictions(clf, axes):
    x0s = np.linspace(axes[0], axes[1], 100)
    x1s = np.linspace(axes[2], axes[3], 100)
    x0, x1 = np.meshgrid(x0s, x1s)
    X = np.c_[x0.ravel(), x1.ravel()]
    y_pred = clf.predict(X).reshape(x0.shape)
    y_decision = clf.decision_function(X).reshape(x0.shape)
    plt.contourf(x0, x1, y_pred, cmap=plt.cm.brg, alpha=0.2)
    plt.contourf(x0, x1, y_decision, cmap=plt.cm.brg, alpha=0.1)

poly_kernel_svm_clf = Pipeline([
        ("scaler", StandardScaler()),
        ("svm_clf", SVC(kernel="poly", gamma=1, degree=3, coef0=1, C=5))
    ])
poly_kernel_svm_clf.fit(nl2, y2)

poly100_kernel_svm_clf = Pipeline([
        ("scaler", StandardScaler()),
        ("svm_clf", SVC(kernel="poly", gamma=10, degree=3, coef0=1, C=5))
    ])
poly100_kernel_svm_clf.fit(nl2, y2)

fig, axes = plt.subplots(ncols=2, nrows =2, figsize=(width_inch*2, height_inch*2), sharey=True)

axes = axes.flatten()

gamma_list=[0.5,10]
C_list=[0.5,10]

i=0
for gamma in gamma_list:
    for C in C_list:
        poly_kernel_svm_clf = Pipeline([
            ("scaler", StandardScaler()),
            ("svm_clf", SVC(kernel="poly", 
                            gamma=gamma,
                            C=C,
                            degree=3, coef0=1))
        ])
        poly_kernel_svm_clf.fit(nl2, y2)
        warnings.simplefilter("ignore")
        plt.sca(axes[i])
        plot_predictions(poly_kernel_svm_clf, [-1.5, 2.45, -1, 1.5])
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            sns.scatterplot(nl2[:,0], nl2[:,1], y2, legend=False)
        plt.title(r"$\gamma = %.2f, C=%.2f$"%(gamma, C), fontsize=18)
        plt.ylabel("")
        i+=1
    
fig_num+=1
plt.suptitle("Figure %d: Polynomial Kernel Decision Boundaries (degree=3, coef0=1)"%fig_num)
plt.tight_layout()

plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2B9XcAAAAOXRFWHRTb2Z0d2FyZQBNYXRwbG90bGliIHZlcnNpb24zLjMuNCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8QVMy6AAAACXBIWXMAABJ0AAASdAHeZh94AAEAAElEQVR4nOzdd3gU5fbA8e%2B29F5IIEACSTb0XqQLoljgWq7KtYCIei1Y77WLvV/LT0HsBbEXUOxSRIr0DqEE0jvpPdns7vz%%2BhRBCCCGEEEIIIYQQQoguRBL/QgghhBBCCCGEEEIIIUQXIol/IYQQVjExMc3%2B9%2Byzz1rnmzdvHjExMXz66acOjL7jbdmyhVtuuYUJEyYwZMgQJk2axO23387evXubvYzU1FRGjBhBTEyM3eJaunRpg9/boEGDGDlyJBdccAFPPfUUqampdlnngw8%2BSExMDC%2B%2B%2BKJdltfZrFq1ipiYGC677LI2L6ulx5Pl%2B543b16j0%2B3evdu6r1122WUUFxe3OVZn0NJ9b8eOHQ0eH0OHDuWss85i7ty5vPPOOxQUFLRz9I2zx7nVnvumvVm%2BO1v/Ro8ezfnnn89TTz1FWlqao0NtF%2BPHjycmJoYdO3a0%2B7os2zUuLq7d19UapaWlTJ8%2BnXvvvbfZ81x22WXExMSwatWqdoyse/jll1%2B49tprGTVqFCNGjODiiy/m3XffxWAwODq0DmEymVi6dCkzZsywtue%2B//576/snTpzgrrvu4qyzzmLo0KHMmjWLJUuWUFFR0e6xvfjii40eu4899hiTJ092%2BO%2BVEEII56R1dABCCCGcj16vx8vLq9Fp%2BvTp00HROKf/%2B7//4%2B233wbAx8eHqKgoUlNTWbt2LevXr%2BfRRx/l6quvbnQZiqLwyCOPtNuFo5eXF3q9vs5rZrOZkpISUlJSSEhI4LvvvuPtt99m/Pjx7RKDcA4HDx7k5ptvpqKigkGDBvHRRx/h4%2BPj6LAcbtSoUXX%2BX1VVRW5uLvv372f//v2sWLGC1157jbFjxzoowu4hMDCQ8PBw6/8VRaGsrIyUlBQ%2B%2B%2BwzvvvuOz788ENGjhzpwChFe3rhhRfIzc3lP//5j6ND6XZeeukl3n//fQB69uyJt7c38fHxvPLKK/z00098%2BumnXf734u233%2BaNN94AICoqCrVaTc%2BePQE4fPgw8%2BbNo7y8nODgYKKjo4mLi2PZsmWsX7%2Bezz77rMk2c2tt3LiRFStWNDrNnXfeyY8//sgzzzzDK6%2B80i5xCCGE6Lwk8S%2BEEKKexYsXtygR/OKLL1JRUUFwcHA7RuU8Nm7cyNtvv41Wq2Xx4sVcddVVABiNRt5%2B%2B22WLl3KM888w/Dhwxk8eHCDy/nqq6/atafnoEGD%2BOSTT2y%2Bl5mZyaJFi4iNjeX%2B%2B%2B/n999/x83Nrd1i6erOPfdchg8f7pTb8NixY9x0002UlpYyYMAAPvzwQ3x9fR0dllP44osvbL6ekJDAU089xbZt27j11lv5/PPP691E6wj2OLc6875pMXXqVF544YV6r1dWVvLkk0%2ByatUq/vvf/7JmzRq0Wrl8aY1ffvkFcM6b9gcPHuTbb7/luuuuo1evXo4Op1tZv34977//Pi4uLrz22mucc845QN02wjPPPMP//vc/B0favn777TcAbrnlFu655x7r61VVVdx2222Ul5dz%2B%2B23s2jRItRqNdnZ2dx6663Exsby4osv8vTTT9s9pj///JO77roLo9HY6HRBQUHMnz%2Bft99%2BmyuvvFI6cgghhKhDSv0IIYRos169ehEZGdnle4RZLF%2B%2BHIBrrrnGmvQH0Gq13H777cyaNQuTydRoeY7MzExeeuklhyXjevbsyUsvvYRKpSIrK4s//vjDIXF0Fd7e3kRGRhIWFuboUOpISEhg4cKFFBYWotfr%2Beijj/D393d0WE6vf//%2BvPvuu4wcOZKSkhIef/xxh8Rhj3Ors%2B6bzeHm5saTTz6Jn58f6enpbNmyxdEhdVqRkZFERkbi4uLi6FDqeemll9BoNCxcuNDRoXQ7lpufN998szXpDzVthCeffBKouWnUESVtHCk/Px%2BAMWPG1Hn9%2B%2B%2B/Jzs7m5EjR3LHHXegVtekT0JCQli6dCk6nY5Vq1Zx6tQpu8ViMBh4/fXXufXWW6msrGzWPAsWLMDNzY2XXnrJbnEIIYToGiTxL4QQQrSAyWRiz549AMyaNcvmNNOnTwcgNja2weU89thjlJaWcuedd9o/yGaKjIy0ltc4dOiQw%2BIQ7SM1NZUFCxaQl5dHdHQ0H3/8MQEBAY4Oq9NwcXHhiSeeAGDv3r3s3LnTsQF1Uy4uLgwZMgSA%2BPh4B0cj7M1ybE2bNo2QkBBHh9PtDBkyhKlTp3LhhRfWe8/ylFN1dTW5ubkdHVqHsvSqP/PGmKXO/6WXXlpvnrCwMCZOnIjRaGTt2rV2iSM7O5sLLriAN998E41Gw1NPPdWs%2Bfz9/Zk5cyaHDh3ir7/%2BskssQgghugZJ/AshhGizxgag3LZtGzfeeCMTJ05k5MiRXHXVVaxfv946wGbtAUnT0tKsAxCWlZXVW1ZcXJz1fVvr37t3L08%2B%2BSSjRo1i1KhRLFiwALPZbJ1u165dLFq0iIkTJzJkyBCmTZvGww8/THJycrM/q6IoLF26lCeffLLB0h/l5eVAzU0CW77//ns2bdrEP/7xD6ZMmdLo%2BiwDt86YMaPZMbaEt7c3QL3tbTab%2Bfbbb7nmmmsYPXo0Q4cO5bzzzuPZZ58lOzu7yeUeP37cOphwQwmDXbt2ERMTw7nnnguc/v5nz56N0WjkvffeY/bs2QwbNozx48dz2223NXiDoqXxWrbr8uXLSUpK4r///S8TJkxg%2BPDhXHrppfz0009ATcLjnXfeYdasWQwZMoTJkyfz5JNPUlpaWmd5jQ2gmpqayrPPPsucOXMYNWqUdTmLFi1i%2B/btTW7L1sjOzmbBggVkZ2cTGRnJ8uXLm0z6t%2BT4sHzep556ijVr1nDuuedat/mePXusx/fNN99MeXk5r776qnWaSZMmce%2B995KYmGgzDrPZzKpVq7jmmmsYM2YMw4YN48ILL%2BS1116jpKTELtunuQYMGMDQoUMB2LBhQ733S0tLeeONN5gzZw7Dhw9n1KhR/Otf/%2BLrr79u8PhXFIUffviB%2BfPnWwcGnzVrFi%2B99FK9z9fQuTU1NZXFixdbB6IcM2YMV1xxBe%2B//369nrmN7ZvFxcUsXbrUGv/IkSO57LLLeP/99232NLXEc%2BjQIXbs2MENN9zAuHHjrMfNZ599Vuecay%2BWpJyHh0e991p67Dc1GPSdd95JTEwMS5cutb7WlnOTwWBg%2BfLlzJkzhxEjRjBlyhSeffbZeueQM23YsIE77riDadOmMXToUOug7M8//zw5OTl1pq0d38mTJ5k7dy5Dhw5l8uTJ1n2nscF9W/rbmJeXx/PPP289L44aNYqLL76Y1157jcLCwkY/15ksPc5nz55t831FUfj222%2B5/PLLGTlyJBMmTOChhx5qsod1Xl4eL774IrNmzWLYsGGMHTuW6667zlrSxZaioiJef/11zj//fIYNG8bUqVN5%2BumnKSwstO77t ...

# %% [markdown]
# You shouldnt stick to the default settings, instead you want to search for optimal hyperparameters for the data. Good suggestions for search spaces are:
#
# - _"The authors of libsvm (Hsu et al. 2009) recommend using cv over a 2d grid with values $C \in \{2^{-5}, 2^{-3}\,\ldots,2^{15}\}$ and $\gamma \in \{2^{-15}, 2^{-13}, \ldots,2^{3}\}$"_<sup>4</sup>.

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, KFold

def hyper_search(model, params, X, y, save_path, n_iter=60, metric="accuracy", 
                 cv = KFold(5), random_state=42, refit=True,
                 overwrite=False):
    if os.path.exists(save_path) and overwrite==False:
        #load the model
        models = joblib.load(save_path)
    else:
        # check all param inputs are lists
        if all(type(x)==list for x in params.values()):
            search_type = "Gridsearch"
            models = GridSearchCV(model, param_grid=params, scoring=metric, cv=cv, 
                                  refit=refit, return_train_score=True)
            n_iter = len(list(itertools.product(*list(iter(params.values())))))
        else:
            search_type = "Randomsearch"
            models = RandomizedSearchCV(model, param_distributions=params,
                                        n_iter=n_iter, scoring=metric, cv=cv,
                                        refit=refit, random_state=random_state,
                                        return_train_score=True)
        
        start = time()
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            models.fit(X, y)
        
        print(search_type + " took %.2f seconds for %d candidates" % ((time() - start), n_iter))
        joblib.dump(models, save_path)
    
    return models

# %%
C_list = []
pwr = -5
for i in range(11):
    C_list.append(2**pwr)
    pwr+=2

gamma_list = []
pwr = -15
for i in range(10):
    gamma_list.append(2**pwr)
    pwr+=2
    
degree_list = list(range(1,5))

coef0_list = []
pwr = 1
for i in range(7):
    coef0_list.append(2**pwr)
    pwr+=1
    
poly_param_grid = {'svm_clf__C':C_list,
                   'svm_clf__gamma': gamma_list,
                   'svm_clf__degree': degree_list,
                   'svm_clf__coef0':coef0_list}

poly = SVC(random_state=42, kernel = 'poly', max_iter = 1e5)
poly_svm = Pipeline([
        ("scaler", StandardScaler()),
        ("svm_clf", poly)])

nl2_poly_gs = hyper_search(poly_svm, poly_param_grid, nl2, y2,
                             os.path.join(os.getcwd(), "Models", "moons_poly_gs.pkl"), 
                             overwrite=False)

pd.DataFrame(nl2_poly_gs.cv_results_).sort_values("rank_test_score")[["param_svm_clf__C", 
                                                                        "param_svm_clf__gamma",
                                                                        "param_svm_clf__degree",
                                                                        "param_svm_clf__coef0",
                                                                        "mean_test_score", 
                                                                        "std_test_score"]].head()
# Out:
#      param_svm_clf__C param_svm_clf__gamma param_svm_clf__degree  \
# 2829            32768                    8                     3
# 957                 2                  0.5                     4
# 1796              128                0.125                     4
# 1149                8                    8                     3
# 757               0.5                  0.5                     4
#
#      param_svm_clf__coef0  mean_test_score  std_test_score
# 2829                    2         0.996667        0.006667
# 957                     8         0.996667        0.006667
# 1796                    8         0.996667        0.006667
# 1149                    2         0.996667        0.006667
# 757                    32         0.996667        0.006667

# %% [markdown]
# ## Radial Basis Function kernel
# The most widely used kernel is the RBF kernel (also known as a Gaussian kernel)$^{4,8}$:
#
# $$K(\mathbf{x}_i,\mathbf{x}_k) = \exp\left(-\gamma||\mathbf{x}_i-\mathbf{x}_k||^2\right),$$
#
# where $\gamma$ is a free parameter to be optimised and $||\mathbf{x}_i-\mathbf{x}_k||^2$ is the squared _Euclidean distance_.
#
# $\gamma$ is often either a positive constant or  $\frac{1}{2\sigma^2}$.
#
# When classifying a test observation $\mathbf{x}^* = (x^*_1...x^*_p)$, only training observations close to $\mathbf{x}^*$ (in terms of Euclidean distance) will play a role in its class label. This is because $(x^*_j-x_{ij})^2$ will be large, so $\exp(-\gamma\sum^P_{j=1}(x^*_j-x_{ij})^2)$ will be small$^1$.

# %% [markdown]
# __Notes__
#
# _Euclidean distance_<sup>8</sup>
#
# $$d(\mathbf{x}_i, \mathbf{x}_k) \stackrel{\text{def}}{=} \sqrt{\left(x_{i1}-x_{k1}\right)^2+\left(x_{i2}-x_{k2}\right)^2 + \ldots + \left(x_{iN}-x_{kN}\right)^2} = \sqrt{\sum_{j=1}^D\left(x_{ij}-x_{kj}\right)^2}$$
#
# - _"if `gamma='scale'` (default) is passed then it uses 1 / (n_features * X.var()) as value of gamma"_$^{12}$
#
# - the minus sign inverts the the distance measure to a similarity score<sup>10</sup>

# %% [markdown]
# ### Hyperparameters<sup>2</sup>
# $\gamma$ is effectively acting like a regularization hyperparameter, so like $C$ if your model is overfitting reduce it and underfitting then increase it.
#
# - Increasing $\gamma$ (`gamma`) makes the bell-shaped curve narrower.
#     - Each instances range of influence is smaller.
#     - The decision boundary becomes more irregular.
#
# - Decreasing $\gamma$ makes the bell-shaped curve wider.
#     - Instances have a larger range of influence.
#     - The decision boundary becomes smoother decision.

# %%
gamma1, gamma2 = 1, 5
C1, C2 = 0.1, 10
hyperparams = (gamma1, C1), (gamma1, C2), (gamma2, C1), (gamma2, C2)

svm_clfs = []
for gamma, C in hyperparams:
    rbf_kernel_svm_clf = Pipeline([
            ("scaler", StandardScaler()),
            ("svm_clf", SVC(kernel="rbf", gamma=gamma, C=C))
        ])
    rbf_kernel_svm_clf.fit(nl2, y2)
    svm_clfs.append(rbf_kernel_svm_clf)

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(width_inch*2, height_inch*2), sharex=True, sharey=True)


with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    for i, svm_clf in enumerate(svm_clfs):
        plt.sca(axes[i // 2, i % 2])
        plot_predictions(svm_clf, [-1.5, 2.45, -1, 1.5])
        sns.scatterplot(nl2[:,0], nl2[:,1], y2, legend=False)
        gamma, C = hyperparams[i]
        plt.title(r"$\gamma = {}, C = {}$".format(gamma, C), fontsize=16)
        if i in (0, 1):
            plt.xlabel("")
        if i in (1, 3):
            plt.ylabel("")

fig_num+=1
plt.suptitle("Figure %d: Gamma Kernel Decision Boundaries"%fig_num)
plt.tight_layout()

plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2B9XcAAAAOXRFWHRTb2Z0d2FyZQBNYXRwbG90bGliIHZlcnNpb24zLjMuNCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8QVMy6AAAACXBIWXMAABJ0AAASdAHeZh94AAEAAElEQVR4nOzdd3iUVdrH8e/0lEnvJCGBQOgliBQRUcSua1ld11URxc7Kupa1rW3XtWMvvFbsHVTETu%2B9l0BIr6SXSabP%2B0ecISGTPpm0%2B3NdXOvOPDNz8mRmcs7vnOc%2BCofD4UAIIYQQQgghhBBCCCGEEH2CsrsbIIQQQgghhBBCCCGEEEIIz5HgXwghhBBCCCGEEEIIIYToQyT4F0IIIYQQQgghhBBCCCH6EAn%2BhRBCCCGEEEIIIYQQQog%2BRIJ/IYQQQgghhBBCCCGEEKIPkeBfCCGEEEIIIYQQQgghhOhDJPgXQgghhBBCCCGEEEIIIfoQCf6FEEIIIYQQQgghhBBCiD5Egn8hhBBCCCGEEEIIIYQQog%2BR4F8IIYQQQgghhBBCCCGE6EMk%2BBdCCCGEEEIIIYQQQggh%2BhB1dzdACCGEED3DsGHD2nzs7NmzeeihhwC49tpr2bJlCw8//DDXXHNNVzWvx1m3bh0ff/wxu3fvprq6mqCgIFJSUrjhhhuYMGFCk%2BMdDgcTJ06kpqam2ee86KKLeP755z3azkOHDrFkyRK2bNlCdnY2RqORoKAgEhMTOe200/jLX/5CaGioR1%2BzP1m8eDEPPPAAsbGxrFixotnjjh49yrXXXktpaSmxsbF8/PHHDBgwwIst7Rqvvvoqr732Gueccw6vvPJKq8fn5uZy5plnur1Po9Hg5%2BdHXFwc06dP569//SsxMTGebnKb3X///SxZsoQbbriB%2B%2B67r0PPsXnzZmbPnk1wcDCbN2/2cAs7x/m7c8fPz4%2BwsDBOPvlkrrvuOoYPH%2B7l1nW9yy67jP379/PUU09x2WWXdelrzZw5k7y8PBYuXMgZZ5zRpa8lhBBCCOEkwb8QQgghGklOTkav17d4THx8vJda0zO9%2BOKLLFy4EIDAwECGDBlCTk4Ov/32G8uXL%2Bfhhx/mb3/7W6PH5OXlUVNTg5%2BfX7Mh2qBBgzzWxpqaGv7zn//w3XffAaBSqYiPjycgIICKigq2b9/O9u3befvtt3n88ce58MILPfbaorGcnByuv/56V%2Bj/0Ucf9YnQv7NGjx6NVqt1/X%2BLxUJZWRkHDhxg//79fPTRRzz55JOce%2B653djKvk%2Bv15OcnOz6/w6Hg7q6OnJycli8eDFLly7lhRde4Oyzz%2B7GVgohhBBCiPaS4F8IIYQQjfz73/9m8uTJbT7%2BmWeeoa6ujoiIiC5sVc%2BxevVqFi5ciFqt5t///jdXXXUVAFarlYULF/Lqq6/yxBNPMG7cOEaNGuV6XGpqKgCTJ092TRp0lbq6OubMmcPevXvR6/XcfvvtXHbZZYSEhLiOyc3N5Y033uCbb77h3nvvJSAggBkzZnRpu/qjwsJCrrvuOoqKioiJieGDDz4gNja2u5vVI7z88svExcU1ub2wsJBnn32WZcuWcc899xAUFMTUqVO93r677rqLm266qdHnpr3Gjh3Ljz/%2BiFrdc4ddI0eO5KOPPmpyu9Vq5bXXXuPNN9/k/vvvZ9KkSQQHB3u/gX3AokWLsFgs3XoFixBCCCH6H6nxL4QQQohOGTBgAElJSQQGBnZ3U7xi0aJFAFx99dWu0B9ArVbz97//nXPOOQebzcbHH3/c6HGHDx8GYMiQIV3exqeffpq9e/cSHBzMp59%2Byty5c5uEl3FxcTz55JPMnTsXu93O448/js1m6/K29SclJSVcd9115OXlERUVxYcfftjvr5Zpi%2BjoaBYsWMA555yDxWLhoYcewmKxeL0dkZGRJCUldaoUlq%2BvL0lJSSQkJHiwZd6hVqu58847SU5OxmAwsGzZsu5uUq81cOBAkpKS8PPz6%2B6mCCGEEKIfkeBfCCGEEKKNbDYb27dvB%2BCcc85xe4yzfvP%2B/fsb3e6t4D8zM5OvvvoKgIceeqjVvRvmz59PaGgoeXl5bNiwoUvb1p9UVFRw/fXXk5mZSWRkJB9%2B%2BCEDBw7s7mb1GgqFgkcffRSdTkdeXh4//PBDdzep30pJSQHq96kQQgghhBC9hwT/QgghhOiUa6%2B9lmHDhjVZ4Q6wceNGbrzxRk455RRSUlK46qqrWL58OZs3b2bYsGFce%2B21rmNzc3MZNmwYw4YNw2AwNHmuw4cPu%2B539/o7duzg8ccfZ8KECUyYMIE5c%2BZgt9tdx23dupV58%2BZxyimnMHr0aGbMmMGDDz5IVlZWm39Wh8PBq6%2B%2ByuOPP96oJnZDtbW1AE1WzztL/QwdOrTNr/fqq68ybNgwZs6c2ebHfP3119hsNmJjY7noootaPd7Hx4d58%2BY1O0lw6NAh/v3vf3POOeeQkpLCmDFjOP3007n77rubTG7A8d/HwYMHWb9%2BPbNnz2bChAmcfPLJzJ07l7179wJQVlbGI488wqmnnsro0aM555xzWLRoEQ6Ho9Hz3X///QwbNozff/%2BdvXv3cuuttzJp0iTX%2B2ndunVA/Xl/7rnnmDlzJqNHj2bmzJm8%2BOKLbleK22w2vvvuO26%2B%2BWbX60%2BYMIGLL76YV155herq6jad6%2BbU1NQwd%2B5cDh8%2BTEREBB9%2B%2BCGJiYktPubQoUPcfffdTJ8%2BndGjRzNt2jTuvPNO9u3b1%2BRY5%2BfnlltuYdu2bVx00UWMHj2aM844g19%2B%2BcX1WbrwwguxWq28/fbbXHjhhYwdO5bJkydz%2B%2B23u34P7vz%2B%2B%2B/MnTuXyZMnM2bMGGbNmsUTTzzBsWPHOnVe2issLMw1kbZy5com95vNZhYtWsSf//xnUlJSGD9%2BPJdeeinvvvsuJpOp2eddtWoVt9xyi%2Bt3P3PmTB599NEmP5/zvffMM880ur20tJSnnnqKc845p9F756WXXqKioqLRsc7flbvyaSaTiffff5/LL7%2BclJQUxo0bx4UXXshLL71EZWVlk%2BOd7fn55585dOgQd9xxB1OmTGHMmDGcf/75LFy4ELPZ3OzP3VFWqxWg2dXqv/76K3PnzmXSpEmu9%2BGDDz5IRkZGk2Od32nz5893%2B1zPPPMMw4YN4/777290%2B7Bhw0hJScHhcPDVV19x2WWXMX78eE466SSuv/561q9f7/b5HA4HX3/9tescT506lQceeKDV9/K2bdu45557mDlzJuPGjWPcuHHMmjWLhx9%2B2O3fDGf7ioqKmDt3LmPHjmXKlCksWLAAqN/cd9iwYW7fx%2B357EP998srr7zCRRddxJgxYxg/fjznnXce//vf/ygqKmrx5xJCCCFE/9Jzi00KIYQQold77733XIFZZGQkgwYNYv/%2B/dx%2B%2B%2B2ceeaZHn%2B9Z555hl27dpGcnExFRQUREREolfVrHN544w1efvllAEJCQkhOTiYnJ4dvvvmGH3/8kZdffrlN9e3VanWrx61YsQKApKQk121ms5msrCyUSiV%2Bfn689tpr7NmzB6vVyuDBg7n00ksb7QfQGatXrwZgxowZKBSKNj3mmmuucXv7kiVLeOihh7DZbISEhDBo0CBqamrIzc3lhx9%2B4JdffuH999/n5JNPbvLYzz//nC%2B%2B%2BILAwEASEhLIyMhg3bp1rg2F77nnHkpKShg0aBAqlYrMzEyeeuopamtruf3225s836pVq/j222/RaDQkJiaSk5PDjh07uPnmm3nzzTdZsGABR44cYeDAgcTExJCdnc3ChQspKSnhf//7n%2Bt5LBYLt912G2vXrgXqS3BERUVRWFjIoUOHOHToEL///jtff/11o41 ...

# %%
rbf_param_grid = {'svm_clf__C':C_list,
                  'svm_clf__gamma':gamma_list
                 }

rbf = SVC(random_state=42, gamma="auto")
rbf_svm = Pipeline([
        ("scaler", StandardScaler()),
        ("svm_clf", rbf)])

nl2_rbf_gs = hyper_search(rbf_svm, rbf_param_grid, nl2, y2,
                            os.path.join(os.getcwd(), "Models", "moons_rbf_gs.pkl"),
                            overwrite=False
                           )

pd.DataFrame(nl2_rbf_gs.cv_results_).sort_values("rank_test_score")[["param_svm_clf__C", 
                                                                 "param_svm_clf__gamma", 
                                                                 "mean_test_score", 
                                                                 "std_test_score"]].head()
# Out:
#     param_svm_clf__C param_svm_clf__gamma  mean_test_score  std_test_score
# 58                32                    2         0.996667        0.006667
# 78               512                    2         0.993333        0.008165
# 107            32768                  0.5         0.993333        0.008165
# 87              2048                  0.5         0.993333        0.008165
# 88              2048                    2         0.993333        0.008165

# %% [markdown]
# $C$ and $\gamma$ are tightly coupled.
#
# Generally if you have a larger/narrow `gamma` (e.g. $\gamma = 5$) you'll need more regularisation, so a larger $C$.
#
# If you have a smaller/wider `gamma` (e.g. $\gamma = 1$), a smaller value of $C$ should be used<sup>7</sup>.

# %%
grid_df = pd.DataFrame(nl2_rbf_gs.cv_results_)[["param_svm_clf__C", 
                                                  "param_svm_clf__gamma", 
                                                  "mean_test_score"]]
grid_df = grid_df.sort_values(["param_svm_clf__C", "param_svm_clf__gamma"])
grid_np = np.array(grid_df["mean_test_score"]).reshape(len(C_list), len(gamma_list))

tidied_gamma_lst = list(pd.Series(gamma_list).apply(np.format_float_scientific, precision=1)[0:3].values)
tidied_gamma_lst = tidied_gamma_lst+list(np.array(gamma_list[3:]).round(3))

grid_plt_df = pd.DataFrame(grid_np, 
                           index = np.array(C_list).round(2), 
                           columns=tidied_gamma_lst)


fig = plt.figure(figsize = (width_inch*1.5, height_inch*1.5))
ax = sns.heatmap(grid_plt_df, 
                 vmin=min(grid_df["mean_test_score"]), 
                 vmax=max(grid_df["mean_test_score"]),
                 #cmap="YlGnBu_r"
                )
ax.collections[0].colorbar.set_label("Accuracy")
ax.invert_yaxis()
ax.set_xlabel("Gamma")
ax.set_ylabel("C",rotation = 0)
plt.yticks(rotation = 0)
plt.xticks(rotation = 0)
fig_num+=1
plt.suptitle("Figure %d: GridSearch Results for Gamma and C on the Moons Data"%fig_num)
plt.tight_layout()
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2Bi9qxdUS1FFaVFzajwQYgIiU0Sme/fH37n/XWahDiJjNPH/XY7t9Z7XNd13mfknNd5Xa/LyTAMQwAAAAAAAA7KOaMHAAAAAAAA8DgR/AAAAAAAAA6N4AcAAAAAAHBoBD8AAAAAAIBDI/gBAAAAAAAcGsEPAAAAAADg0Ah%2BAAAAAAAAh0bwAwAAAAAAODSCHwAAAAAAwKER/AAAAAAAAA6N4AcAAAAAAHBorhk9AMAR%2BPr6pvjYHj166OOPP5Ykde/eXX/99Zc%2B%2BeQTvfLKK49reJnOrl27tHjxYh0%2BfFi3b99Wrly5VLVqVb322muqVq1asudt2rRJy5cv1z///KPIyEgVK1ZMrVu3Vu/eveXu7p7m4wwODtaqVau0Z88eBQUFKSIiQjly5FDRokVVv359dezYUUWKFLGrbetzZsOGDbJYLCk6p127dgoICNCYMWPUrl27RPsPHjyolStXat%2B%2BfQoPD5eTk5MKFCig6tWr68UXX1TdunXtGmtmNWXKFE2dOlVNmzbV5MmTU93en3/%2BqR49eiS738nJSdmyZVPBggVVrVo19evXTyVKlEh1v%2BnlQdcrJiZGly9flo%2BPz2PrPzg4WGPGjNGBAwd09%2B5d5c%2BfX%2BvXr1eOHDkeW58PExcXp82bN%2BuXX37RsWPHzNdNvnz59PTTT6tJkyZq3ry5nJycMmyMSBvbt29X//79VaRIEW3btu2Rz4%2BKitLatWu1ZcsWnThxQrdu3VK2bNlUqlQpNWzYUF26dNETTzzxGEb%2B%2BCUkJOjcuXMqWbKkuc36fpg7d279%2BeefGTY26%2BckSSpbtqzWr1//0HNGjRqlRYsWSZLatm2rsWPHPtYxZkYXLlxQo0aNktzn5uYmLy8vFS1aVH5%2BfurcubMKFy6c5mM4ffq0SpUqlebtAqlB8ANIQxaL5aEf5B/nl4usYMKECZo5c6Yk6YknnlDp0qUVHBysLVu2aOvWrfrkk0/UtWtXm3MSEhL08ccfa82aNZKkEiVKKE%2BePDpz5owmTpyo3bt3a%2B7cuWkWAImNjdX48eO1cOFCxcfHy8nJSUWKFFGxYsV0%2B/ZtHT9%2BXMeOHdPcuXP17rvv6tVXX02TflNj7Nixmj9/vgzDUL58%2BVS6dGndvXtXISEhWrNmjdasWaNWrVrpq6%2B%2Bkqsrb/0Pk1QQzjAMhYeHKygoSEFBQfL399e8efNUo0aNDBhh2tm9e7dGjBihHj16PLYgbFxcnPr06aOgoCDzC6O7u3uGBj4OHz6sYcOG6ezZs5KkHDlyqHjx4nJzc1NISIg2bdqkTZs2afbs2ZoxY4YKFSqUYWNFxjp48KDeeecdXbp0SZKUJ08e%2Bfr6Kjw8XIcPH9ahQ4e0YMECTZw4UbVq1crg0T6ao0eP6rPPPlPt2rU1bNiwjB7OA504cULBwcEP/BxlGIZ%2B%2BeWXdBxV5lexYkWbz0exsbG6du2ajh8/roCAAC1atEijR49Ws2bN0qS/8PBwffnllwoODtbq1avTpE0grfAJGEhDw4cPV%2B3atVN8/FdffaWoqCgVKFDgMY4q89ixY4dmzpwpV1dXDR8%2BXF26dJF074vRzJkzNWXKFI0aNUqVK1dWhQoVzPMWLlyoNWvW6IknntCUKVNUp04dSdKhQ4c0cOBA7du3T3PmzNGAAQNSPcaEhAQNGjRI27dvl7u7u/r27auuXbvK29vbPObKlSuaP3%2B%2Bvv/%2Be40dO1bZsmVT586dH6mfn376SVLaBMOWLVumefPmKX/%2B/Bo/frx5fSQpPj5ea9as0ejRo%2BXv768CBQrogw8%2BSHWfjm7ZsmXJ7jtx4oQGDRqk8%2BfP6/3339evv/4qFxeXdBxd2po5c6bOnTv3WPs4ceKEgoKC5OzsrDVr1uipp556rP09zL59%2B9SnTx/dvXtXFSpU0ODBg1W3bl0zMJiQkKA//vhDY8eO1fHjx9W9e3etX79eXl5eGTpupL9ff/1V77zzjmJjY9W0aVO9/fbbNr9mnzp1SmPGjNHu3bvVt29fLV261ObvV2a3ZMkSBQQEPNJnl4zg6upqZmr17t072eP%2B/vtvhYWFpePIMr9JkyapaNGiibZfunRJX3/9tTZu3KghQ4YoV65caZIhunPnTm3atClLvQ7w30HNDyADPfnkkypVqlSWTZV9VPPnz5ckdevWzQx8SPc%2B1Lz55ptq2rSp4uPjtXjxYnNfRESEmaL/7bff2nyxr1Klit59911JSrNfF%2BbMmaPt27fLzc1Ns2fP1uDBg20CH5KUP39%2BDRkyRMOHD5ckjRs3Tjdv3nykfkqVKmX%2B%2Bp1as2fPliSNHDnS5vpIkouLizp06GCOdenSpbpx40aq%2B/wvK1u2rMaMGSNJunjxonbt2pXBI8r8rl27JknKly9fhgc%2Bbt%2B%2BrXfeeUd3795VgwYNtHz5cvn5%2BdlkRDk7O6t%2B/fpaunSpSpQoofPnz5uvM/x3hIWF6eOPP1ZsbKx69OihyZMnJ0rjL1OmjGbNmqUaNWro7t27Gj58uAzDyKAROy5rRs2WLVseeJw166NcuXKPfUxZXaFChTR%2B/Hg1bdpUsbGx5nMdcGQEPwCki/j4eB04cECS1LRp0ySPadCggSQpICDA3LZ161ZFRESoVq1a8vPzS3ROkyZN9NZbb6lPnz5KSEhI1Rhv375tTskZOHBgokDCv3Xt2lUWi0W3b9/Wpk2bUtW3vW7evKmQkBBJUqVKlZI9rnXr1vL09FR0dLROnjyZXsNzWNWrV1f27NklSWfOnMng0WR%2B8fHxkvRYavM8qrlz5%2BrKlSvKmzevvv766weO6YknntDgwYMl3QuwpvY9BlnLhAkTdOPGDZUoUeKBGXOurq768MMPJUnHjx/X/v3702uI/xn169eXl5eXDh06lGxmh2EY2rx5s/LmzZvlph9lFCcnJ3322Wfy8PBQSEiI/P39M3pIwGPFtBcgAz2o4OmePXv0/fff6/jx44qKilLZsmXVp08f5ciRQz169FCtWrXMgl73F7b6%2B%2B%2B/zS9lVidPnlTr1q0lSYGBgYn6X7ZsmTZs2GAWEnv66ac1d%2B5cOTvfi4/u27dP8%2BfP18GDB3Xr1i3ly5dP9erVU79%2B/VS8ePEU3VfDMDRlyhSFhoYmW%2BAzMjJS0v99UbJeB0nJFu7KmTOnBg4cmGj7mjVrzA%2Bj99/nB/H391dERISyZcumnj17PvR4Jycn9evXTxcvXlS9evXM7dbHo0yZMpo4caI%2B/vhjHT9%2BXLly5VL//v31yiuvJFvw1DAMrV69WsuXL9fp06fl6emp559/3vwC9m/3/1q9Y8cOdejQIcnj3N3dtWrVKnl6eibKZJGkq1evas6cOdq2bZtCQ0Pl4eGh8uXLq0uXLsnOA75y5YoWLVqknTt3Kjg4WFFRUcqZM6fKly%2Bvjh07JgpyffDBB1q7dq0mTpyo//3vf1q8eLGio6P11FNPaeHChWb9h/3792vx4sU6dOiQrly5ojx58qhu3brq379/slkDFy5c0LRp07Rz507dvHlThQoVUtOmTfXGG28kej2khfsLYCb1K%2B%2BdO3c0f/58/fLLLzp//rxcXFxksVjUrl07tW/fPslpMlu2bNGyZct07NgxRUZGKnfu3Hr66afVtWtX1a9f3%2BbYhg0bKiQkRDNnzjSDhverXbu2bty4oYULFyabzv7vAq9ffPGFvvjiC7355psaNGiQpHtFSr/77jv98ccfCgsLk6enp0qWLKmmTZuqW7duypYt2wOv07%2BL7oWEhJjP/fvHduvWLS1YsECbN2/W%2BfPn5ezsrJIlS6pFixZ65ZVX5OnpmeT937JliyZMmGBmazVo0EBff/11suMxDEMrV66Up ...

# %% [markdown]
# __Extra Example__
#
# Lets have a look at the decision boundaries for our "optimal hyperparameters" as a comparison to those by the linear models we saw earlier.

# %%
nl1_poly_gs = hyper_search(poly_svm, poly_param_grid, nl1, y1,
                             os.path.join(os.getcwd(), "Models", "nl1_poly_gs.pkl"), 
                             overwrite=False)

pd.DataFrame(nl1_poly_gs.cv_results_).sort_values("rank_test_score")[["param_svm_clf__C", 
                                                                        "param_svm_clf__gamma",
                                                                        "param_svm_clf__degree",
                                                                        "param_svm_clf__coef0",
                                                                        "mean_test_score", 
                                                                        "std_test_score"]].head()
# Out:
#      param_svm_clf__C param_svm_clf__gamma param_svm_clf__degree  \
# 387             0.125                  0.5                     3
# 514             0.125             0.007812                     4
# 1545               32              0.03125                     3
# 906                 2                0.125                     3
# 506             0.125                0.125                     3
#
#      param_svm_clf__coef0  mean_test_score  std_test_score
# 387                     8         0.983333        0.014907
# 514                    64         0.983333        0.014907
# 1545                   16         0.983333        0.014907
# 906                     4         0.983333        0.014907
# 506                    64         0.983333        0.014907

# %%
nl1_rbf_gs = hyper_search(rbf_svm, rbf_param_grid, nl1, y1,
                            os.path.join(os.getcwd(), "Models", "nl1_rbf_gs.pkl"),
                            overwrite=False
                           )

pd.DataFrame(nl1_rbf_gs.cv_results_).sort_values("rank_test_score")[["param_svm_clf__C", 
                                                                 "param_svm_clf__gamma", 
                                                                 "mean_test_score", 
                                                                 "std_test_score"]].head()
# Out:
#    param_svm_clf__C param_svm_clf__gamma  mean_test_score  std_test_score
# 29              0.5                    8         0.983333        0.014907
# 27              0.5                  0.5         0.983333        0.014907
# 28              0.5                    2         0.983333        0.014907
# 37                2                  0.5         0.983333        0.014907
# 18            0.125                    2         0.983333        0.014907

# %%
 with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fig, axes = plt.subplots(ncols=2, nrows=3, figsize=(width_inch*2, height_inch*3))
    
    axes = axes.flatten()
    plt.sca(axes[0])
    sns.scatterplot(nl1[:,0], nl1[:,1], y1, legend=False)

    plt.sca(axes[1])
    sns.scatterplot(nl2[:,0], nl2[:,1], y2, legend=False)

    plt.sca(axes[2])
    plot_predictions(nl1_poly_gs, [-5, 5, -5, 7.5])
    sns.scatterplot(nl1[:,0], nl1[:,1], y1, legend=False)

    plt.sca(axes[3])
    plot_predictions(nl2_poly_gs, [-1.5, 2.5, -1, 1.5])
    sns.scatterplot(nl2[:,0], nl2[:,1], y2, legend=False)

    plt.sca(axes[4])
    plot_predictions(nl1_rbf_gs, [-5, 5, -5, 7.5])
    sns.scatterplot(nl1[:,0], nl1[:,1], y1, legend=False)

    plt.sca(axes[5])
    plot_predictions(nl2_rbf_gs, [-1.5, 2.5, -1, 1.5])
    sns.scatterplot(nl2[:,0], nl2[:,1], y2, legend=False)
    
    for i in range(4):
        axes[i].axes.xaxis.set_visible(False)

    axes[0].text(-6.5, 0, 'Data')
    axes[2].text(-6.5, 0, 'Poly')
    axes[4].text(-6.5, 0, 'RBF')
    
    fig_num+=1
    plt.suptitle("Figure %d: Best Non-Linear SVM Model Decision Boundary Using GridSearch"%fig_num)
    plt.tight_layout()
    
    plt.close()
    display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%%2B84tnvkkUcIDQ3lp59%2BKsTWF7zNmzczcuRIWrZsSZ06dWjdujXPPPMMe/fuzbSu/TvKyX/z58%2B/pXZNmTLF5b4bNmxIly5dmDhxIseOHbul97kdrl69SlxcXI7Xt3%2BPXbt2JTk5Oct158%2BfT2hoKPfff/%2BtNjPfdOrUKdd/85dffpnQ0FAmT56cjy0regzDYOnSpYwaNYp27dpRp04dmjdvzn333cfkyZMJCwvLtE2vXr0IDQ3ltddey/H73H///YSGhvLpp58C/x5H9v%2BOHj2a7T4OHz6cYZucSn%2Be6NOnT462mTRpkmObl19%2BOcfvlVf27%2BdWz1Pw7zXnxIkTOVrffuzf/F/NmjVp2LAhnTp1YtSoUaxYseKW23YrIiMjHW1LSEjI836K8rXV1TWmVq1atGzZkoceeogffvgBq9Va2E297datW0doaCidOnUq7Kbkiv3e4JFHHsl23R07duT6/JXVe44ZM%2BaW9lMQjh07xnvvvUe/fv1o3LgxtWvXplWrVjz00EPMmDGDmJiYPO03r%2BeD5s2bExoayo4dO5wu37BhA2PHjqVTp07Uq1ePJk2a0KNHD9566y0OHTqUp7YWZf/Vex8hhLiTmQq7AUIIIfJX9erV8fb2znKdoKCgAmpN0fTpp58yY8YMAIoXL07VqlWJiIhg1apVrFmzhtdff52HHnrIsX716tWz7Ei5cuUKERERKIpy275bb29vqlev7vi3YRgkJSURERHB/PnzWbx4MZ988gn33HPPbXm/3Pr%2B%2B%2B%2BZMmUKc%2BfOpXjx4rna9ty5c0yZMoWXXnopn1onipKEhARGjhzJzp07AahQoQI1a9bk2rVrnDlzhuPHjzN79mxeeuklHn30Ucd2ffr04aOPPmLVqlX83//9H2azOcv3OX36NIcPHwZwGXhauXIlNWvWzHI/y5cvz83Hc%2BrYsWNERERkeT4wDKPQO8sLQ6lSpahUqZLj34ZhkJCQQGRkJGvWrGHNmjW0adOGzz//PNtrmbg1N98vWK1WYmJi2Lt3L3v27GH58uX88MMPuLm5FWIrhXAtPj6et99%2Bm0WLFgGgaRpBQUH4%2BPgQGxvLnj172LNnD9988w1vvfUWvXr1KtT2Wq1Wxo0bx7JlywAoW7YsoaGhxMXFERkZyenTp5k7dy7Dhw9nwoQJhdpWIYQQ/20SQBBCiLvca6%2B9RvPmzXO8/uTJk0lKSsLf3z8fW1V0bNiwgRkzZmAymXjttdcYPHgwkPZQN2PGDKZMmcKkSZOoX78%2BtWvXBuD11193ub%2BUlBT69%2B8PwNNPP03Tpk1vSztr1arF7NmzM71utVqZOnUq06dP5%2BWXX6ZZs2b4%2BvrelvfMjffee%2B%2BWtv/%2B%2B%2B/p2bMntWrVuk0tujOMHTuWJ598Ej8/v8JuSoF57bXX2LlzJw0bNmTy5MkZOo/j4uKYPn06s2bN4t1336VChQp07twZgPvuu49PPvmE2NhYtm7dSvv27bN8n8WLFwPQqFGjDO8BYDKZsFqtrFq1iueeey7L/axcuTIvHzPTe61cuZLHH3/c5Xp79%2B7l8uXLt/Red6J27drx/vvvZ3rdZrOxevVq3njjDTZv3sxzzz3HV199hclUsI8vAQEB/PXXXwB4eXnleT93wrXV1f3C6dOnefLJJ9m7dy9ffvklL7zwQiG0ThS2IUOG0KNHjyIbyEtKSmLYsGEcPHgQb29vRo0axf3335/h%2BhoZGcm0adP4448/eOmll/Dx8cn2WpLe7Tof2H322WcsW7aMypUr88knn2S4B0pOTubHH3/k008/ZdasWZQvXz5HM06EEEKI/CApjIQQQmRQvnx5QkJCcj2K/E71/fffA2kPxvbgAaR1%2Bj3zzDN069YNm82W47QTH3/8MSdPnqRevXqMHj06P5qcgclk4vnnn6d69eokJCSwdOnSfH/P201RFKxWK6%2B99ho2m62wm1OgypQpQ0hICCVLlizsphSIiIgIli1bhtlsZtq0aZk69osXL86ECRPo27cvANOnT3csCwgIoFWrVgA5Os6XLFkCOJ99UK1aNfz8/Dh58iTh4eEu93Hs2DHCw8OznaWQlWbNmgGwatWqLNezzz64lfe6m2iaRrdu3fj2228xm81s3ryZBQsWFHg7zGYzISEhhISEoChKnvdzJ19bQ0JCGD9%2BPAC//vprIbdGFJaSJUsSEhJCQEBAYTfFqffff5%2BDBw/i6%2BvLzz//zOOPP54pOF%2BhQgXeffddHn/8cXRd56233srVfcftOh8AJCYmMmfOHCAtkHDzAAoPDw%2Beeuopnn76aQC%2B%2BuordF2/pfcUQggh8koCCEIIIf6zbDYbe/bsAaBbt25O1%2BnYsSOAIxVKVo4ePcrs2bMxmUz873//K9CRsg0bNgTSRoreafr374/JZOLw4cN89913hd0ckY%2BOHTuGYRgEBgZmGTQZOHAgkPabSp8uzB5YWLNmDampqS63//vvv4mIiMDDw4Pu3btnWq6qqmNmQ1YzDOxpJe69917XHyobbdq0wcvLi3379rmcYWAYBitXrqRkyZKOgINIU6dOHR5%2B%2BGEAZsyYgWEYhdyi/6bGjRsDcO3atTznjxciv4SHh/P7778D8Oqrr2Zb72HMmDGULFmS8%2BfPs3Xr1oJoYibh4eEkJibi5uZGjRo1XK5nvx5euXKFixcvFlTzhBBCiAwkgCCEECKDrAo9btu2jSeeeIJWrVrRsGFDBg8ezJo1axwF%2BtJPrc6u0NyJEyecFvWzv//evXt56623aNSoEY0aNWLYsGEZRl7t2rWL0aNH06pVK%2BrUqUP79u155ZVXOHv2bI4/q2EYTJkyhbfeeitDfYH0EhMTAXI0Qu3DDz9E13UGDRrk9GEwfQHX283eyepqSn1uv6/o6Gjee%2B89unXrRp06dWjUqBF9%2BvThs88%2BIzY21rGevaiiXe/evbMsFOhMzZo1GT58uGN/EREROd7Wzp4eplmzZtSpU4eOHTvyyiuvOC3Ga/87vP3228TExPD222/ToUMHx/fyf//3fwWWSsZZIUH772nEiBEkJibyySef0LVrV%2BrWrUvr1q0ZN26c088FoOs68%2BfPZ8iQITRp0oR69erRo0cPPvvsM27cuOF0G5vNxqJFi3jqqado06ZNhr/3F198kWm79O3bvXs3vXv3dnzn2eXwtwfV7LmdXWnQoAELFixgzZo1aJrmeL1r1654e3sTHx/Phg0bXG5vT1/UpUsXl%2Bk27PVCsgogrFy5Em9vb9q0aeP6Q2XD3d2d9u3bYxiGy1kI%2B/fv5%2BLFi3Tt2jXD571ZSkoK3333HQMGDKBhw4bUr1%2BfXr168dlnn3H9%2BnWn2xiGwbx58xzbtGzZkokTJ2Z7jEdHRzN58mS6detGvXr1aNq0KY8%2B%2BuhtqQmRWwMGDADSjpuTJ09mWn7s2DFefPFF2rZtS506dWjdujXPP/98lsVHo6Oj%2Beyzz%2BjZsycNGjSgUaNGDBkyxJGexC6ra9mqVat47LHHHOedNm3aMGrUKDZv3pzp/bK6th4%2BfD ...

# %% [markdown]
# ### Standardization$^{11}$
#
# SVMs, along with many other machine learning estimators (e.g. l1 and l2 regularizers of linear models), are sensitive to feature scales.
#
# If a feature has a variance orders of magnitude larger than others, it might dominate the objective function and make the estimator unable to learn from other features correctly as expected.

# %%
# copied from https://github.com/ageron/handson-ml2/blob/master/05_support_vector_machines.ipynb
Xs = np.array([[1, 50], [5, 20], [3, 80], [5, 60]]).astype(np.float64)
ys = np.array([0, 0, 1, 1])
svm_clf = SVC(kernel="linear", C=100)
svm_clf.fit(Xs, ys)

fig = plt.figure(figsize=(width_inch*2, height_inch))
plt.subplot(121)
plt.plot(Xs[:, 0][ys==1], Xs[:, 1][ys==1], "bo")
plt.plot(Xs[:, 0][ys==0], Xs[:, 1][ys==0], "ms")
svc_decision_boundary(svm_clf, 0, 6)
plt.xlabel("$x_0$", fontsize=20)
plt.ylabel("$x_1$    ", fontsize=20, rotation=0)
plt.title("Unscaled", fontsize=16)
plt.axis([0, 6, 0, 90])

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(Xs)
svm_clf.fit(X_scaled, ys)

plt.subplot(122)
plt.plot(X_scaled[:, 0][ys==1], X_scaled[:, 1][ys==1], "bo")
plt.plot(X_scaled[:, 0][ys==0], X_scaled[:, 1][ys==0], "ms")
svc_decision_boundary(svm_clf, -2, 2)
plt.xlabel("$x_0$", fontsize=20)
plt.ylabel("$x'_1$  ", fontsize=20, rotation=0)
plt.title("Scaled", fontsize=16)
plt.axis([-2, 2, -2, 2])

fig_num+=1
plt.suptitle("Figure %d: Sensitivity to Feature Scales"%fig_num)
plt.tight_layout()
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%...%2Bedd95hxYoVlJaWEh8fz8CBA7nqqqsYNGhQ2D5FRUW8/PLLfPXVV%2BTl5REVFUW/fv244oorGD16dJOOz%2BfzMX36dObOnUtGRgZFRUXExMTQuXNnRo4cycUXX0y7du2a9JwH25gxY9i8eTMvvfRSyP3KysoiOTm5we0b6rnnnuNf//oXp59%2BOs8%2B%2B2ydfWVlZZSXlx/U%2BxgIBNiwYQM9evQ4aOeA/X//N7eqqiq2bdtGly5dDsn5m0JeXh7vvvsuP/zwA1u2bKGiooJWrVrRp08fTjvtNH73u99htVoPydiO1r/nIiIiIg2lwL%2BIiIgcsVwuFzExMXttcyQH3ZrCU089xUsvvQRAXFwcKSkp5Obm8uWXX/L111/zl7/8hYkTJ9bpk5%2Bfz8SJE8nNzcVut9OjRw8KCwtZtGgRixYt4uabb%2Bamm25qkvHl5%2Bdz9dVXk5mZicVioWvXrnTo0IHt27ezZs0aVq1axbRp0/jHP/7BmWee2STnPFTKysp4/PHHmTt3LgsXLmy2886ePZtHHnmEv//97wct8L9q1Sruv/9%2Bhg0bxl133XVQzrGnw/n9v2DBAh588EEmTZp0xAal58yZw7333ovX68XpdNKtWzcsFgubN29m3rx5zJs3j2nTpvHqq6%2BSlJR0qIcrIiIiIntQ4F9ERESOWPfddx/Dhg1rcPtHH30Ur9d71ASpvvvuO1566SVsNhv33Xcfl1xyCQDV1dW89NJLPPfcczz00EMcc8wx9O3bN9jv73//O7m5ubhcLl544YVg8PS9997jgQce4LnnnmP48OEMHjz4gMd40003kZmZyZgxY3jwwQdp27ZtcF9%2Bfj6PPfYYM2fO5M4776Rr167069fvgM/ZHKZNm4bP56NDhw7BbatXr%2Ba9994jISGhQe0b69JLL%2BXMM88MCYY/%2BeSTFBQU7PdxG%2BLdd99l9erVjXo/HqjGvv%2Bb00svvcSGDRsO9TD2W3p6OnfeeSd%2Bv58HH3yQ888/H7vdHty/aNEiHnjgAdLT07nuuuv46KOPMAzjEI5YRERERPakGv8iIiJy1OjYsSPJycnExcUd6qE0i2nTpgE1AeHaoD%2BAzWbjpptu4vTTT8fv9/POO%2B8E95WVlfH1118DNQmA3Z%2BYvuSSSzj99NMB%2BOSTTw54fEuWLGHFihW0bduWp59%2Buk7QH6Bt27Y8%2BuijDB06FJ/PxyuvvHLA52wuXbt2JTk5GafTeVDah9OqVSuSk5OPuLJIcvh588038fl8TJo0iYsvvrhO0B9g%2BPDhvPDCC0RERLB69Wq%2B//77QzRSEREREamPAv8iIiIiLZDf72fZsmUAwWD9nmprya9evTq4bfv27fj9fqCmlMqeap%2B4z8vLO%2BAxrlmzJnieyMjIsG0sFgvnn38%2BUFNORkQOvtq/Cf3796%2B3TXJycnCNEL03RURERA4/CvyLiIjIUePyyy/H7XbXecK91qJFi7jmmms44YQTGDhwIJdccglff/01P/74I263m8svvzzYdtOmTbjdbtxuN%2BXl5SHHyszMDO4Pd/7ly5fz4IMPMmjQIAYNGsTkyZMJBALBdj/99BNTpkzhhBNOoF%2B/fowaNYp77723UaVDTNPkueee48EHHwwbwAfweDwAwUA/QFJSUnCxzrS0tJA%2Ba9euBWpmT%2Bxu%2BvTpYa95b2y2mqqTv/76Kzt27Ki33WmnncaMGTP43//%2BF3Z/Y%2B5X7et53XXX4fF4ePLJJzn11FPp378/J554InfccQfr168P6WeaJh988AETJ05k0KBB9OvXj5NPPpnbb7%2BdlStXhrQfM2YMbrebb775Bqh57SdNmgTULJy8573as/1dd92F2%2B3m73//e7335bLLLsPtdvOf//wHqFnc1%2B12c8sttwC/vSabN28G4Prrr8ftdjN9%2BnQeeeSR4H2ozz333IPb7eb555%2Bvt03te%2BHjjz8G4PXXX8ftdnP33XfXaZeTk8Nf//pXxowZQ79%2B/Rg6dChXXnkln332Wb3HPli%2B%2Buorrr76aoYNG0b//v0ZO3YsDz30EPn5%2BfX2%2Beabb7j55psZNWoU/fv3Z%2BDAgYwbN46pU6fWKaNU%2B/u1ZMkSoGbWjNvt5rnnngNCX6M9PfrooyH3r/Yen3322axbt46LLrqI/v37M2LEiDp/y6qqqpg2bRrnn38%2BAwcO5Nhjj%2BW8887jtddeo7KyslH3qPa9%2Bd133%2B213cMPP8znn3/OlVdeGbKvrKyMl19%2BmfPOO49BgwZx7LHHcv755/Of//ynzt%2B7Wrm5ufzjH/9g/PjxwffYiBEjmDJlCosXL27U%2BHfs2MGjjz7K6aefzoABAzjuuOO44oor%2BPzzz8O2b%2Bz7W0RERORIoMC/iIiIHPVef/11Jk%2BezA8//IDVaqVHjx6sXr2aG2%2B8kTfffLPJz/foo4/yn//8h06dOhEdHU1SUhIWS83HshdeeIHLLruMr776ikAggMvlwuPx8NFHH3HOOefsMxBXy2azMWrUKC6%2B%2BGJiY2PDtpk3bx5Q8%2BRurejoaMaNGwfAgw8%2BGAwaA8yaNYvZs2djs9m48MIL9%2Bvad3f88ccDNYHwiy66iPfee4%2BdO3eGtHM6naSmpoZdm2F/71d5eTkTJ07k3//%2BN1VVVSQnJ1NYWMisWbO46KKLyM3NrdP%2B/vvv57777mP58uUkJSUFzzN79mwuvvhivvrqq71eq8vlCiZgbDZbMOlTn3POOQeAL774ImyQdOvWrSxduhS73V7vosetW7dm0KBBREREAJCSksKgQYNo3bo15557LlCzCG1RUVFI38rKSubOnYthGMGxhBMZGRk8JkC7du0YNGgQ3bt3D7b56quvOOecc/jf//5HYWEhbrebmJgYFi5cyK233srtt99eJ/l0sJimyV/%2B8hemTJnC/Pnzsdvt9OrVix07dvD2229zzjnnhH1y/c9//jPXX389c%2BfOxWKx4HK5iIuLIzs7OxhoLywsBCA2NpZBgwYF11no0qULgwYNOqC1G2qVlpYGF8JOSUmhtLQ0%2BN4tKiri0ksvZerUqaxZs4akpCS6du1KRkYG//znP7nkkkuCY2yI4cOHAzBz5kxuvPFG5s%2Bfj8/nC2nXqVMnevToQXR0dJ3tmzdv5sILL%2BSJJ54gIyODTp060b59e3799VcefPBB7rnnnjrt58%2Bfz9lnn81bb73Fli1b6Nq1K126dKGoqIivvvqKyZMnM3v27AaNffXq1YwfP57XX3%2BdvLw8unfvTnx8PIsXL%2BaPf/wj99xzD6Zp1ulzoO9vERERkcOSKSIiInKEcblcpsvlMhcvXtyofpdddpnpcrnMt99%2BO7htxYoVptvtNlNTU83//Oc/ZiAQME3TNHfu3Glee%2B21wXNddtllwT65ubnB7WVlZSHnycjICO4Pd36Xy2XOnTvXNE3T9Pv9ZmFhoWmapvnFF1%2BYLpfLHDRokPnpp58G%2B1VVVZnPP/98cN/mzZsbdd3hfPfdd8GxfPnll3X2lZeXm7feeqvpdrvNvn37mmeffbY5atQo0%2BVymaNGjTK//vrrkOOVlJSY69atM9etW9eocfzjH/8IjsPlcplut9scP368%2Bfe//9386quvwt7fWvtzvxYvXhw814knnmguXLgwuG/dunXmiSeeaLpcLvP%2B%2B%2B8Pbs/MzDRdLpd5/PHHm5mZmcHtlZWV5gMPPGC6XC7zlFNOqTO20aNHmy6Xy5w3b17IuYcOHRpyLXu29/v95siRI02Xy1VnjLVeffVV0%2BVymTfccENw27PPPmu6XC7z5ptv3udYTNM0x48fb7pcLvO9994LOf6cOXNMl8 ...

# %% [markdown]
# __Notes__
#
# - We can see that in the unscaled plot that $\mathbf{x}_1$ is much larger than $\mathbf{x}_0$ so the widest street is very close to the horizontal.
# - After scaling we have a much better decision boundary.

# %% [markdown]
# Standardization is especially important for RBF kernels.
#
# These models assume that all features look like standard normally distributed data: Gaussian with zero mean and unit variance.
#
# #### Dataset Example: Breast Cancer
#
# We can see below for example that the features in the Breast Cancer dataset are of completely different orders of magnitude$^{16}$.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

X, y = load_breast_cancer(return_X_y=True, as_frame=True)
X = X.reindex(sorted(X.columns), axis=1)

X_train, X_test, y_train, y_test = train_test_split(X.values, y.values,
                                                    test_size = 0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train,
                                                    test_size = 0.2, random_state=42)

fig, ax = plt.subplots(figsize=(width_inch*2, height_inch*1.5))

plt.boxplot(X_train, vert=False) 
plt.xscale("symlog") 
plt.ylabel("Feature") 
plt.xlabel("Feature magnitude")

ax.set_yticklabels(list(X.columns))

fig_num+=1
plt.suptitle("Figure %d: Feature Maginitudes for the Breast Cancer Dataset"%fig_num)
plt.tight_layout()
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2Bf/A8VfLDUVEEWWnUJYMZZ2yjbFvwwxCthljmzHDyIwZxtc6w9jHLluMZZgwtsJEEhmMPaRUtkqhRXWr%2B/uj3z3TVaFENO/n4%2BGhe87n8zmfc%2B65p9v7fM77o6fRaDQIIYQQQgghhBBCCCGEEKJQ0C/oDgghhBBCCCGEEEIIIYQQIv9I4F8IIYQQQgghhBBCCCGEKEQk8C%2BEEEIIIYQQQgghhBBCFCIS%2BBdCCCGEEEIIIYQQQgghChEJ/AshhBBCCCGEEEIIIYQQhYgE/oUQQgghhBBCCCGEEEKIQkQC/0IIIYQQQgghhBBCCCFEISKBfyGEEEIIIYQQQgghhBCiEJHAvxBCCCGEEEIIIYQQQghRiEjgXwghhBBCCCGEEEIIIYQoRCTwL4QQQgghhBBCCCGEEEIUIoYF3QEhhBDidbC1tX3psgMHDuS7774DYMCAAZw%2BfZrvv/8eV1fX19W9t46fnx%2BbNm3in3/%2BIS4ujpIlS%2BLg4MCQIUNo2LBhtnXu3LnD8uXLOXbsGDExMVSoUIGWLVsyfPhwypUrly/92rlzJ5MmTXrp8n/88Qe1a9fOl23nVlhYGOXLl0elUhXI9vPq1KlTDBw4UHm9dOlS2rZt%2B9w6MTExtGjRgrS0NAAOHz6MtbX1a%2B1ndtzd3dm1axdDhgxh4sSJr9RW69atlXO6VatWOuuCg4OpXr36K7X/MsaOHcvBgwcZPXo0Y8aMee3by419%2B/axYsUKQkNDKVKkCB07dmTq1KkF0pfs3o/nvX9vyvOuV0WLFqV06dI0aNCAfv360bhx4zfcuzfjVT4rISEhbNu2DX9/f8LCwlCr1ZiZmVGvXj169OjxwuvSf11ERARt2rTJdp1KpcLY2Bhra2tatmzJJ598Qvny5fO9D2/qWpmfoqOjMTIywtTUtKC7IoQQQuQ7CfwLIYQo1GxsbChevPhzy1SsWPEN9ebtNH/%2BfJYvXw6AqakpNWrUIDw8HG9vbw4fPsz3339Pv379dOqcO3eOTz/9lCdPnqBSqbCxseHhw4ds3LiR3bt3s3z58hxvGOSFkZER9vb2LyxnbGycb9t8WWq1mqVLl7JmzRoCAgLeucD/sw4dOvTCANuhQ4eUoH9hFh8fz9y5czl06BD%%2BvXrY2dnB0BcXBxjxozhyZMnNGzYkAULFigj/Lds2cK0adP49NNPOXToEKVLl86XflpYWLBly5Z8aSu/PXjwgGXLlhV0N16ZoaEhqamp/PXXX6jV6ufewDh48OAb7FnOvvrqK4YPH46Zmdkrt7Vu3TrUarXOKNjLly%2BzZcsWSpUq9crtv8sOHDgAQOPGjVm/fj0GBgYF0o935f3I6Xql0WjYunUrU6ZMYfbs2TRv3vydGx2dkz179nDy5Enat2%2Bf67rjxo1j//79mJiYMGLECPr374%2BJiQkA6enp7N27lzlz5uDn58dnn33G%2BvXr3/kbrK/bwoULs30K6/79%2B/z000/8%2BeefjB8/npIlS9K0adNX3t7x48fZv3%2B/8j3hXTFr1qyC7oIQQgjxWkmOfyGEECKTChUqUL169f/MyK9169YB0L9/fyXoDxlB4NGjR9O%2BfXvS0tLYtGmTsm779u1ERUVRpkwZli1bppPWp2/fvnTv3p24uLhcj/oUBat48eLUrl2bx48fc%2BrUqRzLxcbGcvr06QJLqZRZ2bJlqV69er7cYKpUqRLVq1cvkKdG3nYxMTEAODg4FFjQvzDQ09Pjk08%2BwcXFhbS0NHbs2FHQXSpwW7duZf/%2B/RgbG7Nq1So%2B/fRTJegPoK%2BvT9euXVmzZg1GRkb8/fffbN68uQB7/G6ztLRk3rx5tG/fHrVazXfffYdarS7obgkhhBDiNZHAvxBCCPEflZaWxt9//w2Q4yhNba7sy5cvK8tOnDgBQI8ePbIdeatNC/Tnn3%2BSnp6en10Wr9kHH3wAZKTyyYmPjw%2Bpqan5liJCvP20aZ0ypw4Reffee%2B8BcOvWrQLuScGKj4/np59%2BAmD48OHKcclOrVq16NOnDwAbNmx4I/0rrPT09JgyZQpFihThzp077N27t6C7JIQQQojXRAL/QgghRCYDBgzA1tZWZ4S71smTJxk2bBjNmjXDwcGBvn37cvjwYU6dOoWtrS0DBgxQykZERGBra4utrS0JCQlZ2rp%2B/bqyPrvtnz17lh9//JGGDRvSsGFD3NzcdILogYGBjBo1imbNmmFvb4%2BzszPffvstt2/fful91Wg0LF68mB9//BEbG5tsyyQmJgLo5HO/e/cuQI6P9FepUgWAJ0%2BeEBoaqixfvHgxtra2tG7d%2BqX7%2BKri4%2BNZsmQJXbp0oX79%2BjRs2JBPPvmEbdu25ZijPj4%2BnpUrV/LJJ5/g5OSEnZ0djo6OuLq6sn37dp33wd3dXWcyxYYNG2Jra0tERASQMeGora0tR48ezXZbTk5O2Nra6oyw1x6nNWvWsHnzZlq2bEm9evXo3LmzzvsbHh7ODz/8QOvWrbG3t8fJyYnPPvuMkydP5vl4aW8AHTlyJMebNgcOHEBPT0%2B5SZCTo0ePMmbMGJydnalbty4ODg506NCBWbNmERUVlW2dBw8eMH36dNq1a0fdunVp27YtCxYsICkpSTmW2mMLGcff1taWOXPmKMu0n8fPPvuMxMREfvnlF6W95s2bM378eEJCQrJs%2B9n3asCAAUoO9kePHmX5vGpfX79%2BPUtbCQkJyvrM/dXy9vbG1dWVRo0a0bhxY8aMGZNtnzLLy7ns7e3NkCFDcHR0xN7enhYtWjBy5Ej8/Pyeuy0t7bmoTe20ZMmSbD/Dly9f5uuvv6Zly5bY29vTpEkTRowYkW0e/szvz5kzZ%2BjSpQv29va0atXquSmkXvR%2BZObj44Orq6ty/fzkk0/Yv39/jm1fu3ZNp//Nmzfnyy%2B/5NKlSy88RnmhHWH97NMl2vN5//79LF68GCcnJxo0aEDPnj2Jj49/pf5eu3aNyZMn0759exwcHKhbty4uLi58/fXXOjd2M3vZ88fW1pYlS5YAGWnAnv19mJODBw8SHx%2BPSqV6qfJubm4sWLCAbdu2vfL%2BaX/XXrx4kVOnTjF06FAcHR2pX78%2BPXr0wNPTM8drYFBQEN9%2B%2B61y7W3atCmjR4/mwoUL2ZbPzbVa%2B92hc%2BfO3Lx5k48//pi6devSokWLbL%2BX5FWZMmWUG/vZ/X4KDw9nxowZdOnShYYNGyrv/6hRowgICNAp27p1a2VS68uXL2d7jchNe1qnTp1i5MiRNG3aFDs7O5o2bcrQoUPZt29fjvv1st%2BNtNc2rS5dumT5XSyEEEIUBpLjXwghhHgJa9euVYKLZcuWpWrVqly%2BfJmRI0fqBH7zy5w5czh//jw2NjY8evQICwsL9PUz7tf/%2BuuvLFy4EAAzMzNsbGyUCfX27dvHwoULcXZ2fuE2DA0NX1juyJEjANnmoU5NTc22Tua0AXfv3qVatWov7MvrEBERwZAhQ7h9%2BzaGhoZUqVKF9PR0zp07x7lz5zh06BC//vqrzijmu3fvMnDgQ ...

# %%
from sklearn.metrics import accuracy_score

lin = LinearSVC(random_state=42)
rbf = SVC(random_state=42, gamma="auto")

linear_svm = Pipeline([
        ("scaler", StandardScaler()),
        ("svm_clf", lin)
    ])

rbf_svm = Pipeline([
        ("scaler", StandardScaler()),
        ("svm_clf", rbf)])

model_name = ["Linear Model", "Linear Model", "RBF Model", "RBF Model"]

for i, model in enumerate([lin, linear_svm, rbf, rbf_svm]):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        trained_model = model.fit(X_train, y_train)
        pred_train = trained_model.predict(X_train)
        pred_val = trained_model.predict(X_val)
        
        if (i % 2) == 0:
            scaled = "Unscaled"
        else:
            scaled = "Scaled"
        
        score_df = pd.DataFrame([round(accuracy_score(y_train, pred_train),2), 
                                 round(accuracy_score(y_val, pred_val),2)], columns = ["Score"])
        
        score_df["Data"] = ['Training', 'Validation']
        score_df["Model Name"] = model_name[i]
        score_df["Scaling"] = scaled
        
        if i == 0:
            scores_df = score_df
        else:
            scores_df = pd.concat([scores_df, score_df], axis=0)

#fig = plt.figure(figsize=(width_inch, height_inch))
#fig, ax = plt.subplots(figsize=(width_inch, height_inch))
sns_plot = sns.catplot(data = scores_df, y="Scaling", x = "Score", hue="Data", kind="bar", col="Model Name", ax=ax)
fig = sns_plot.fig
plt.xlim(0.5,1.0)
fig_num+=1
plt.suptitle("Figure %d: Effects of Scaling on SVM Overfitting"%fig_num)
plt.tight_layout()
plt.close()
display(MatplotlibFigure(fig, centered=True))
# Out:
# <center><img src='...%2B3cMSIQZhyu%2B%2BLq7TnXln5p2Z3T2TZ1%2BxMZlMJgEAAAAAAACAgdkmdwUAAAAAAAAAILEIOgEAAAAAAAAYHkEnAAAAAAAAAMMj6AQAAAAAAABgeASdAAAAAAAAAAyPoBMAAAAAAACA4RF0AgAAAAAAADA8gk4AAAAAAAAAhkfQCQAAAAAAAMDwCDoBAAAAAAAAGB5BJwAAAAAAAADDI%2BgEALxynp6ecf43ZMgQy3Zt2rSRp6enfv/992SsffKbMmWKPD091a9fvziVj4iIUNOmTVWmTJkkrce4cePidS9LlSoVZR/Xrl1Tjx49VKZMGRUrVkxVq1ZVYGCgwsPDNW7cOFWpUkWFCxdW%2BfLltXz58iSt/8vcuXNHjx49eq3HjIuYrllcbNu2TZ9%2B%2BqmqVKmiokWLqlSpUqpVq5YGDhyo48ePv%2BKax%2Bz69euW98mTJ08sy/v16ydPT08NHz482epmBM%2BePdPChQvVsWNHVahQQYULF9b777%2BvJk2aaMyYMQoICLAqHxoaqtKlS8vT01OTJk2K0zHCw8NVrlw5eXp6atGiRZKsvwMKFSqke/fuvXQ/GzZssGxTpUqV%2BJ%2BspLCwMC1dulTdu3dXpUqVVKRIEZUoUUL169fX8OHDdfny5QTt93U7efKk2rdvr/fee08lSpRQgwYNYvwsmF24cCHafQUGBka5z%2Bb78/HHH7%2BS%2BgMAYAT2yV0BAMDbw8PDQ6lSpYq1TM6cOV9TbYzh4sWLGj9%2BfLy2GT16tI4dO6Z06dK9kjqlSpVKHh4eLy2XMmVKq9dhYWHq1KmTLl%2B%2BLGdnZ7m7u8vR0VGpUqXShAkTLOeZL18%2B2draKlu2bK%2Bk/tGZNWuWxo0bpwULFihNmjSv7bgvE9s1e9l2n3/%2BudauXStJypo1qzw9PfXo0SNdv35dFy5c0IIFC/TRRx/pq6%2B%2Beh2ngiRy69YtdezYUWfPnpWtra1y5cqlbNmy6c6dOzp58qT%2B%2BecfzZo1S0OGDFGtWrUkSY6OjqpVq5YWLFigNWvWqHv37i89zq5du3T37l05OzurZs2aUdaHh4fLz89PTZo0iXU/69atS9iJ/r8TJ07o008/tYSZrq6uyp8/vx4%2BfKhz587p9OnTmj17tnr16qXu3bvLxsYmUcd7VR49eqSPPvpIDx48UJo0aZQnTx65ubnFWP7y5cv64YcflCZNGo0dO9Zq3apVqzRs2DANGjRIWbJkedVVBwDAUAg6AQCvzTfffBOvVobDhw9XcHCwMmXK9Apr9eaKiIjQgAEDFBISEqfyJpNJ48eP1%2BTJk19pvQoVKqS5c%2BfGe7vTp0/r8uXLsrW11dKlS/XOO%2B9Y1pnDkG7duqlv375JVte4Gjp06Gs/ZlzEds1iM3r0aK1du1Z58%2BbVyJEjVahQIcu6p0%2Bfas6cORo1apRmzJih7Nmzq02bNq/qFOLl008/VefOneXq6prcVXlj9erVS2fPnlWVKlU0cOBAZc6c2bLu1q1b%2BuWXX7RixQp9%%2BfO1d9//60UKVK8tOzt27fVs2fPeLf%2BfJ3M3VwzZMgQJbAzr4uuu/vbLLZrFpOgoCDNmzdPUmTg%2BXzIKUkpUqRQly5dLK36Jk%2BerIiIiCSsdcJlzpxZ7u7uSp8%2BfXJX5Y20f/9%2BHT16VJkzZ9bo0aOtQk4p8voNHz5cpUuX1rNnzzR16lTLumLFiilv3rySpNWrV8d6nODgYG3atEmS1KhRoyjrS5YsKXt7e%2B3evTvWYRR27NihJ0%2BeqGDBgnE%2BR7N79%2B7pk08%2BUVBQkOrUqaPff/9dXl5eVi0206dPrz59%2BmjSpElydHTU6tWrtWDBgngf63Uwf5bz5ctnFeQ7ODjI3d1d7u7uiW6Nmj59erm7u9PKEwDwViPoBADgDXTt2jWNHj1aOXLkUMOGDWMtu3PnTvn6%2Bmrz5s3KlCmTPvvss9dUy/gJDw%2BXFNmN9kVhYWExrnubxXbNYnL58mUFBQXJ0dFRBQoUiLFc06ZNJUWG5P7%2B/omrKF6LkydPSoocBsTJySnaMra2tmrcuLEk6Z9//rFa16BBA0mytCCMyebNmxUUFKRs2bLp/fffj7Le1dVVXl5eCg0N1bZt22Lcj7mldo0aNWI9XnRmzJih27dvK3fu3BoyZIjs7WPuiPbBBx%2BoU6dOkqSff/5ZDx48iPfxXrWEfJYBAED8EXQCAN5YsU1GtGfPHnXq1EnlypVTiRIl1KJFC23evFn79u2Tp6enVVfcl032cPbsWcv66I5/%2BPBhDRw4UCVLllTJkiXVvn17qxZwBw4cUM%2BePVWuXDkVLlxY3t7eGjBggK5cuZLgc//mm28UFBSkQYMGydnZOday58%2BfV1BQkOrXr6%2BVK1eqWLFiL92/edKKhE4OEh/m69%2BtWzdJ0o0bNyzX23yNzcFE27Zto514KSHX%2BNq1axoyZIh8fHxUtGhRlS5dWh07dtTOnTstZczXwaxu3bry9PTUvn37LMv27dunHj16qGzZsnr33XdVtmxZdezY8aVhUXQePXqkcePGqW7duipWrJhKlCihRo0aadq0aXr69GmcrtnzdYuOORAKDQ3Vnj17YiyXLVs2LV%2B%2BXH5%2BfsqaNWuU9WfOnNGAAQMsE0SVLVtWvXr10rFjx6Ld35YtW9S7d295e3tbJoupWbOmhg4dGm032%2BhENxmR%2BTPdtWtXBQUFaeTIkapevbqKFCmi8uXL6/PPP9elS5ei3d/Dhw81ZswY1ahRQ0WLFlXFihU1aNAgPXjwwPLee9n1fF5ISIhmzpypJk2aqESJEipWrJjq1Kmj0aNH6%2BHDhzGez7p163T69Gn17t1b77//vooUKaJatWrpt99%2BU2hoaJyPb763x48f1927d2Ms5%2BPjo7/%2B%2BksLFy60Wl6/fn3Z2trq8uXLltA0OuZu6%2BbyMR1DipxsKDqhoaHasmWL8uTJE%2BW79WXCw8P1559/Sorsjh2XVu1dunRRihQpFBQUpBUrVkiSlixZIk9PT9WtWzfG7caOHStPT0998sknVsvv3r2r4cOHy9fXV0WLFpWXl5fatWsX45ijnp6eKlGihAICAtSxY0cVLVpU77//vj788EN5enpq0KBBkiJb5Zo/y9evX4/2/588PT0trfPXr19v%2Ba5cunSpPD09dePGDUmRQ314enpq6dKlkqKfjMi8/zp16igsLExTp05VnTp1VLRoUZUpU0Y9evSIEoibPX36VDNmzFC9evVUvHhxlS1bVl999ZX8/f0t723zsQEAeFMQdAIADGfGjBlq3769duzYITs7O%2BXNm1cnTpxQjx49NHv27CQ/3vDhwzV//ny5ubkpZcqUypQpk%2BWP/4kTJ6p169batGmTIiIi5OHhoaCgIC1ZskT169ePtbVTTBYuXKi9e/eqUaNGKleu3EvLFy1aVMuWLdPPP//8Ro5t6OTkpJIlS1rGBHR0dLSExilTprR0g5UiW6qVLFlSefLksWyfkGu8a9cuNWzYUHPmzNHt27eVL18%2BOTk5aefOnerYsaMWL14sKTLsK1mypGW7QoUKqWTJkkqdOrWkyMCnffv22rx5s6WFpKOj ...

# %% [markdown]
# __Notes__
#
# - In this example, the RBF model overfits quite substantially, with a perfect score on the training set and only 60% accuracy on the test set.
# - Also you see the linear model also has a minor improvement in accuracy if scaled.

# %% [markdown]
# ## Recap$^1$
#
# The kernel approach is an efficient computational approach to enlarge our feature space to accommodate a non-linear boundary.
#
# Assume we have a new point $x^*$. If wanted to compute $f(x^*)$ using our linear classifier we would need to the inner product between $x^*$ and each training point $x_i$:
#
# $$f(x) = \sum_{i\in s}\alpha_i \left<x^*,x_i\right> + b.$$
#
# Instead of actually calculating the inner product, we could instead use a _generalisation_, $K(x,x_{i^{\prime}})$, where $K$ is a _kernel_. We can now define the classifier as:
#
# $$f(x) = \sum_{i\in s}\alpha_i K\left(x^*,x_i\right) + b.$$
#
# A kernel is a function that quantifies the similarity of two observations. For example, for a _linear kernel_ we could use:
#
# $$K(x_i, x_{i^\prime}) = \sum^p_{j=1}x_{ij}x_{{i^\prime}j},$$
#
# where we quantifiy the similarity of pairs of observations using Pearson (standard) correlation.
#
# However, we could use other forms of kernel to fit the support vector classifier in a higher-dimensional space, such as a _polynomial kernel_:
#
# $$K(x_i, x_{i^\prime}) = \left(\gamma \sum^p_{j=1}x_{ij}x_{{i^\prime}j} + r\right)^d.$$
#
# Another popular choice is the _radial kernel_:
#
# $$K(x_i, x_{i^\prime}) = \exp\left(-\gamma\sum^p_{j=1}(x_{ij}-x_{{i^\prime}j})^2\right).$$

# %% [markdown]
# # Associated Exercises
#
# Now might be a good time to try exercises 5-8.
#
# # References
# 1. James, G., Witten, D., Hastie, T., & Tibshirani, R. (2013). An introduction to statistical learning (Vol. 112, p. 18). New York: springer.
# 2. Géron, A. (2017). Hands-on machine learning with Scikit-Learn and TensorFlow: concepts, tools, and techniques to build intelligent systems. " O'Reilly Media, Inc.".
# 3. Zheng, A., & Casari, A. (2018). Feature Engineering for Machine Learning: Principles and Techniques for Data Scientists. " O'Reilly Media, Inc.".
# 4. Raschka, 2016
# 5. Cortes, C. and Vapnik, V. Support vector networks. Machine Learning, 20:273–297, 1995
# 6. Burges, C. J. (1998). A tutorial on support vector machines for pattern recognition. Data mining and knowledge discovery, 2(2), 121-167.
# 7. Murphy, K. P. (2012). Machine learning: a probabilistic perspective. MIT press.
# 8. Burkov, A. (2019). The hundred-page machine learning book (Vol. 1). Canada: Andriy Burkov.
# 9. Zhang, J. (2015). A complete list of kernels used in support vector machines. Biochem. Pharmacol.(Los Angel), 4, 2167-0501.
# 10. Raschka, Sebastian, and Vahid Mirjalili. "Python Machine Learning: Machine Learning and Deep Learning with Python." Scikit-Learn, and TensorFlow. Second edition ed (2017).
# 11. https://scikit-learn.org/stable/modules/preprocessing.html#preprocessing
# 12. https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# 13. Al-Mejibli, I. S., Alwan, J. K., & Abd Dhafar, H. (2020). The effect of gamma value on support vector machine performance with different kernels. International Journal of Electrical and Computer Engineering, 10(5), 5497.

# %%
import sys
from shutil import copyfile

# where the HTML template is located
dst = os.path.join(sys.prefix, 'lib', 'site-packages', 'nbconvert', 'templates', "classic.tplx")

# If its not located where it should be
if not os.path.exists(dst):
    # uses a nb_pdf_template
    curr_path = os.path.join(os.getcwd(),"..", "Extra", "classic.tplx")
    # copy where it is meant to be
    copyfile(curr_path, dst)

# Create HTML notes document (preferred)
# !jupyter nbconvert 2_Support_Vector_Machines.ipynb \
    --to html \
    --output-dir . \
    --template classic
# !jupyter nbconvert 2_Support_Vector_Machines.ipynb \
    --to slides \
    --output-dir . \
    --TemplateExporter.exclude_input=True \
    --TemplateExporter.exclude_output_prompt=True \
    --SlidesExporter.reveal_scroll=True
